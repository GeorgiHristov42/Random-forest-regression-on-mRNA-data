# %%
from __future__ import print_function, division
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score, explained_variance_score, mean_absolute_error, mean_squared_error, adjusted_rand_score
from sklearn.model_selection import train_test_split, KFold, cross_val_predict
from sklearn.linear_model import LinearRegression, Lasso, LassoCV
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVR
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from ipywidgets import FloatProgress
from IPython.display import display
# %matplotlib inline

# %%
def fit_scatter(y_true, y_pred):
    assert y_true.shape == y_pred.shape
    fig, ax = plt.subplots()
    ax.scatter(y_true, y_pred)
    ax.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], 'k--', lw=4)
    ax.set_xlabel('Observed AUC')
    ax.set_ylabel('Predicted AUC')
    ax.set_title('')

# %%
def print_stats(true,predictions):
    print('Coefficient of determination R^2: {}'.format(r2_score(true, predictions)))
    print('Mean squared error:               {}'.format(mean_squared_error(true, predictions)))
    print('Mean absolute error:              {}'.format(mean_absolute_error(true, predictions)))
    print('Root mean squared error:          {}'.format(np.sqrt(mean_squared_error(true, predictions))))
    print('Correlation Coefficient:          {}'.format(np.corrcoef(true, predictions)[0][1]))

# %%
def get_best_settings(results_1,results_2):
    best_result_1 = results_1[0][0][0]
    best_result_2 = results_2[0][0][0]
    best_difference = results_2[0][0][0] - results_1[0][0][0]

    best_i_1=0
    best_j_1=0
    best_k_1=0

    best_i_2=0
    best_j_2=0
    best_k_2=0

    best_i_3=0
    best_j_3=0
    best_k_3=0
    

    mxf = [5,7,10,12,15,18,20,25,30,50,80,10]
    md = [5,7,10,12,15,18,20]
    n_est = [10,20,30,40,50,60,80,90,100,120,140,160]
    
    for i in range(len(mxf)):
        for j in range(len(md)):
            for k in range(len(n_est)):
                if best_result_1 < results_1[i][j][k]:
                    best_result_1 = results_1[i][j][k]
                    best_i_1=i
                    best_j_1=j
                    best_k_1=k
                if best_result_2 < results_2[i][j][k]:
                    best_result_2 = results_2[i][j][k]
                    best_i_2=i
                    best_j_2=j
                    best_k_2=k
                if best_difference < results_2[i][j][k] - results_1[i][j][k]:
                    best_difference = results_2[i][j][k] - results_1[i][j][k]
                    best_i_3=i
                    best_j_3=j
                    best_k_3=k

#     print('{} {} {} : {}'.format(best_i_1,best_j_1,best_k_1,best_result_1))
#     print('{} {} {} : {}'.format(best_i_2,best_j_2,best_k_2,best_result_2))
#     print('{} {} {} : {}'.format(best_i_3,best_j_3,best_k_3,best_difference))

    print('Normal best: {} | max_features: {}; max_depth: {}; n_estimators: {};'.format(best_result_1,mxf[best_i_1],md[best_j_1],n_est[best_k_1]))
    print('Extended best: {} | max_features: {}; max_depth: {}; n_estimators: {};'.format(best_result_2,mxf[best_i_2],md[best_j_2],n_est[best_k_2]))
    print('Best difference: {} | max_features: {}; max_depth: {}; n_estimators: {};'.format(best_difference,mxf[best_i_3],md[best_j_3],n_est[best_k_3]))
    
    return mxf[best_i_1],md[best_j_1],n_est[best_k_1],mxf[best_i_2],md[best_j_2],n_est[best_k_2]

# %%
data_path = os.path.join(os.getcwd(), 'datasets', 'features.csv')
data_path_rp = os.path.join(os.getcwd(), 'datasets', 'rp_features.csv')
data_path_nrp = os.path.join(os.getcwd(), 'datasets', 'nrp_features.csv')

data_path_extended = os.path.join(os.getcwd(), 'datasets', 'extended_features.csv')
data_path_rp_extended = os.path.join(os.getcwd(), 'datasets', 'rp_extended_features.csv')
data_path_nrp_extended = os.path.join(os.getcwd(), 'datasets', 'nrp_extended_features.csv')

data_path_cut = os.path.join(os.getcwd(), 'datasets', 'features_cut.csv')
data_path_extended_cut = os.path.join(os.getcwd(), 'datasets', 'extended_features_cut.csv')

gene_features = pd.read_csv(data_path, delimiter = ',')
rp_gene_features = pd.read_csv(data_path_rp, delimiter = ',')
nrp_gene_features = pd.read_csv(data_path_nrp, delimiter = ',')

extended_features = pd.read_csv(data_path_extended, delimiter = ',')
rp_extended_features = pd.read_csv(data_path_rp_extended, delimiter = ',')
nrp_extended_features = pd.read_csv(data_path_nrp_extended, delimiter = ',')

gene_features_cut = pd.read_csv(data_path_cut, delimiter = ',')
extended_features_cut = pd.read_csv(data_path_extended_cut, delimiter = ',')

print('Number of data points: {}. Number of attributes: {}'.format(gene_features.shape[0],gene_features.shape[1]))
print('Number of data points: {}. Number of attributes: {}'.format(extended_features.shape[0],extended_features.shape[1]))
print('Number of data points: {}. Number of attributes: {}'.format(rp_gene_features.shape[0],rp_gene_features.shape[1]))
print('Number of data points: {}. Number of attributes: {}'.format(rp_extended_features.shape[0],rp_extended_features.shape[1]))
print('Number of data points: {}. Number of attributes: {}'.format(nrp_gene_features.shape[0],nrp_gene_features.shape[1]))
print('Number of data points: {}. Number of attributes: {}'.format(nrp_extended_features.shape[0],nrp_extended_features.shape[1]))
print('Number of data points: {}. Number of attributes: {}'.format(gene_features_cut.shape[0],gene_features_cut.shape[1]))
print('Number of data points: {}. Number of attributes: {}'.format(extended_features_cut.shape[0],extended_features_cut.shape[1]))
# Out:
# Number of data points: 117. Number of attributes: 101
# Number of data points: 117. Number of attributes: 106
# Number of data points: 84. Number of attributes: 101
# Number of data points: 84. Number of attributes: 106
# Number of data points: 33. Number of attributes: 101
# Number of data points: 33. Number of attributes: 106
# Number of data points: 117. Number of attributes: 21
# Number of data points: 117. Number of attributes: 26

# %%
def get_data(dataset):
    
    X = gene_features.drop(['ORG', 'Gene','AUC'], axis=1)
    X_cut = gene_features_cut.drop(['ORG', 'Gene','AUC'], axis=1)
    y = gene_features['AUC']

    X_rp = rp_gene_features.drop(['ORG', 'Gene','AUC'], axis=1)
    y_rp = rp_gene_features['AUC']

    X_nrp = nrp_gene_features.drop(['ORG', 'Gene','AUC'], axis=1)
    y_nrp = nrp_gene_features['AUC']

    X_extended = extended_features.drop(['ORG', 'Gene','AUC'], axis=1)
    X_extended_cut = extended_features_cut.drop(['ORG', 'Gene','AUC'], axis=1)
    y_extended = extended_features['AUC']

    X_rp_extended = rp_extended_features.drop(['ORG', 'Gene','AUC'], axis=1)
    y_rp_extended = rp_extended_features['AUC']

    X_nrp_extended = nrp_extended_features.drop(['ORG', 'Gene','AUC'], axis=1)
    y_nrp_extended = nrp_extended_features['AUC']
    
    if dataset == 'full':
        return X,y,X_extended,y_extended
    elif dataset == 'rp':
        return X_rp,y_rp,X_rp_extended,y_rp_extended
    elif dataset == 'nrp':
        return X_nrp,y_nrp,X_nrp_extended,y_nrp_extended
    elif dataset == 'cut':
        return X_cut,y,X_extended_cut,y_extended
    else:
        return None, None, None, None

# %%
kf = KFold(n_splits=5,shuffle=True,random_state=0)

# %%
X,y,X2,y2 = get_data('full')

lr1 = LinearRegression()
lr2 = LinearRegression()

predictions1 = cross_val_predict(lr1,X,y=y,cv=kf)
predictions2 = cross_val_predict(lr1,X2,y=y2,cv=kf)

print('Data')
print_stats(y,predictions1)
print('\n')
print('Extended Data')
print_stats(y2,predictions2)
# Out:
# Data
# Coefficient of determination R^2: -7.2183020153338795
# Mean squared error:               0.42862335450518435
# Mean absolute error:              0.47025816832413864
# Root mean squared error:          0.6546933285937656
# Correlation Coefficient:          0.15630895126957245
#
#
# Extended Data
# Coefficient of determination R^2: -5.124905342449308
# Mean squared error:               0.3194428081383538
# Mean absolute error:              0.3629398280868392
# Root mean squared error:          0.5651927176975601
# Correlation Coefficient:          0.22134989868330107

# %%
X,y,X2,y2 = get_data('full')

rfr1 = ExtraTreesRegressor(random_state=1337)
rfr2 = ExtraTreesRegressor(random_state=1337)

predictions_rfr1 = cross_val_predict(rfr1,X,y=y,cv=kf)
predictions_rfr2 = cross_val_predict(rfr2,X2,y=y2,cv=kf)

print('Data')
print_stats(y,predictions_rfr1)
print('\n')
print('Extended Data')
print_stats(y2,predictions_rfr2)

rfr1.fit(X,y)
fig, ax1 = plt.subplots(figsize=(20,6))
xx = np.arange(len(rfr1.feature_importances_))
ax1.bar(xx, rfr1.feature_importances_)
ax1.set_xticks(xx)
ax1.set_xticklabels(gene_features.drop(['ORG','Gene','AUC'], axis=1).columns, rotation='vertical')
ax1.set_title('Random forrest regression feature importance')

rfr2.fit(X2,y2)
fig2, ax2 = plt.subplots(figsize=(20,6))
xx = np.arange(len(rfr2.feature_importances_))
ax2.bar(xx, rfr2.feature_importances_)
ax2.set_xticks(xx)
ax2.set_xticklabels(extended_features.drop(['ORG','Gene','AUC'], axis=1).columns, rotation='vertical')
ax2.set_title('Random forrest regression extended features importance')
# Out:
# Data
# Coefficient of determination R^2: 0.22679697269381738
# Mean squared error:               0.04032619811965812
# Mean absolute error:              0.1447948717948718
# Root mean squared error:          0.2008138394624686
# Correlation Coefficient:          0.4992323501777428
#
#
# Extended Data
# Coefficient of determination R^2: 0.2969882017516636
# Mean squared error:               0.036665393247863255
# Mean absolute error:              0.14024017094017094
# Root mean squared error:          0.191482096415992
# Correlation Coefficient:          0.5601146457156252

# %% [markdown]
# # Full Set

# %%
def best_RFs(results1,results2,dataset):
     
    X,y,X2,y2 = get_data(dataset)
    mxf1, md1, n_est1, mxf2, md2, n_est2 = get_best_settings(results1,results2)
    
    kf = KFold(n_splits=5,shuffle=True,random_state=0)
    
    rfr1 = ExtraTreesRegressor(n_estimators=n_est1, 
                                criterion='mse', 
                                max_features=mxf1, 
                                max_depth=md1, 
                                n_jobs=2,
                                random_state=1337)

    rfr2 = ExtraTreesRegressor(n_estimators=n_est2, 
                                criterion='mse', 
                                max_features=mxf2, 
                                max_depth=md2, 
                                n_jobs=2,
                                random_state=1337)

    predictions_rfr1 = cross_val_predict(rfr1,X,y=y,cv=kf)
    predictions_rfr2 = cross_val_predict(rfr2,X2,y=y2,cv=kf)

    print('Normal feature space')
    print_stats(y, predictions_rfr1)
    print('\n')
    print('Extended feature space')
    print_stats(y2, predictions_rfr2)
    print('-------------------------------------------------------\n')
         
    settings = 'max_features: {}; max_depth: {}; n_estimators: {};'.format(mxf1,md1,n_est1)
          
    rfr1.fit(X,y)
    fig, ax1 = plt.subplots(figsize=(20,6))
    xx = np.arange(len(rfr1.feature_importances_))
    ax1.bar(xx, rfr1.feature_importances_)
    ax1.set_xticks(xx)
    ax1.set_xticklabels(gene_features.drop(['ORG','Gene','AUC'], axis=1).columns, rotation='vertical')
    ax1.set_title('Normal RF: {} -- {}'.format(settings,np.corrcoef(y, predictions_rfr1)[0][1]))

    settings = 'max_features: {}; max_depth: {}; n_estimators: {};'.format(mxf2,md2,n_est2)
    rfr2.fit(X2,y2)
    fig2, ax2 = plt.subplots(figsize=(20,6))
    xx = np.arange(len(rfr2.feature_importances_))
    ax2.bar(xx, rfr2.feature_importances_)
    ax2.set_xticks(xx)
    ax2.set_xticklabels(extended_features.drop(['ORG','Gene','AUC'], axis=1).columns, rotation='vertical')
    ax2.set_title('Extended RF : {} -- {}'.format(settings,np.corrcoef(y2, predictions_rfr2)[0][1]))

# %%
X,y,X2,y2 = get_data('full')
print('echo')
mxf = [5,7,10,12,15,18,20,25,30,50,80,10]
md = [5,7,10,12,15,18,20]
n_est = [10,20,30,40,50,60,80,90,100,120,140,160]

results_1_full = np.zeros((len(mxf),len(md),len(n_est)))
results_2_full = np.zeros((len(mxf),len(md),len(n_est)))

f = FloatProgress(min=0, max=(len(mxf)*len(md)*len(n_est)))
display(f)


i = 0
for max_features in mxf:
    j = 0
    for max_depth in md:
        k = 0
        for n_estimators in n_est:            
            
            kf = KFold(n_splits=5,shuffle=True,random_state=0)

            rfr1 = ExtraTreesRegressor(n_estimators=n_estimators, 
                                        criterion='mse', 
                                        max_features=max_features, 
                                        max_depth=max_depth, 
                                        n_jobs=2,
                                        random_state=1337)

            rfr2 = ExtraTreesRegressor(n_estimators=n_estimators, 
                                        criterion='mse', 
                                        max_features=max_features, 
                                        max_depth=max_depth, 
                                        n_jobs=2,
                                        random_state=1337)

            predictions_rfr1 = cross_val_predict(rfr1,X=X,y=y,cv=kf)
            predictions_rfr2 = cross_val_predict(rfr2,X=X2,y=y2,cv=kf)
            
            print('max_features: {}; max_depth: {}; n_estimators: {};\n'.format(max_features,max_depth,n_estimators))

            print('Normal feature space')
            print_stats(y, predictions_rfr1)
            print('\n')
            print('Extended feature space')
            print_stats(y2, predictions_rfr2)
            print('-------------------------------------------------------\n')
            

            results_1_full[i][j][k]=np.corrcoef(y, predictions_rfr1)[0][1]
            results_2_full[i][j][k]=np.corrcoef(y2, predictions_rfr2)[0][1]
            
            f.value += 1
            
            k += 1
        j += 1
    i += 1
# Out:
# echo
# FloatProgress(value=0.0, max=1008.0)
# max_features: 5; max_depth: 5; n_estimators: 10;
#
# Normal feature space
# Coefficient of determination R^2: 0.32593903458010076
# Mean squared error:               0.03515547026626796
# Mean absolute error:              0.14173351167018933
# Root mean squared error:          0.1874979206985186
# Correlation Coefficient:          0.573707468406997
#
#
# Extended feature space
# Coefficient of determination R^2: 0.20641257829135884
# Mean squared error:               0.04138934078489923
# Mean absolute error:              0.1499463155600729
# Root mean squared error:          0.2034437042154395
# Correlation Coefficient:          0.470548824669076
# -------------------------------------------------------
#
# max_features: 5; max_depth: 5; n_estimators: 20;
#
# Normal feature space
# Coefficient of determination R^2: 0.3026746350605406
# Mean squared error:               0.03636881883194702
# Mean absolute error:              0.14484901908078682
# Root mean squared error:          0.1907061059115492
# Correlation Coefficient:          0.5552667214108965
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2877748409652445
# Mean squared error:               0.03714591362776329
# Mean absolute error:              0.14232452654228497
# Root mean squared error:          0.19273275182947835
# Correlation Coefficient:          0.5367964280730543
# -------------------------------------------------------
#
# max_features: 5; max_depth: 5; n_estimators: 30;
#
# Normal feature space
# Coefficient of determination R^2: 0.29449953771844206
# Mean squared error:               0.036795188858217504
# Mean absolute error:              0.14459243884979306
# Root mean squared error:          0.19182072061750133
# Correlation Coefficient:          0.5472629378411419
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3326403819872129
# Mean squared error:               0.034805963275653384
# Mean absolute error:              0.13617423548210586
# Root mean squared error:          0.18656356363355997
# Correlation Coefficient:          0.5832635164500457
# -------------------------------------------------------
#
# max_features: 5; max_depth: 5; n_estimators: 40;
#
# Normal feature space
# Coefficient of determination R^2: 0.3026142650284892
# Mean squared error:               0.03637196741490262
# Mean absolute error:              0.1431849921699895
# Root mean squared error:          0.19071436079882034
# Correlation Coefficient:          0.5554679434253925
#
#
# Extended feature space
# Coefficient of determination R^2: 0.32573105759727283
# Mean squared error:               0.03516631725045925
# Mean absolute error:              0.13724820621209033
# Root mean squared error:          0.18752684407961237
# Correlation Coefficient:          0.5806877192139185
# -------------------------------------------------------
#
# max_features: 5; max_depth: 5; n_estimators: 50;
#
# Normal feature space
# Coefficient of determination R^2: 0.3255990785244184
# Mean squared error:               0.035173200583880904
# Mean absolute error:              0.1419429996919351
# Root mean squared error:          0.18754519610984682
# Correlation Coefficient:          0.5793027704194349
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3254459253816556
# Mean squared error:               0.03518118824528364
# Mean absolute error:              0.13857253149588766
# Root mean squared error:          0.1875664901982325
# Correlation Coefficient:          0.5838534163790059
# -------------------------------------------------------
#
# max_features: 5; max_depth: 5; n_estimators: 60;
#
# Normal feature space
# Coefficient of determination R^2: 0.3236466362804885
# Mean squared error:               0.03527502968951725
# Mean absolute error:              0.14132811277818522
# Root mean squared error:          0.18781647874858384
# Correlation Coefficient:          0.5772796880773531
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3316113914795925
# Mean squared error:               0.03485963000173711
# Mean absolute error:              0.1385893299135152
# Root mean squared error:          0.1867073378358149
# Correlation Coefficient:          0.590223898361523
# -------------------------------------------------------
#
# max_features: 5; max_depth: 5; n_estimators: 80;
#
# Normal feature space
# Coefficient of determination R^2: 0.32048271410029383
# Mean squared error:               0.035440043208823074
# Mean absolute error:              0.14129522094670308
# Root mean squared error:          0.1882552607732997
# Correlation Coefficient:          0.5759354467879824
#
#
# Extended feature space
# Coefficient of determination R^2: 0.32778669393181425
# Mean squared error:               0.0350591060844897
# Mean absolute error:              0.1385525674537277
# Root mean squared error:          0.1872407703586206
# Correlation Coefficient:          0.5885752040992982
# -------------------------------------------------------
#
# max_features: 5; max_depth: 5; n_estimators: 90;
#
# Normal feature space
# Coefficient of determination R^2: 0.31469784748234697
# Mean squared error:               0.03574175138777817
# Mean absolute error:              0.14214470343017038
# Root mean squared error:          0.18905488988063274
# Correlation Coefficient:          0.5698438170425111
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3327991500016937
# Mean squared error:               0.034797682772110455
# Mean absolute error:              0.13763343351218602
# Root mean squared error:          0.1865413701357167
# Correlation Coefficient:          0.5948429187440625
# -------------------------------------------------------
#
# max_features: 5; max_depth: 5; n_estimators: 100;
#
# Normal feature space
# Coefficient of determination R^2: 0.31176583724175533
# Mean squared error:               0.03589466960159182
# Mean absolute error:              0.1425332256890851
# Root mean squared error:          0.1894588863093833
# Correlation Coefficient:          0.567357727102476
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3379486650975204
# Mean squared error:               0.03452911118270791
# Mean absolute error:              0.13757244420967968
# Root mean squared error:          0.18582010435555113
# Correlation Coefficient:          0.5992344020439585
# -------------------------------------------------------
#
# max_features: 5; max_depth: 5; n_estimators: 120;
#
# Normal feature space
# Coefficient of determination R^2: 0.31408299539741535
# Mean squared error:               0.035773818834639606
# Mean absolute error:              0.14202383569233026
# Root mean squared error:          0.1891396807511306
# Correlation Coefficient:          0.5710594888846743
#
#
# Extended feature space
# Coefficient of determination R^2: 0.33438178650530326
# Mean squared error:               0.03471514078644555
# Mean absolute error:              0.13826457276540838
# Root mean squared error:          0.18631999566993757
# Correlation Coefficient:          0.5942543698304271
# -------------------------------------------------------
#
# max_features: 5; max_depth: 5; n_estimators: 140;
#
# Normal feature space
# Coefficient of determination R^2: 0.31123850746434456
# Mean squared error:               0.03592217234579647
# Mean absolute error:              0.14187403268947069
# Root mean squared error:          0.18953145476621147
# Correlation Coefficient:          0.5690749512111873
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3349260331578646
# Mean squared error:               0.03468675574711945
# Mean absolute error:              0.13815476367318447
# Root mean squared error:          0.1862438072718646
# Correlation Coefficient:          0.594198959740174
# -------------------------------------------------------
#
# max_features: 5; max_depth: 5; n_estimators: 160;
#
# Normal feature space
# Coefficient of determination R^2: 0.3128181069024131
# Mean squared error:               0.03583978875747663
# Mean absolute error:              0.14189839029422877
# Root mean squared error:          0.1893139951442487
# Correlation Coefficient:          0.5701253840629065
#
#
# Extended feature space
# Coefficient of determination R^2: 0.33793057316056396
# Mean squared error:               0.03453005476286514
# Mean absolute error:              0.13752503976489014
# Root mean squared error:          0.1858226432996397
# Correlation Coefficient:          0.5971384550375287
# -------------------------------------------------------
# max_features: 5; max_depth: 7; n_estimators: 10;
#
# Normal feature space
# Coefficient of determination R^2: 0.3648107849588548
# Mean squared error:               0.033128124470050854
# Mean absolute error:              0.13703781323785985
# Root mean squared error:          0.18201133060897845
# Correlation Coefficient:          0.6094278253232922
#
#
# Extended feature space
# Coefficient of determination R^2: 0.22342889852514547
# Mean squared error:               0.04050185913159281
# Mean absolute error:              0.14905232081661005
# Root mean squared error:          0.201250736971552
# Correlation Coefficient:          0.4803583982367557
# -------------------------------------------------------
#
# max_features: 5; max_depth: 7; n_estimators: 20;
#
# Normal feature space
# Coefficient of determination R^2: 0.3066776553351974
# Mean squared error:               0.03616004237483041
# Mean absolute error:              0.14232279868744283
# Root mean squared error:          0.19015794060419988
# Correlation Coefficient:          0.5581646262958296
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2575639312939564
# Mean squared error:               0.03872155558175816
# Mean absolute error:              0.14335050541026764
# Root mean squared error:          0.19677793469227733
# Correlation Coefficient:          0.508319050315467
# -------------------------------------------------------
#
# max_features: 5; max_depth: 7; n_estimators: 30;
#
# Normal feature space
# Coefficient of determination R^2: 0.3285286326835226
# Mean squared error:               0.035020410466343604
# Mean absolute error:              0.1406896075118713
# Root mean squared error:          0.1871374106541597
# Correlation Coefficient:          0.5792112206736125
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3245763419913902
# Mean squared error:               0.035226541135584113
# Mean absolute error:              0.13780844326852007
# Root mean squared error:          0.1876873494287351
# Correlation Coefficient:          0.5733383731683527
# -------------------------------------------------------
#
# max_features: 5; max_depth: 7; n_estimators: 40;
#
# Normal feature space
# Coefficient of determination R^2: 0.32459709453891616
# Mean squared error:               0.03522545879199069
# Mean absolute error:              0.14102209804528823
# Root mean squared error:          0.1876844660380573
# Correlation Coefficient:          0.5760443813306715
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3082773188519542
# Mean squared error:               0.036076612349826155
# Mean absolute error:              0.13991878842275965
# Root mean squared error:          0.18993844358061418
# Correlation Coefficient:          0.5601266566456455
# -------------------------------------------------------
#
# max_features: 5; max_depth: 7; n_estimators: 50;
#
# Normal feature space
# Coefficient of determination R^2: 0.3481084924887585
# Mean squared error:               0.03399922808891299
# Mean absolute error:              0.13955555817823623
# Root mean squared error:          0.1843887959961586
# Correlation Coefficient:          0.6014200766884845
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3138924093102874
# Mean squared error:               0.035783758801293836
# Mean absolute error:              0.14226261633502862
# Root mean squared error:          0.18916595571427178
# Correlation Coefficient:          0.5681389836735947
# -------------------------------------------------------
#
# max_features: 5; max_depth: 7; n_estimators: 60;
#
# Normal feature space
# Coefficient of determination R^2: 0.3432581388183469
# Mean squared error:               0.03425219699378767
# Mean absolute error:              0.14051406906562228
# Root mean squared error:          0.18507349079159788
# Correlation Coefficient:          0.5971138431199
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3228348287486631
# Mean squared error:               0.03531736929529644
# Mean absolute error:              0.14196259527708183
# Root mean squared error:          0.18792916031126314
# Correlation Coefficient:          0.5782748701230379
# -------------------------------------------------------
#
# max_features: 5; max_depth: 7; n_estimators: 80;
#
# Normal feature space
# Coefficient of determination R^2: 0.3447525317311444
# Mean squared error:               0.03417425732911765
# Mean absolute error:              0.1388074872752854
# Root mean squared error:          0.1848628067760458
# Correlation Coefficient:          0.5988822254676746
#
#
# Extended feature space
# Coefficient of determination R^2: 0.31505959234827186
# Mean squared error:               0.035722884680565614
# Mean absolute error:              0.14226786312805323
# Root mean squared error:          0.1890049858616582
# Correlation Coefficient:          0.5696090653969292
# -------------------------------------------------------
#
# max_features: 5; max_depth: 7; n_estimators: 90;
#
# Normal feature space
# Coefficient of determination R^2: 0.3374607286374157
# Mean squared error:               0.03455455937893205
# Mean absolute error:              0.13895343282860617
# Root mean squared error:          0.1858885671011858
# Correlation Coefficient:          0.5910625065202881
#
#
# Extended feature space
# Coefficient of determination R^2: 0.31854130609378817
# Mean squared error:               0.03554129682674306
# Mean absolute error:              0.14224619571563893
# Root mean squared error:          0.1885239953606518
# Correlation Coefficient:          0.5735705524735959
# -------------------------------------------------------
#
# max_features: 5; max_depth: 7; n_estimators: 100;
#
# Normal feature space
# Coefficient of determination R^2: 0.33584248832361996
# Mean squared error:               0.0346389582718421
# Mean absolute error:              0.13910349674835756
# Root mean squared error:          0.1861154433996333
# Correlation Coefficient:          0.5892226079659411
#
#
# Extended feature space
# Coefficient of determination R^2: 0.32540416861645616
# Mean squared error:               0.03518336605826006
# Mean absolute error:              0.1412695209773661
# Root mean squared error:          0.187572295550969
# Correlation Coefficient:          0.5797755694269454
# -------------------------------------------------------
#
# max_features: 5; max_depth: 7; n_estimators: 120;
#
# Normal feature space
# Coefficient of determination R^2: 0.3302989148979112
# Mean squared error:               0.034928081868570444
# Mean absolute error:              0.13978413305589008
# Root mean squared error:          0.18689056120781072
# Correlation Coefficient:          0.5848221303166432
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3275979015474595
# Mean squared error:               0.035068952501053144
# Mean absolute error:              0.14097332813984498
# Root mean squared error:          0.18726706197581341
# Correlation Coefficient:          0.5820079537084094
# -------------------------------------------------------
#
# max_features: 5; max_depth: 7; n_estimators: 140;
#
# Normal feature space
# Coefficient of determination R^2: 0.3267925825702821
# Mean squared error:               0.03511095369799144
# Mean absolute error:              0.14061641607628675
# Root mean squared error:          0.18737917092887205
# Correlation Coefficient:          0.5829421590728283
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3333206835735677
# Mean squared error:               0.03477048232746305
# Mean absolute error:              0.14028815849065654
# Root mean squared error:          0.18646844861118744
# Correlation Coefficient:          0.5880049212710385
# -------------------------------------------------------
#
# max_features: 5; max_depth: 7; n_estimators: 160;
#
# Normal feature space
# Coefficient of determination R^2: 0.32898709702335416
# Mean squared error:               0.034996499380709006
# Mean absolute error:              0.140227041486852
# Root mean squared error:          0.1870735133061573
# Correlation Coefficient:          0.5861339137058974
#
#
# Extended feature space
# Coefficient of determination R^2: 0.33496133771806225
# Mean squared error:               0.034684914447177806
# Mean absolute error:              0.14027472947192554
# Root mean squared error:          0.18623886395480888
# Correlation Coefficient:          0.590165175770168
# -------------------------------------------------------
# max_features: 5; max_depth: 10; n_estimators: 10;
#
# Normal feature space
# Coefficient of determination R^2: 0.3267367457764613
# Mean squared error:               0.035113865851113535
# Mean absolute error:              0.1395438665988008
# Root mean squared error:          0.1873869415170479
# Correlation Coefficient:          0.5760720118548575
#
#
# Extended feature space
# Coefficient of determination R^2: 0.22189361946245167
# Mean squared error:               0.04058193120252979
# Mean absolute error:              0.1514597050403135
# Root mean squared error:          0.20144957483829493
# Correlation Coefficient:          0.47949852757380523
# -------------------------------------------------------
#
# max_features: 5; max_depth: 10; n_estimators: 20;
#
# Normal feature space
# Coefficient of determination R^2: 0.34291187277883184
# Mean squared error:               0.03427025640692815
# Mean absolute error:              0.139780413295142
# Root mean squared error:          0.18512227420526184
# Correlation Coefficient:          0.5957648789735435
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2856673162866964
# Mean squared error:               0.037255831016505675
# Mean absolute error:              0.1425694077800449
# Root mean squared error:          0.19301769612267594
# Correlation Coefficient:          0.5349241768814204
# -------------------------------------------------------
#
# max_features: 5; max_depth: 10; n_estimators: 30;
#
# Normal feature space
# Coefficient of determination R^2: 0.3500494175758725
# Mean squared error:               0.03389799965752536
# Mean absolute error:              0.13883104675650243
# Root mean squared error:          0.1841140941305835
# Correlation Coefficient:          0.6066481569192154
#
#
# Extended feature space
# Coefficient of determination R^2: 0.32680883893174373
# Mean squared error:               0.035110105851785645
# Mean absolute error:              0.13870052007824094
# Root mean squared error:          0.1873769085340711
# Correlation Coefficient:          0.5753527973959215
# -------------------------------------------------------
#
# max_features: 5; max_depth: 10; n_estimators: 40;
#
# Normal feature space
# Coefficient of determination R^2: 0.3521654597681978
# Mean squared error:               0.03378763804011866
# Mean absolute error:              0.1372454732129207
# Root mean squared error:          0.18381413993520374
# Correlation Coefficient:          0.6087662445216098
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3054469116097508
# Mean squared error:               0.03622423148629807
# Mean absolute error:              0.14175728097244583
# Root mean squared error:          0.19032664418388212
# Correlation Coefficient:          0.557677678574962
# -------------------------------------------------------
#
# max_features: 5; max_depth: 10; n_estimators: 50;
#
# Normal feature space
# Coefficient of determination R^2: 0.3677544083684334
# Mean squared error:               0.03297460057449925
# Mean absolute error:              0.13674612776449754
# Root mean squared error:          0.1815890981708408
# Correlation Coefficient:          0.6256192708624805
#
#
# Extended feature space
# Coefficient of determination R^2: 0.31166130869223696
# Mean squared error:               0.035900121260274184
# Mean absolute error:              0.1418023070354998
# Root mean squared error:          0.18947327320831872
# Correlation Coefficient:          0.5654781231172636
# -------------------------------------------------------
#
# max_features: 5; max_depth: 10; n_estimators: 60;
#
# Normal feature space
# Coefficient of determination R^2: 0.35827886323309244
# Mean squared error:               0.03346879510934322
# Mean absolute error:              0.13806882323955866
# Root mean squared error:          0.18294478705156705
# Correlation Coefficient:          0.6145014428654517
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3300891427311303
# Mean squared error:               0.034939022480103055
# Mean absolute error:              0.14056863559654761
# Root mean squared error:          0.18691982901795906
# Correlation Coefficient:          0.5856379205436344
# -------------------------------------------------------
#
# max_features: 5; max_depth: 10; n_estimators: 80;
#
# Normal feature space
# Coefficient of determination R^2: 0.3543614191477983
# Mean squared error:               0.03367310836307768
# Mean absolute error:              0.13685308448850816
# Root mean squared error:          0.18350233884906667
# Correlation Coefficient:          0.6094399968514329
#
#
# Extended feature space
# Coefficient of determination R^2: 0.33028770695886744
# Mean squared error:               0.03492866641564855
# Mean absolute error:              0.14004897764557148
# Root mean squared error:          0.1868921250766028
# Correlation Coefficient:          0.5849423690663033
# -------------------------------------------------------
#
# max_features: 5; max_depth: 10; n_estimators: 90;
#
# Normal feature space
# Coefficient of determination R^2: 0.34956936442222863
# Mean squared error:               0.03392303670199899
# Mean absolute error:              0.13654220520029675
# Root mean squared error:          0.18418207486614704
# Correlation Coefficient:          0.6045163288651852
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3437365103288461
# Mean squared error:               0.03422724765496472
# Mean absolute error:              0.13849073453020008
# Root mean squared error:          0.18500607464341465
# Correlation Coefficient:          0.6002368488720997
# -------------------------------------------------------
#
# max_features: 5; max_depth: 10; n_estimators: 100;
#
# Normal feature space
# Coefficient of determination R^2: 0.34560830238347606
# Mean squared error:               0.034129624838488186
# Mean absolute error:              0.1368489510051074
# Root mean squared error:          0.18474204945947792
# Correlation Coefficient:          0.6002629201351078
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3504599003960748
# Mean squared error:               0.033876591035277896
# Mean absolute error:              0.137678988695955
# Root mean squared error:          0.18405594539508333
# Correlation Coefficient:          0.6061293681532368
# -------------------------------------------------------
#
# max_features: 5; max_depth: 10; n_estimators: 120;
#
# Normal feature space
# Coefficient of determination R^2: 0.3375137471540345
# Mean squared error:               0.03455179421230741
# Mean absolute error:              0.1377263580123881
# Root mean squared error:          0.18588112925283032
# Correlation Coefficient:          0.59257829476756
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3505357402145922
# Mean squared error:               0.033872635629726075
# Mean absolute error:              0.138310744274371
# Root mean squared error:          0.18404519996382973
# Correlation Coefficient:          0.6063321484383954
# -------------------------------------------------------
#
# max_features: 5; max_depth: 10; n_estimators: 140;
#
# Normal feature space
# Coefficient of determination R^2: 0.32861088015405837
# Mean squared error:               0.03501612087140601
# Mean absolute error:              0.13891248875016635
# Root mean squared error:          0.1871259492197862
# Correlation Coefficient:          0.5848837985563681
#
#
# Extended feature space
# Coefficient of determination R^2: 0.35197910325042814
# Mean squared error:               0.03379735741470861
# Mean absolute error:              0.13756724580173824
# Root mean squared error:          0.18384057608348764
# Correlation Coefficient:          0.6077565326119211
# -------------------------------------------------------
#
# max_features: 5; max_depth: 10; n_estimators: 160;
#
# Normal feature space
# Coefficient of determination R^2: 0.331480450129525
# Mean squared error:               0.03486645921300297
# Mean absolute error:              0.13890789746171853
# Root mean squared error:          0.18672562548563862
# Correlation Coefficient:          0.5885209859681335
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3491584033955706
# Mean squared error:               0.033944470264976885
# Mean absolute error:              0.13766743396874764
# Root mean squared error:          0.1842402514788147
# Correlation Coefficient:          0.6048690496811163
# -------------------------------------------------------
# max_features: 5; max_depth: 12; n_estimators: 10;
#
# Normal feature space
# Coefficient of determination R^2: 0.35790974916665963
# Mean squared error:               0.03348804615524714
# Mean absolute error:              0.13723840108441915
# Root mean squared error:          0.18299739384823802
# Correlation Coefficient:          0.605711082428622
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2312583574402518
# Mean squared error:               0.0400935157854987
# Mean absolute error:              0.15147135272135276
# Root mean squared error:          0.20023365297945972
# Correlation Coefficient:          0.4889586309851751
# -------------------------------------------------------
#
# max_features: 5; max_depth: 12; n_estimators: 20;
#
# Normal feature space
# Coefficient of determination R^2: 0.3710582829561565
# Mean squared error:               0.032802287874623776
# Mean absolute error:              0.13834113828810568
# Root mean squared error:          0.18111401898976173
# Correlation Coefficient:          0.6199337886783736
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2935409902289038
# Mean squared error:               0.03684518164743988
# Mean absolute error:              0.14122654920696587
# Root mean squared error:          0.19195098761777674
# Correlation Coefficient:          0.5418575803292164
# -------------------------------------------------------
#
# max_features: 5; max_depth: 12; n_estimators: 30;
#
# Normal feature space
# Coefficient of determination R^2: 0.368083046567513
# Mean squared error:               0.03295746053668546
# Mean absolute error:              0.13726384834127106
# Root mean squared error:          0.1815418974691117
# Correlation Coefficient:          0.616782249554429
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3382659773015285
# Mean squared error:               0.03451256184915292
# Mean absolute error:              0.13693420848619564
# Root mean squared error:          0.1857755684936879
# Correlation Coefficient:          0.5857870266559904
# -------------------------------------------------------
#
# max_features: 5; max_depth: 12; n_estimators: 40;
#
# Normal feature space
# Coefficient of determination R^2: 0.3694562062762802
# Mean squared error:               0.032885843757508325
# Mean absolute error:              0.1358282221314975
# Root mean squared error:          0.18134454432794037
# Correlation Coefficient:          0.62086867213016
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3238882464518198
# Mean squared error:               0.03526242857533023
# Mean absolute error:              0.13778651739404943
# Root mean squared error:          0.1877829294034211
# Correlation Coefficient:          0.5740775653748249
# -------------------------------------------------------
#
# max_features: 5; max_depth: 12; n_estimators: 50;
#
# Normal feature space
# Coefficient of determination R^2: 0.37742944149009305
# Mean squared error:               0.0324700017968178
# Mean absolute error:              0.13659460068838758
# Root mean squared error:          0.18019434451951535
# Correlation Coefficient:          0.6308029274829317
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3310399186878298
# Mean squared error:               0.03488943501310768
# Mean absolute error:              0.13825429191843291
# Root mean squared error:          0.18678713824326257
# Correlation Coefficient:          0.5833943564884924
# -------------------------------------------------------
#
# max_features: 5; max_depth: 12; n_estimators: 60;
#
# Normal feature space
# Coefficient of determination R^2: 0.37339391233791996
# Mean squared error:               0.032680473745789806
# Mean absolute error:              0.13571542241535667
# Root mean squared error:          0.18077741492174793
# Correlation Coefficient:          0.6262994403902384
#
#
# Extended feature space
# Coefficient of determination R^2: 0.34454042408960917
# Mean squared error:               0.03418531974671454
# Mean absolute error:              0.13832092092103843
# Root mean squared error:          0.1848927249696822
# Correlation Coefficient:          0.598703142578964
# -------------------------------------------------------
#
# max_features: 5; max_depth: 12; n_estimators: 80;
#
# Normal feature space
# Coefficient of determination R^2: 0.3635575022854406
# Mean squared error:               0.03319348909435156
# Mean absolute error:              0.1363414555077118
# Root mean squared error:          0.18219080408832813
# Correlation Coefficient:          0.6171710646345118
#
#
# Extended feature space
# Coefficient of determination R^2: 0.34621111678609096
# Mean squared error:               0.03409818521374445
# Mean absolute error:              0.13798137398125374
# Root mean squared error:          0.18465693925153326
# Correlation Coefficient:          0.601347590864344
# -------------------------------------------------------
#
# max_features: 5; max_depth: 12; n_estimators: 90;
#
# Normal feature space
# Coefficient of determination R^2: 0.3563369168165037
# Mean squared error:               0.03357007680789781
# Mean absolute error:              0.13681299356765017
# Root mean squared error:          0.18322138741942168
# Correlation Coefficient:          0.6096033247911453
#
#
# Extended feature space
# Coefficient of determination R^2: 0.35453790685974207
# Mean squared error:               0.033663903693429226
# Mean absolute error:              0.13715442980057288
# Root mean squared error:          0.18347725661081055
# Correlation Coefficient:          0.6122563333821052
# -------------------------------------------------------
#
# max_features: 5; max_depth: 12; n_estimators: 100;
#
# Normal feature space
# Coefficient of determination R^2: 0.3475362561514257
# Mean squared error:               0.034029072922799566
# Mean absolute error:              0.13745091417465416
# Root mean squared error:          0.18446970733104004
# Correlation Coefficient:          0.6008089935605555
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3538980456526011
# Mean squared error:               0.03369727548440391
# Mean absolute error:              0.13712156458226005
# Root mean squared error:          0.18356817666579334
# Correlation Coefficient:          0.6095763041058326
# -------------------------------------------------------
#
# max_features: 5; max_depth: 12; n_estimators: 120;
#
# Normal feature space
# Coefficient of determination R^2: 0.33935634017232963
# Mean squared error:               0.034455694263800296
# Mean absolute error:              0.1384114581719639
# Root mean squared error:          0.18562245086142004
# Correlation Coefficient:          0.5937564745265933
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3577033323913442
# Mean squared error:               0.03349881176723083
# Mean absolute error:              0.13724786046208853
# Root mean squared error:          0.18302680614388384
# Correlation Coefficient:          0.6135210114539007
# -------------------------------------------------------
#
# max_features: 5; max_depth: 12; n_estimators: 140;
#
# Normal feature space
# Coefficient of determination R^2: 0.331883825601468
# Mean squared error:               0.034845421272612524
# Mean absolute error:              0.13957824180052053
# Root mean squared error:          0.18666928315235082
# Correlation Coefficient:          0.5878606249768147
#
#
# Extended feature space
# Coefficient of determination R^2: 0.35551904304486026
# Mean squared error:               0.03361273279680032
# Mean absolute error:              0.13721302487034398
# Root mean squared error:          0.18333775605913888
# Correlation Coefficient:          0.6115714306189413
# -------------------------------------------------------
#
# max_features: 5; max_depth: 12; n_estimators: 160;
#
# Normal feature space
# Coefficient of determination R^2: 0.3379572920520053
# Mean squared error:               0.03452866124619261
# Mean absolute error:              0.1392498313966471
# Root mean squared error:          0.18581889367390123
# Correlation Coefficient:          0.5946276560684481
#
#
# Extended feature space
# Coefficient of determination R^2: 0.35090783861871155
# Mean squared error:               0.03385322893648432
# Mean absolute error:              0.13747892493737104
# Root mean squared error:          0.18399246978201125
# Correlation Coefficient:          0.6070661249484269
# -------------------------------------------------------
# max_features: 5; max_depth: 15; n_estimators: 10;
#
# Normal feature space
# Coefficient of determination R^2: 0.36719779719265655
# Mean squared error:               0.03300363048224315
# Mean absolute error:              0.13954735449735448
# Root mean squared error:          0.18166901354453144
# Correlation Coefficient:          0.616020678895211
#
#
# Extended feature space
# Coefficient of determination R^2: 0.22322443271604064
# Mean squared error:               0.04051252299145298
# Mean absolute error:              0.14875641025641023
# Root mean squared error:          0.20127722919260632
# Correlation Coefficient:          0.479736316208694
# -------------------------------------------------------
#
# max_features: 5; max_depth: 15; n_estimators: 20;
#
# Normal feature space
# Coefficient of determination R^2: 0.37210292646074283
# Mean squared error:               0.03274780477064897
# Mean absolute error:              0.13765877696377699
# Root mean squared error:          0.1809635454190953
# Correlation Coefficient:          0.6205588171932633
#
#
# Extended feature space
# Coefficient of determination R^2: 0.28978716954325023
# Mean squared error:               0.03704096116631053
# Mean absolute error:              0.14072856125356126
# Root mean squared error:          0.1924602846467565
# Correlation Coefficient:          0.5389768236240458
# -------------------------------------------------------
#
# max_features: 5; max_depth: 15; n_estimators: 30;
#
# Normal feature space
# Coefficient of determination R^2: 0.380965046922095
# Mean squared error:               0.03228560323642858
# Mean absolute error:              0.13597637633970966
# Root mean squared error:          0.17968195022435776
# Correlation Coefficient:          0.6307628830443451
#
#
# Extended feature space
# Coefficient of determination R^2: 0.33737035105495905
# Mean squared error:               0.03455927299769324
# Mean absolute error:              0.13613431013431015
# Root mean squared error:          0.1859012452827932
# Correlation Coefficient:          0.5852079055322522
# -------------------------------------------------------
#
# max_features: 5; max_depth: 15; n_estimators: 40;
#
# Normal feature space
# Coefficient of determination R^2: 0.3657095712397107
# Mean squared error:               0.033081248510763286
# Mean absolute error:              0.13599512650929318
# Root mean squared error:          0.18188251293283608
# Correlation Coefficient:          0.6169666145499084
#
#
# Extended feature space
# Coefficient of determination R^2: 0.31655410004537987
# Mean squared error:               0.035644939029350425
# Mean absolute error:              0.13905891839641843
# Root mean squared error:          0.18879867327221986
# Correlation Coefficient:          0.5663776659313198
# -------------------------------------------------------
#
# max_features: 5; max_depth: 15; n_estimators: 50;
#
# Normal feature space
# Coefficient of determination R^2: 0.3773531079985195
# Mean squared error:               0.03247398294975649
# Mean absolute error:              0.13597020377153704
# Root mean squared error:          0.1802053910119131
# Correlation Coefficient:          0.6308552614310271
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3260879214145358
# Mean squared error:               0.035147705113040675
# Mean absolute error:              0.13931935693935693
# Root mean squared error:          0.18747721225002434
# Correlation Coefficient:          0.5774052672992174
# -------------------------------------------------------
#
# max_features: 5; max_depth: 15; n_estimators: 60;
#
# Normal feature space
# Coefficient of determination R^2: 0.3663600017133556
# Mean squared error:               0.033047325482506856
# Mean absolute error:              0.13652551575996014
# Root mean squared error:          0.18178923368149957
# Correlation Coefficient:          0.6190764296769383
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3380369443733354
# Mean squared error:               0.0345245070005712
# Mean absolute error:              0.1389309455976122
# Root mean squared error:          0.18580771512660932
# Correlation Coefficient:          0.590875404513275
# -------------------------------------------------------
#
# max_features: 5; max_depth: 15; n_estimators: 80;
#
# Normal feature space
# Coefficient of determination R^2: 0.3610651488547011
# Mean squared error:               0.03332347712425151
# Mean absolute error:              0.1366829728835978
# Root mean squared error:          0.1825471914992162
# Correlation Coefficient:          0.6154914741906077
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3341071982692885
# Mean squared error:               0.03472946186281981
# Mean absolute error:              0.13938426689051683
# Root mean squared error:          0.18635842310671072
# Correlation Coefficient:          0.5875277822524757
# -------------------------------------------------------
#
# max_features: 5; max_depth: 15; n_estimators: 90;
#
# Normal feature space
# Coefficient of determination R^2: 0.3549341572308997
# Mean squared error:               0.03364323736077406
# Mean absolute error:              0.13715407181296066
# Root mean squared error:          0.18342092945128716
# Correlation Coefficient:          0.6089261077349905
#
#
# Extended feature space
# Coefficient of determination R^2: 0.33910891038783497
# Mean squared error:               0.034468598898363095
# Mean absolute error:              0.13889541898430782
# Root mean squared error:          0.18565720804311125
# Correlation Coefficient:          0.5946577081724942
# -------------------------------------------------------
#
# max_features: 5; max_depth: 15; n_estimators: 100;
#
# Normal feature space
# Coefficient of determination R^2: 0.34750997192791877
# Mean squared error:               0.03403044376948165
# Mean absolute error:              0.13770088970288963
# Root mean squared error:          0.18447342293534225
# Correlation Coefficient:          0.6017020178731501
#
#
# Extended feature space
# Coefficient of determination R^2: 0.34592797809504205
# Mean squared error:               0.03411295223682551
# Mean absolute error:              0.13820198819698812
# Root mean squared error:          0.18469691994406814
# Correlation Coefficient:          0.6004522718735884
# -------------------------------------------------------
#
# max_features: 5; max_depth: 15; n_estimators: 120;
#
# Normal feature space
# Coefficient of determination R^2: 0.33863345058496297
# Mean squared error:               0.03449339637784963
# Mean absolute error:              0.13873838149504808
# Root mean squared error:          0.18572397900607673
# Correlation Coefficient:          0.5934364298043723
#
#
# Extended feature space
# Coefficient of determination R^2: 0.35028267024669735
# Mean squared error:               0.03388583442655311
# Mean absolute error:              0.1379072215177984
# Root mean squared error:          0.1840810539587198
# Correlation Coefficient:          0.605206684567253
# -------------------------------------------------------
#
# max_features: 5; max_depth: 15; n_estimators: 140;
#
# Normal feature space
# Coefficient of determination R^2: 0.3313542176303099
# Mean squared error:               0.03487304283540577
# Mean absolute error:              0.1397866905052619
# Root mean squared error:          0.18674325378820456
# Correlation Coefficient:          0.5877723868831962
#
#
# Extended feature space
# Coefficient of determination R^2: 0.347699451646141
# Mean squared error:               0.034020561505203266
# Mean absolute error:              0.13773807835428714
# Root mean squared error:          0.18444663592812763
# Correlation Coefficient:          0.6026625594590038
# -------------------------------------------------------
#
# max_features: 5; max_depth: 15; n_estimators: 160;
#
# Normal feature space
# Coefficient of determination R^2: 0.33773305336951354
# Mean squared error:               0.0345403563550022
# Mean absolute error:              0.1395017965367965
# Root mean squared error:          0.18585036011534173
# Correlation Coefficient:          0.5953688404780133
#
#
# Extended feature space
# Coefficient of determination R^2: 0.34324380688065315
# Mean squared error:               0.03425294447218399
# Mean absolute error:              0.13832964786637866
# Root mean squared error:          0.18507551019025717
# Correlation Coefficient:          0.598546945025581
# -------------------------------------------------------
# max_features: 5; max_depth: 18; n_estimators: 10;
#
# Normal feature space
# Coefficient of determination R^2: 0.36759747346267657
# Mean squared error:               0.03298278547274453
# Mean absolute error:              0.13975595441595437
# Root mean squared error:          0.1816116336382241
# Correlation Coefficient:          0.615532141381733
#
#
# Extended feature space
# Coefficient of determination R^2: 0.216045883975855
# Mean squared error:               0.040886918290598276
# Mean absolute error:              0.14949059829059827
# Root mean squared error:          0.20220513913003862
# Correlation Coefficient:          0.4737444390807839
# -------------------------------------------------------
#
# max_features: 5; max_depth: 18; n_estimators: 20;
#
# Normal feature space
# Coefficient of determination R^2: 0.37465533009679985
# Mean squared error:               0.032614684838271596
# Mean absolute error:              0.1373577492877493
# Root mean squared error:          0.1805953621726527
# Correlation Coefficient:          0.6226705279863499
#
#
# Extended feature space
# Coefficient of determination R^2: 0.28507285800638393
# Mean squared error:               0.03728683482991452
# Mean absolute error:              0.141278547008547
# Root mean squared error:          0.1930979928168973
# Correlation Coefficient:          0.5345357391494167
# -------------------------------------------------------
#
# max_features: 5; max_depth: 18; n_estimators: 30;
#
# Normal feature space
# Coefficient of determination R^2: 0.3738870471741902
# Mean squared error:               0.03265475442964018
# Mean absolute error:              0.13656838556505224
# Root mean squared error:          0.1807062656070347
# Correlation Coefficient:          0.6230695116163883
#
#
# Extended feature space
# Coefficient of determination R^2: 0.33462370321004276
# Mean squared error:               0.03470252368509021
# Mean absolute error:              0.13657715099715104
# Root mean squared error:          0.18628613390451318
# Correlation Coefficient:          0.5825534556495434
# -------------------------------------------------------
#
# max_features: 5; max_depth: 18; n_estimators: 40;
#
# Normal feature space
# Coefficient of determination R^2: 0.3566464880109669
# Mean squared error:               0.033553931204635554
# Mean absolute error:              0.1366517165242165
# Root mean squared error:          0.18317732175309134
# Correlation Coefficient:          0.6070448873063891
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3136366508360634
# Mean squared error:               0.03579709781645299
# Mean absolute error:              0.13912901709401712
# Root mean squared error:          0.18920120987047886
# Correlation Coefficient:          0.5637328747030924
# -------------------------------------------------------
#
# max_features: 5; max_depth: 18; n_estimators: 50;
#
# Normal feature space
# Coefficient of determination R^2: 0.369296845988458
# Mean squared error:               0.03289415515090976
# Mean absolute error:              0.1365488945868945
# Root mean squared error:          0.18136745890845402
# Correlation Coefficient:          0.6216508330121778
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3242592029666238
# Mean squared error:               0.03524308143702184
# Mean absolute error:              0.1393282279202279
# Root mean squared error:          0.18773140769999525
# Correlation Coefficient:          0.575684226919421
# -------------------------------------------------------
#
# max_features: 5; max_depth: 18; n_estimators: 60;
#
# Normal feature space
# Coefficient of determination R^2: 0.3612395448975412
# Mean squared error:               0.033314381545048524
# Mean absolute error:              0.13668818138651462
# Root mean squared error:          0.1825222768460018
# Correlation Coefficient:          0.6126837660288612
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3368915268171063
# Mean squared error:               0.03458424594839083
# Mean absolute error:              0.13892751187084515
# Root mean squared error:          0.1859684004028395
# Correlation Coefficient:          0.5898307779888007
# -------------------------------------------------------
#
# max_features: 5; max_depth: 18; n_estimators: 80;
#
# Normal feature space
# Coefficient of determination R^2: 0.3583115069838435
# Mean squared error:               0.03346709258321016
# Mean absolute error:              0.13664280982905974
# Root mean squared error:          0.1829401338777529
# Correlation Coefficient:          0.6118775864935732
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3350901490255004
# Mean squared error:               0.034678196327718416
# Mean absolute error:              0.13912629629629622
# Root mean squared error:          0.18622082678293106
# Correlation Coefficient:          0.5886097317343477
# -------------------------------------------------------
#
# max_features: 5; max_depth: 18; n_estimators: 90;
#
# Normal feature space
# Coefficient of determination R^2: 0.35376226973528846
# Mean squared error:               0.033704356841237834
# Mean absolute error:              0.13680111111111104
# Root mean squared error:          0.18358746373660112
# Correlation Coefficient:          0.6073996293628434
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3397883674267034
# Mean squared error:               0.03443316199732215
# Mean absolute error:              0.13880836973725855
# Root mean squared error:          0.18556174712834042
# Correlation Coefficient:          0.5952627878267066
# -------------------------------------------------------
#
# max_features: 5; max_depth: 18; n_estimators: 100;
#
# Normal feature space
# Coefficient of determination R^2: 0.3469746140343005
# Mean squared error:               0.03405836521795061
# Mean absolute error:              0.1375226381766381
# Root mean squared error:          0.18454908620188454
# Correlation Coefficient:          0.6011160445822059
#
#
# Extended feature space
# Coefficient of determination R^2: 0.34625591072842177
# Mean squared error:               0.03409584899760302
# Mean absolute error:              0.13821633618233609
# Root mean squared error:          0.18465061331499286
# Correlation Coefficient:          0.6007484833623717
# -------------------------------------------------------
#
# max_features: 5; max_depth: 18; n_estimators: 120;
#
# Normal feature space
# Coefficient of determination R^2: 0.3406352356167477
# Mean squared error:               0.034388993812244105
# Mean absolute error:              0.13821131528964858
# Root mean squared error:          0.18544269684256673
# Correlation Coefficient:          0.5954623103559209
#
#
# Extended feature space
# Coefficient of determination R^2: 0.35167895949555694
# Mean squared error:               0.03381301133236783
# Mean absolute error:              0.13774412155745486
# Root mean squared error:          0.18388314586271312
# Correlation Coefficient:          0.6069804415306082
# -------------------------------------------------------

# %%
get_best_settings(results_1_full,results_2_full)

# %% [markdown]
# Normal best: 0.6606799891294596 | max_features: 50; max_depth: 12; n_estimators: 20;
#
# Extended best: 0.643178381615747 | max_features: 20; max_depth: 7; n_estimators: 100;
#
# Best difference: 0.0855855290853309 | max_features: 12; max_depth: 12; n_estimators: 10;

# %%
best_RFs(results_1_full,results_2_full,'full')
# Out:
# Normal best: 0.0 | max_features: 5; max_depth: 5; n_estimators: 10;
# Extended best: 0.0 | max_features: 5; max_depth: 5; n_estimators: 10;
# Best difference: 0.0 | max_features: 5; max_depth: 5; n_estimators: 10;
# Normal feature space
# Coefficient of determination R^2: 0.32593903458010076
# Mean squared error:               0.03515547026626796
# Mean absolute error:              0.14173351167018933
# Root mean squared error:          0.1874979206985186
# Correlation Coefficient:          0.573707468406997
#
#
# Extended feature space
# Coefficient of determination R^2: 0.20641257829135895
# Mean squared error:               0.041389340784899226
# Mean absolute error:              0.1499463155600729
# Root mean squared error:          0.20344370421543947
# Correlation Coefficient:          0.4705488246690762
# -------------------------------------------------------

# %% [markdown]
# ## MAE Results
#
# Normal best: 0.6485849616979102 | max_features: 50; max_depth: 7; n_estimators: 10;
#
# Extended best: 0.6406053037479402 | max_features: 5; max_depth: 20; n_estimators: 50;
#
# Best difference: 0.10009093774816558 | max_features: 20; max_depth: 5; n_estimators: 10;
#
# Normal feature space
# Coefficient of determination R^2: 0.41756892464489404
# Mean squared error:               0.03037653773504273
# Mean absolute error:              0.1291034188034188
# Root mean squared error:          0.1742886620955096
# Correlation Coefficient:          0.6485849616979102
#
#
# Extended feature space
# Coefficient of determination R^2: 0.38691168381575647
# Mean squared error:               0.03197545797179487
# Mean absolute error:              0.13664094017094014
# Root mean squared error:          0.1788168279882933
# Correlation Coefficient:          0.6406053037479402

# %% [markdown]
# # RP Genes

# %%
X,y,X2,y2 = get_data('rp')

mxf = [5,7,10,12,15,18,20,25,30,50,80,10]
md = [5,7,10,12,15,18,20]
n_est = [10,20,30,40,50,60,80,90,100,120,140,160]

results_1_rp = np.zeros((len(mxf),len(md),len(n_est)))
results_2_rp = np.zeros((len(mxf),len(md),len(n_est)))

f = FloatProgress(min=0, max=(len(mxf)*len(md)*len(n_est)))
display(f)


i = 0
for max_features in mxf:
    j = 0
    for max_depth in md:
        k = 0
        for n_estimators in n_est:            
            
            kf = KFold(n_splits=5,shuffle=True,random_state=0)

            rfr1 = ExtraTreesRegressor(n_estimators=n_estimators, 
                                        criterion='mse', 
                                        max_features=max_features, 
                                        max_depth=max_depth, 
                                        n_jobs=2,
                                        random_state=1337)

            rfr2 = ExtraTreesRegressor(n_estimators=n_estimators, 
                                        criterion='mse', 
                                        max_features=max_features, 
                                        max_depth=max_depth, 
                                        n_jobs=2,
                                        random_state=1337)

            predictions_rfr1 = cross_val_predict(rfr1,X=X,y=y,cv=kf)
            predictions_rfr2 = cross_val_predict(rfr2,X=X2,y=y2,cv=kf)
            
            print('max_features: {}; max_depth: {}; n_estimators: {};\n'.format(max_features,max_depth,n_estimators))

            print('Normal feature space')
            print_stats(y, predictions_rfr1)
            print('\n')
            print('Extended feature space')
            print_stats(y2, predictions_rfr2)
            print('-------------------------------------------------------\n')
            

            results_1_rp[i][j][k]=np.corrcoef(y, predictions_rfr1)[0][1]
            results_2_rp[i][j][k]=np.corrcoef(y2, predictions_rfr2)[0][1]
            
            f.value += 1
            
            k += 1
        j += 1
    i += 1
# Out:
# FloatProgress(value=0.0, max=1008.0)
# max_features: 5; max_depth: 5; n_estimators: 10;
#
# max_features: 5; max_depth: 5; n_estimators: 20;
#
# max_features: 5; max_depth: 5; n_estimators: 30;
#
# max_features: 5; max_depth: 5; n_estimators: 40;
#
# max_features: 5; max_depth: 5; n_estimators: 50;
#
# max_features: 5; max_depth: 5; n_estimators: 60;
#
# max_features: 5; max_depth: 5; n_estimators: 80;
#
# max_features: 5; max_depth: 5; n_estimators: 90;
#
# max_features: 5; max_depth: 5; n_estimators: 100;
#
# max_features: 5; max_depth: 5; n_estimators: 120;
#
# max_features: 5; max_depth: 5; n_estimators: 140;
#
# max_features: 5; max_depth: 5; n_estimators: 160;
#
# max_features: 5; max_depth: 7; n_estimators: 10;
#
# max_features: 5; max_depth: 7; n_estimators: 20;
#
# max_features: 5; max_depth: 7; n_estimators: 30;
#
# max_features: 5; max_depth: 7; n_estimators: 40;
#
# max_features: 5; max_depth: 7; n_estimators: 50;
#
# max_features: 5; max_depth: 7; n_estimators: 60;
#
# max_features: 5; max_depth: 7; n_estimators: 80;
#
# max_features: 5; max_depth: 7; n_estimators: 90;
#
# max_features: 5; max_depth: 7; n_estimators: 100;
#
# max_features: 5; max_depth: 7; n_estimators: 120;
#
# max_features: 5; max_depth: 7; n_estimators: 140;
#
# max_features: 5; max_depth: 7; n_estimators: 160;
#
# max_features: 5; max_depth: 10; n_estimators: 10;
#
# max_features: 5; max_depth: 10; n_estimators: 20;
#
# max_features: 5; max_depth: 10; n_estimators: 30;
#
# max_features: 5; max_depth: 10; n_estimators: 40;
#
# max_features: 5; max_depth: 10; n_estimators: 50;
#
# max_features: 5; max_depth: 10; n_estimators: 60;
#
# max_features: 5; max_depth: 10; n_estimators: 80;
#
# max_features: 5; max_depth: 10; n_estimators: 90;
#
# max_features: 5; max_depth: 10; n_estimators: 100;
#
# max_features: 5; max_depth: 10; n_estimators: 120;
#
# max_features: 5; max_depth: 10; n_estimators: 140;
#
# max_features: 5; max_depth: 10; n_estimators: 160;
#
# max_features: 5; max_depth: 12; n_estimators: 10;
#
# max_features: 5; max_depth: 12; n_estimators: 20;
#
# max_features: 5; max_depth: 12; n_estimators: 30;
#
# max_features: 5; max_depth: 12; n_estimators: 40;
#
# max_features: 5; max_depth: 12; n_estimators: 50;
#
# max_features: 5; max_depth: 12; n_estimators: 60;
#
# max_features: 5; max_depth: 12; n_estimators: 80;
#
# max_features: 5; max_depth: 12; n_estimators: 90;
#
# max_features: 5; max_depth: 12; n_estimators: 100;
#
# max_features: 5; max_depth: 12; n_estimators: 120;
#
# max_features: 5; max_depth: 12; n_estimators: 140;
#
# max_features: 5; max_depth: 12; n_estimators: 160;
#
# max_features: 5; max_depth: 15; n_estimators: 10;
#
# max_features: 5; max_depth: 15; n_estimators: 20;
#
# max_features: 5; max_depth: 15; n_estimators: 30;
#
# max_features: 5; max_depth: 15; n_estimators: 40;
#
# max_features: 5; max_depth: 15; n_estimators: 50;
#
# max_features: 5; max_depth: 15; n_estimators: 60;
#
# max_features: 5; max_depth: 15; n_estimators: 80;
#
# max_features: 5; max_depth: 15; n_estimators: 90;
#
# max_features: 5; max_depth: 15; n_estimators: 100;
#
# max_features: 5; max_depth: 15; n_estimators: 120;
#
# max_features: 5; max_depth: 15; n_estimators: 140;
#
# max_features: 5; max_depth: 15; n_estimators: 160;
#
# max_features: 5; max_depth: 18; n_estimators: 10;
#
# max_features: 5; max_depth: 18; n_estimators: 20;
#
# max_features: 5; max_depth: 18; n_estimators: 30;
#
# max_features: 5; max_depth: 18; n_estimators: 40;
#
# max_features: 5; max_depth: 18; n_estimators: 50;
#
# max_features: 5; max_depth: 18; n_estimators: 60;
#
# max_features: 5; max_depth: 18; n_estimators: 80;
#
# max_features: 5; max_depth: 18; n_estimators: 90;
#
# max_features: 5; max_depth: 18; n_estimators: 100;
#
# max_features: 5; max_depth: 18; n_estimators: 120;
#
# max_features: 5; max_depth: 18; n_estimators: 140;
#
# max_features: 5; max_depth: 18; n_estimators: 160;
#
# max_features: 5; max_depth: 20; n_estimators: 10;
#
# max_features: 5; max_depth: 20; n_estimators: 20;
#
# max_features: 5; max_depth: 20; n_estimators: 30;
#
# max_features: 5; max_depth: 20; n_estimators: 40;
#
# max_features: 5; max_depth: 20; n_estimators: 50;
#
# max_features: 5; max_depth: 20; n_estimators: 60;
#
# max_features: 5; max_depth: 20; n_estimators: 80;
#
# max_features: 5; max_depth: 20; n_estimators: 90;
#
# max_features: 5; max_depth: 20; n_estimators: 100;
#
# max_features: 5; max_depth: 20; n_estimators: 120;
#
# max_features: 5; max_depth: 20; n_estimators: 140;
#
# max_features: 5; max_depth: 20; n_estimators: 160;
#
# max_features: 7; max_depth: 5; n_estimators: 10;
#
# max_features: 7; max_depth: 5; n_estimators: 20;
#
# max_features: 7; max_depth: 5; n_estimators: 30;
#
# max_features: 7; max_depth: 5; n_estimators: 40;
#
# max_features: 7; max_depth: 5; n_estimators: 50;
#
# max_features: 7; max_depth: 5; n_estimators: 60;
#
# max_features: 7; max_depth: 5; n_estimators: 80;
#
# max_features: 7; max_depth: 5; n_estimators: 90;
#
# max_features: 7; max_depth: 5; n_estimators: 100;
#
# max_features: 7; max_depth: 5; n_estimators: 120;
#
# max_features: 7; max_depth: 5; n_estimators: 140;
#
# max_features: 7; max_depth: 5; n_estimators: 160;
#
# max_features: 7; max_depth: 7; n_estimators: 10;
#
# max_features: 7; max_depth: 7; n_estimators: 20;
#
# max_features: 7; max_depth: 7; n_estimators: 30;
#
# max_features: 7; max_depth: 7; n_estimators: 40;
#
# max_features: 7; max_depth: 7; n_estimators: 50;
#
# max_features: 7; max_depth: 7; n_estimators: 60;
#
# max_features: 7; max_depth: 7; n_estimators: 80;
#
# max_features: 7; max_depth: 7; n_estimators: 90;
#
# max_features: 7; max_depth: 7; n_estimators: 100;
#
# max_features: 7; max_depth: 7; n_estimators: 120;
#
# max_features: 7; max_depth: 7; n_estimators: 140;
#
# max_features: 7; max_depth: 7; n_estimators: 160;
#
# max_features: 7; max_depth: 10; n_estimators: 10;
#
# max_features: 7; max_depth: 10; n_estimators: 20;
#
# max_features: 7; max_depth: 10; n_estimators: 30;
#
# max_features: 7; max_depth: 10; n_estimators: 40;
#
# max_features: 7; max_depth: 10; n_estimators: 50;
#
# max_features: 7; max_depth: 10; n_estimators: 60;
#
# max_features: 7; max_depth: 10; n_estimators: 80;
#
# max_features: 7; max_depth: 10; n_estimators: 90;
#
# max_features: 7; max_depth: 10; n_estimators: 100;
#
# max_features: 7; max_depth: 10; n_estimators: 120;
#
# max_features: 7; max_depth: 10; n_estimators: 140;
#
# max_features: 7; max_depth: 10; n_estimators: 160;
#
# max_features: 7; max_depth: 12; n_estimators: 10;
#
# max_features: 7; max_depth: 12; n_estimators: 20;
#
# max_features: 7; max_depth: 12; n_estimators: 30;
#
# max_features: 7; max_depth: 12; n_estimators: 40;
#
# max_features: 7; max_depth: 12; n_estimators: 50;
#
# max_features: 7; max_depth: 12; n_estimators: 60;
#
# max_features: 7; max_depth: 12; n_estimators: 80;
#
# max_features: 7; max_depth: 12; n_estimators: 90;
#
# max_features: 7; max_depth: 12; n_estimators: 100;
#
# max_features: 7; max_depth: 12; n_estimators: 120;
#
# max_features: 7; max_depth: 12; n_estimators: 140;
#
# max_features: 7; max_depth: 12; n_estimators: 160;
#
# max_features: 7; max_depth: 15; n_estimators: 10;
#
# max_features: 7; max_depth: 15; n_estimators: 20;
#
# max_features: 7; max_depth: 15; n_estimators: 30;
#
# max_features: 7; max_depth: 15; n_estimators: 40;
#
# max_features: 7; max_depth: 15; n_estimators: 50;
#
# max_features: 7; max_depth: 15; n_estimators: 60;
#
# max_features: 7; max_depth: 15; n_estimators: 80;
#
# max_features: 7; max_depth: 15; n_estimators: 90;
#
# max_features: 7; max_depth: 15; n_estimators: 100;
#
# max_features: 7; max_depth: 15; n_estimators: 120;
#
# max_features: 7; max_depth: 15; n_estimators: 140;
#
# max_features: 7; max_depth: 15; n_estimators: 160;
#
# max_features: 7; max_depth: 18; n_estimators: 10;
#
# max_features: 7; max_depth: 18; n_estimators: 20;
#
# max_features: 7; max_depth: 18; n_estimators: 30;
#
# max_features: 7; max_depth: 18; n_estimators: 40;
#
# max_features: 7; max_depth: 18; n_estimators: 50;
#
# max_features: 7; max_depth: 18; n_estimators: 60;
#
# max_features: 7; max_depth: 18; n_estimators: 80;
#
# max_features: 7; max_depth: 18; n_estimators: 90;
#
# max_features: 7; max_depth: 18; n_estimators: 100;
#
# max_features: 7; max_depth: 18; n_estimators: 120;
#
# max_features: 7; max_depth: 18; n_estimators: 140;
#
# max_features: 7; max_depth: 18; n_estimators: 160;
#
# max_features: 7; max_depth: 20; n_estimators: 10;
#
# max_features: 7; max_depth: 20; n_estimators: 20;
#
# max_features: 7; max_depth: 20; n_estimators: 30;
#
# max_features: 7; max_depth: 20; n_estimators: 40;
#
# max_features: 7; max_depth: 20; n_estimators: 50;
# max_features: 7; max_depth: 20; n_estimators: 60;
#
# max_features: 7; max_depth: 20; n_estimators: 80;
#
# max_features: 7; max_depth: 20; n_estimators: 90;
#
# max_features: 7; max_depth: 20; n_estimators: 100;
#
# max_features: 7; max_depth: 20; n_estimators: 120;
#
# max_features: 7; max_depth: 20; n_estimators: 140;
#
# max_features: 7; max_depth: 20; n_estimators: 160;
#
# max_features: 10; max_depth: 5; n_estimators: 10;
#
# max_features: 10; max_depth: 5; n_estimators: 20;
#
# max_features: 10; max_depth: 5; n_estimators: 30;
#
# max_features: 10; max_depth: 5; n_estimators: 40;
#
# max_features: 10; max_depth: 5; n_estimators: 50;
#
# max_features: 10; max_depth: 5; n_estimators: 60;
#
# max_features: 10; max_depth: 5; n_estimators: 80;
#
# max_features: 10; max_depth: 5; n_estimators: 90;
#
# max_features: 10; max_depth: 5; n_estimators: 100;
#
# max_features: 10; max_depth: 5; n_estimators: 120;
#
# max_features: 10; max_depth: 5; n_estimators: 140;
#
# max_features: 10; max_depth: 5; n_estimators: 160;
#
# max_features: 10; max_depth: 7; n_estimators: 10;
#
# max_features: 10; max_depth: 7; n_estimators: 20;
#
# max_features: 10; max_depth: 7; n_estimators: 30;
#
# max_features: 10; max_depth: 7; n_estimators: 40;
#
# max_features: 10; max_depth: 7; n_estimators: 50;
#
# max_features: 10; max_depth: 7; n_estimators: 60;
#
# max_features: 10; max_depth: 7; n_estimators: 80;
#
# max_features: 10; max_depth: 7; n_estimators: 90;
#
# max_features: 10; max_depth: 7; n_estimators: 100;
#
# max_features: 10; max_depth: 7; n_estimators: 120;
#
# max_features: 10; max_depth: 7; n_estimators: 140;
#
# max_features: 10; max_depth: 7; n_estimators: 160;
#
# max_features: 10; max_depth: 10; n_estimators: 10;
#
# max_features: 10; max_depth: 10; n_estimators: 20;
#
# max_features: 10; max_depth: 10; n_estimators: 30;
#
# max_features: 10; max_depth: 10; n_estimators: 40;
#
# max_features: 10; max_depth: 10; n_estimators: 50;
#
# max_features: 10; max_depth: 10; n_estimators: 60;
#
# max_features: 10; max_depth: 10; n_estimators: 80;
#
# max_features: 10; max_depth: 10; n_estimators: 90;
#
# max_features: 10; max_depth: 10; n_estimators: 100;
#
# max_features: 10; max_depth: 10; n_estimators: 120;
#
# max_features: 10; max_depth: 10; n_estimators: 140;
#
# max_features: 10; max_depth: 10; n_estimators: 160;
#
# max_features: 10; max_depth: 12; n_estimators: 10;
#
# max_features: 10; max_depth: 12; n_estimators: 20;
#
# max_features: 10; max_depth: 12; n_estimators: 30;
#
# max_features: 10; max_depth: 12; n_estimators: 40;
#
# max_features: 10; max_depth: 12; n_estimators: 50;
#
# max_features: 10; max_depth: 12; n_estimators: 60;
#
# max_features: 10; max_depth: 12; n_estimators: 80;
#
# max_features: 10; max_depth: 12; n_estimators: 90;
#
# max_features: 10; max_depth: 12; n_estimators: 100;
#
# max_features: 10; max_depth: 12; n_estimators: 120;
#
# max_features: 10; max_depth: 12; n_estimators: 140;
#
# max_features: 10; max_depth: 12; n_estimators: 160;
#
# max_features: 10; max_depth: 15; n_estimators: 10;
#
# max_features: 10; max_depth: 15; n_estimators: 20;
#
# max_features: 10; max_depth: 15; n_estimators: 30;
#
# max_features: 10; max_depth: 15; n_estimators: 40;
#
# max_features: 10; max_depth: 15; n_estimators: 50;
#
# max_features: 10; max_depth: 15; n_estimators: 60;
#
# max_features: 10; max_depth: 15; n_estimators: 80;
#
# max_features: 10; max_depth: 15; n_estimators: 90;
#
# max_features: 10; max_depth: 15; n_estimators: 100;
#
# max_features: 10; max_depth: 15; n_estimators: 120;
#
# max_features: 10; max_depth: 15; n_estimators: 140;
#
# max_features: 10; max_depth: 15; n_estimators: 160;
#
# max_features: 10; max_depth: 18; n_estimators: 10;
#
# max_features: 10; max_depth: 18; n_estimators: 20;
#
# max_features: 10; max_depth: 18; n_estimators: 30;
#
# max_features: 10; max_depth: 18; n_estimators: 40;
#
# max_features: 10; max_depth: 18; n_estimators: 50;
#
# max_features: 10; max_depth: 18; n_estimators: 60;
#
# max_features: 10; max_depth: 18; n_estimators: 80;
#
# max_features: 10; max_depth: 18; n_estimators: 90;
#
# max_features: 10; max_depth: 18; n_estimators: 100;
#
# max_features: 10; max_depth: 18; n_estimators: 120;
#
# max_features: 10; max_depth: 18; n_estimators: 140;
#
# max_features: 10; max_depth: 18; n_estimators: 160;
#
# max_features: 10; max_depth: 20; n_estimators: 10;
#
# max_features: 10; max_depth: 20; n_estimators: 20;
#
# max_features: 10; max_depth: 20; n_estimators: 30;
#
# max_features: 10; max_depth: 20; n_estimators: 40;
#
# max_features: 10; max_depth: 20; n_estimators: 50;
#
# max_features: 10; max_depth: 20; n_estimators: 60;
#
# max_features: 10; max_depth: 20; n_estimators: 80;
#
# max_features: 10; max_depth: 20; n_estimators: 90;
#
# max_features: 10; max_depth: 20; n_estimators: 100;
#
# max_features: 10; max_depth: 20; n_estimators: 120;
#
# max_features: 10; max_depth: 20; n_estimators: 140;
#
# max_features: 10; max_depth: 20; n_estimators: 160;
#
# max_features: 12; max_depth: 5; n_estimators: 10;
#
# max_features: 12; max_depth: 5; n_estimators: 20;
#
# max_features: 12; max_depth: 5; n_estimators: 30;
#
# max_features: 12; max_depth: 5; n_estimators: 40;
#
# max_features: 12; max_depth: 5; n_estimators: 50;
#
# max_features: 12; max_depth: 5; n_estimators: 60;
#
# max_features: 12; max_depth: 5; n_estimators: 80;
#
# max_features: 12; max_depth: 5; n_estimators: 90;
#
# max_features: 12; max_depth: 5; n_estimators: 100;
#
# max_features: 12; max_depth: 5; n_estimators: 120;
#
# max_features: 12; max_depth: 5; n_estimators: 140;
#
# max_features: 12; max_depth: 5; n_estimators: 160;
#
# max_features: 12; max_depth: 7; n_estimators: 10;
#
# max_features: 12; max_depth: 7; n_estimators: 20;
#
# max_features: 12; max_depth: 7; n_estimators: 30;
#
# max_features: 12; max_depth: 7; n_estimators: 40;
#
# max_features: 12; max_depth: 7; n_estimators: 50;
#
# max_features: 12; max_depth: 7; n_estimators: 60;
#
# max_features: 12; max_depth: 7; n_estimators: 80;
#
# max_features: 12; max_depth: 7; n_estimators: 90;
#
# max_features: 12; max_depth: 7; n_estimators: 100;
#
# max_features: 12; max_depth: 7; n_estimators: 120;
#
# max_features: 12; max_depth: 7; n_estimators: 140;
#
# max_features: 12; max_depth: 7; n_estimators: 160;
#
# max_features: 12; max_depth: 10; n_estimators: 10;
#
# max_features: 12; max_depth: 10; n_estimators: 20;
#
# max_features: 12; max_depth: 10; n_estimators: 30;
#
# max_features: 12; max_depth: 10; n_estimators: 40;
#
# max_features: 12; max_depth: 10; n_estimators: 50;
#
# max_features: 12; max_depth: 10; n_estimators: 60;
#
# max_features: 12; max_depth: 10; n_estimators: 80;
#
# max_features: 12; max_depth: 10; n_estimators: 90;
#
# max_features: 12; max_depth: 10; n_estimators: 100;
#
# max_features: 12; max_depth: 10; n_estimators: 120;
#
# max_features: 12; max_depth: 10; n_estimators: 140;
#
# max_features: 12; max_depth: 10; n_estimators: 160;
#
# max_features: 12; max_depth: 12; n_estimators: 10;
#
# max_features: 12; max_depth: 12; n_estimators: 20;
#
# max_features: 12; max_depth: 12; n_estimators: 30;
#
# max_features: 12; max_depth: 12; n_estimators: 40;
#
# max_features: 12; max_depth: 12; n_estimators: 50;
#
# max_features: 12; max_depth: 12; n_estimators: 60;
#
# max_features: 12; max_depth: 12; n_estimators: 80;
#
# max_features: 12; max_depth: 12; n_estimators: 90;
#
# max_features: 12; max_depth: 12; n_estimators: 100;
#
# max_features: 12; max_depth: 12; n_estimators: 120;
#
# max_features: 12; max_depth: 12; n_estimators: 140;
#
# max_features: 12; max_depth: 12; n_estimators: 160;
#
# max_features: 12; max_depth: 15; n_estimators: 10;
#
# max_features: 12; max_depth: 15; n_estimators: 20;
#
# max_features: 12; max_depth: 15; n_estimators: 30;
#
# max_features: 12; max_depth: 15; n_estimators: 40;
#
# max_features: 12; max_depth: 15; n_estimators: 50;
#
# max_features: 12; max_depth: 15; n_estimators: 60;
#
# max_features: 12; max_depth: 15; n_estimators: 80;
#
# max_features: 12; max_depth: 15; n_estimators: 90;
#
# max_features: 12; max_depth: 15; n_estimators: 100;
#
# max_features: 12; max_depth: 15; n_estimators: 120;
#
# max_features: 12; max_depth: 15; n_estimators: 140;
#
# max_features: 12; max_depth: 15; n_estimators: 160;
#
# max_features: 12; max_depth: 18; n_estimators: 10;
#
# max_features: 12; max_depth: 18; n_estimators: 20;
#
# max_features: 12; max_depth: 18; n_estimators: 30;
#
# max_features: 12; max_depth: 18; n_estimators: 40;
#
# max_features: 12; max_depth: 18; n_estimators: 50;
#
# max_features: 12; max_depth: 18; n_estimators: 60;
#
# max_features: 12; max_depth: 18; n_estimators: 80;
# max_features: 12; max_depth: 18; n_estimators: 90;
#
# max_features: 12; max_depth: 18; n_estimators: 100;
#
# max_features: 12; max_depth: 18; n_estimators: 120;
#
# max_features: 12; max_depth: 18; n_estimators: 140;
#
# max_features: 12; max_depth: 18; n_estimators: 160;
#
# max_features: 12; max_depth: 20; n_estimators: 10;
#
# max_features: 12; max_depth: 20; n_estimators: 20;
#
# max_features: 12; max_depth: 20; n_estimators: 30;
#
# max_features: 12; max_depth: 20; n_estimators: 40;
#
# max_features: 12; max_depth: 20; n_estimators: 50;
#
# max_features: 12; max_depth: 20; n_estimators: 60;
#
# max_features: 12; max_depth: 20; n_estimators: 80;
#
# max_features: 12; max_depth: 20; n_estimators: 90;
#
# max_features: 12; max_depth: 20; n_estimators: 100;
#
# max_features: 12; max_depth: 20; n_estimators: 120;
#
# max_features: 12; max_depth: 20; n_estimators: 140;
#
# max_features: 12; max_depth: 20; n_estimators: 160;
#
# max_features: 15; max_depth: 5; n_estimators: 10;
#
# max_features: 15; max_depth: 5; n_estimators: 20;
#
# max_features: 15; max_depth: 5; n_estimators: 30;
#
# max_features: 15; max_depth: 5; n_estimators: 40;
#
# max_features: 15; max_depth: 5; n_estimators: 50;
#
# max_features: 15; max_depth: 5; n_estimators: 60;
#
# max_features: 15; max_depth: 5; n_estimators: 80;
#
# max_features: 15; max_depth: 5; n_estimators: 90;
#
# max_features: 15; max_depth: 5; n_estimators: 100;
#
# max_features: 15; max_depth: 5; n_estimators: 120;
#
# max_features: 15; max_depth: 5; n_estimators: 140;
#
# max_features: 15; max_depth: 5; n_estimators: 160;
#
# max_features: 15; max_depth: 7; n_estimators: 10;
#
# max_features: 15; max_depth: 7; n_estimators: 20;
#
# max_features: 15; max_depth: 7; n_estimators: 30;
#
# max_features: 15; max_depth: 7; n_estimators: 40;
#
# max_features: 15; max_depth: 7; n_estimators: 50;
#
# max_features: 15; max_depth: 7; n_estimators: 60;
#
# max_features: 15; max_depth: 7; n_estimators: 80;
#
# max_features: 15; max_depth: 7; n_estimators: 90;
#
# max_features: 15; max_depth: 7; n_estimators: 100;
#
# max_features: 15; max_depth: 7; n_estimators: 120;
#
# max_features: 15; max_depth: 7; n_estimators: 140;
#
# max_features: 15; max_depth: 7; n_estimators: 160;
#
# max_features: 15; max_depth: 10; n_estimators: 10;
#
# max_features: 15; max_depth: 10; n_estimators: 20;
#
# max_features: 15; max_depth: 10; n_estimators: 30;
#
# max_features: 15; max_depth: 10; n_estimators: 40;
#
# max_features: 15; max_depth: 10; n_estimators: 50;
#
# max_features: 15; max_depth: 10; n_estimators: 60;
#
# max_features: 15; max_depth: 10; n_estimators: 80;
#
# max_features: 15; max_depth: 10; n_estimators: 90;
#
# max_features: 15; max_depth: 10; n_estimators: 100;
#
# max_features: 15; max_depth: 10; n_estimators: 120;
#
# max_features: 15; max_depth: 10; n_estimators: 140;
#
# max_features: 15; max_depth: 10; n_estimators: 160;
#
# max_features: 15; max_depth: 12; n_estimators: 10;
#
# max_features: 15; max_depth: 12; n_estimators: 20;
#
# max_features: 15; max_depth: 12; n_estimators: 30;
#
# max_features: 15; max_depth: 12; n_estimators: 40;
#
# max_features: 15; max_depth: 12; n_estimators: 50;
#
# max_features: 15; max_depth: 12; n_estimators: 60;
#
# max_features: 15; max_depth: 12; n_estimators: 80;
#
# max_features: 15; max_depth: 12; n_estimators: 90;
#
# max_features: 15; max_depth: 12; n_estimators: 100;
#
# max_features: 15; max_depth: 12; n_estimators: 120;
#
# max_features: 15; max_depth: 12; n_estimators: 140;
#
# max_features: 15; max_depth: 12; n_estimators: 160;
#
# max_features: 15; max_depth: 15; n_estimators: 10;
#
# max_features: 15; max_depth: 15; n_estimators: 20;
#
# max_features: 15; max_depth: 15; n_estimators: 30;
#
# max_features: 15; max_depth: 15; n_estimators: 40;
#
# max_features: 15; max_depth: 15; n_estimators: 50;
#
# max_features: 15; max_depth: 15; n_estimators: 60;
#
# max_features: 15; max_depth: 15; n_estimators: 80;
#
# max_features: 15; max_depth: 15; n_estimators: 90;
#
# max_features: 15; max_depth: 15; n_estimators: 100;
#
# max_features: 15; max_depth: 15; n_estimators: 120;
#
# max_features: 15; max_depth: 15; n_estimators: 140;
#
# max_features: 15; max_depth: 15; n_estimators: 160;
#
# max_features: 15; max_depth: 18; n_estimators: 10;
#
# max_features: 15; max_depth: 18; n_estimators: 20;
#
# max_features: 15; max_depth: 18; n_estimators: 30;
#
# max_features: 15; max_depth: 18; n_estimators: 40;
#
# max_features: 15; max_depth: 18; n_estimators: 50;
#
# max_features: 15; max_depth: 18; n_estimators: 60;
#
# max_features: 15; max_depth: 18; n_estimators: 80;
#
# max_features: 15; max_depth: 18; n_estimators: 90;
#
# max_features: 15; max_depth: 18; n_estimators: 100;
#
# max_features: 15; max_depth: 18; n_estimators: 120;
#
# max_features: 15; max_depth: 18; n_estimators: 140;
#
# max_features: 15; max_depth: 18; n_estimators: 160;
#
# max_features: 15; max_depth: 20; n_estimators: 10;
#
# max_features: 15; max_depth: 20; n_estimators: 20;
#
# max_features: 15; max_depth: 20; n_estimators: 30;
#
# max_features: 15; max_depth: 20; n_estimators: 40;
#
# max_features: 15; max_depth: 20; n_estimators: 50;
#
# max_features: 15; max_depth: 20; n_estimators: 60;
#
# max_features: 15; max_depth: 20; n_estimators: 80;
#
# max_features: 15; max_depth: 20; n_estimators: 90;
#
# max_features: 15; max_depth: 20; n_estimators: 100;
#
# max_features: 15; max_depth: 20; n_estimators: 120;
#
# max_features: 15; max_depth: 20; n_estimators: 140;
#
# max_features: 15; max_depth: 20; n_estimators: 160;
#
# max_features: 18; max_depth: 5; n_estimators: 10;
#
# max_features: 18; max_depth: 5; n_estimators: 20;
#
# max_features: 18; max_depth: 5; n_estimators: 30;
#
# max_features: 18; max_depth: 5; n_estimators: 40;
#
# max_features: 18; max_depth: 5; n_estimators: 50;
#
# max_features: 18; max_depth: 5; n_estimators: 60;
#
# max_features: 18; max_depth: 5; n_estimators: 80;
#
# max_features: 18; max_depth: 5; n_estimators: 90;
#
# max_features: 18; max_depth: 5; n_estimators: 100;
#
# max_features: 18; max_depth: 5; n_estimators: 120;
#
# max_features: 18; max_depth: 5; n_estimators: 140;
#
# max_features: 18; max_depth: 5; n_estimators: 160;
#
# max_features: 18; max_depth: 7; n_estimators: 10;
#
# max_features: 18; max_depth: 7; n_estimators: 20;
#
# max_features: 18; max_depth: 7; n_estimators: 30;
#
# max_features: 18; max_depth: 7; n_estimators: 40;
#
# max_features: 18; max_depth: 7; n_estimators: 50;
#
# max_features: 18; max_depth: 7; n_estimators: 60;
#
# max_features: 18; max_depth: 7; n_estimators: 80;
#
# max_features: 18; max_depth: 7; n_estimators: 90;
#
# max_features: 18; max_depth: 7; n_estimators: 100;
#
# max_features: 18; max_depth: 7; n_estimators: 120;
#
# max_features: 18; max_depth: 7; n_estimators: 140;
#
# max_features: 18; max_depth: 7; n_estimators: 160;
#
# max_features: 18; max_depth: 10; n_estimators: 10;
#
# max_features: 18; max_depth: 10; n_estimators: 20;
#
# max_features: 18; max_depth: 10; n_estimators: 30;
#
# max_features: 18; max_depth: 10; n_estimators: 40;
#
# max_features: 18; max_depth: 10; n_estimators: 50;
#
# max_features: 18; max_depth: 10; n_estimators: 60;
#
# max_features: 18; max_depth: 10; n_estimators: 80;
#
# max_features: 18; max_depth: 10; n_estimators: 90;
#
# max_features: 18; max_depth: 10; n_estimators: 100;
#
# max_features: 18; max_depth: 10; n_estimators: 120;
#
# max_features: 18; max_depth: 10; n_estimators: 140;
#
# max_features: 18; max_depth: 10; n_estimators: 160;
#
# max_features: 18; max_depth: 12; n_estimators: 10;
#
# max_features: 18; max_depth: 12; n_estimators: 20;
#
# max_features: 18; max_depth: 12; n_estimators: 30;
#
# max_features: 18; max_depth: 12; n_estimators: 40;
#
# max_features: 18; max_depth: 12; n_estimators: 50;
#
# max_features: 18; max_depth: 12; n_estimators: 60;
#
# max_features: 18; max_depth: 12; n_estimators: 80;
#
# max_features: 18; max_depth: 12; n_estimators: 90;
#
# max_features: 18; max_depth: 12; n_estimators: 100;
#
# max_features: 18; max_depth: 12; n_estimators: 120;
#
# max_features: 18; max_depth: 12; n_estimators: 140;
#
# max_features: 18; max_depth: 12; n_estimators: 160;
#
# max_features: 18; max_depth: 15; n_estimators: 10;
#
# max_features: 18; max_depth: 15; n_estimators: 20;
#
# max_features: 18; max_depth: 15; n_estimators: 30;
#
# max_features: 18; max_depth: 15; n_estimators: 40;
#
# max_features: 18; max_depth: 15; n_estimators: 50;
#
# max_features: 18; max_depth: 15; n_estimators: 60;
#
# max_features: 18; max_depth: 15; n_estimators: 80;
#
# max_features: 18; max_depth: 15; n_estimators: 90;
#
# max_features: 18; max_depth: 15; n_estimators: 100;
# max_features: 18; max_depth: 15; n_estimators: 120;
#
# max_features: 18; max_depth: 15; n_estimators: 140;
#
# max_features: 18; max_depth: 15; n_estimators: 160;
#
# max_features: 18; max_depth: 18; n_estimators: 10;
#
# max_features: 18; max_depth: 18; n_estimators: 20;
#
# max_features: 18; max_depth: 18; n_estimators: 30;
#
# max_features: 18; max_depth: 18; n_estimators: 40;
#
# max_features: 18; max_depth: 18; n_estimators: 50;
#
# max_features: 18; max_depth: 18; n_estimators: 60;
#
# max_features: 18; max_depth: 18; n_estimators: 80;
#
# max_features: 18; max_depth: 18; n_estimators: 90;
#
# max_features: 18; max_depth: 18; n_estimators: 100;
#
# max_features: 18; max_depth: 18; n_estimators: 120;
#
# max_features: 18; max_depth: 18; n_estimators: 140;
#
# max_features: 18; max_depth: 18; n_estimators: 160;
#
# max_features: 18; max_depth: 20; n_estimators: 10;
#
# max_features: 18; max_depth: 20; n_estimators: 20;
#
# max_features: 18; max_depth: 20; n_estimators: 30;
#
# max_features: 18; max_depth: 20; n_estimators: 40;
#
# max_features: 18; max_depth: 20; n_estimators: 50;
#
# max_features: 18; max_depth: 20; n_estimators: 60;
#
# max_features: 18; max_depth: 20; n_estimators: 80;
#
# max_features: 18; max_depth: 20; n_estimators: 90;
#
# max_features: 18; max_depth: 20; n_estimators: 100;
#
# max_features: 18; max_depth: 20; n_estimators: 120;
#
# max_features: 18; max_depth: 20; n_estimators: 140;
#
# max_features: 18; max_depth: 20; n_estimators: 160;
#
# max_features: 20; max_depth: 5; n_estimators: 10;
#
# max_features: 20; max_depth: 5; n_estimators: 20;
#
# max_features: 20; max_depth: 5; n_estimators: 30;
#
# max_features: 20; max_depth: 5; n_estimators: 40;
#
# max_features: 20; max_depth: 5; n_estimators: 50;
#
# max_features: 20; max_depth: 5; n_estimators: 60;
#
# max_features: 20; max_depth: 5; n_estimators: 80;
#
# max_features: 20; max_depth: 5; n_estimators: 90;
#
# max_features: 20; max_depth: 5; n_estimators: 100;
#
# max_features: 20; max_depth: 5; n_estimators: 120;
#
# max_features: 20; max_depth: 5; n_estimators: 140;
#
# max_features: 20; max_depth: 5; n_estimators: 160;
#
# max_features: 20; max_depth: 7; n_estimators: 10;
#
# max_features: 20; max_depth: 7; n_estimators: 20;
#
# max_features: 20; max_depth: 7; n_estimators: 30;
#
# max_features: 20; max_depth: 7; n_estimators: 40;
#
# max_features: 20; max_depth: 7; n_estimators: 50;
#
# max_features: 20; max_depth: 7; n_estimators: 60;
#
# max_features: 20; max_depth: 7; n_estimators: 80;
#
# max_features: 20; max_depth: 7; n_estimators: 90;
#
# max_features: 20; max_depth: 7; n_estimators: 100;
#
# max_features: 20; max_depth: 7; n_estimators: 120;
#
# max_features: 20; max_depth: 7; n_estimators: 140;
#
# max_features: 20; max_depth: 7; n_estimators: 160;
#
# max_features: 20; max_depth: 10; n_estimators: 10;
#
# max_features: 20; max_depth: 10; n_estimators: 20;
#
# max_features: 20; max_depth: 10; n_estimators: 30;
#
# max_features: 20; max_depth: 10; n_estimators: 40;
#
# max_features: 20; max_depth: 10; n_estimators: 50;
#
# max_features: 20; max_depth: 10; n_estimators: 60;
#
# max_features: 20; max_depth: 10; n_estimators: 80;
#
# max_features: 20; max_depth: 10; n_estimators: 90;
#
# max_features: 20; max_depth: 10; n_estimators: 100;
#
# max_features: 20; max_depth: 10; n_estimators: 120;
#
# max_features: 20; max_depth: 10; n_estimators: 140;
#
# max_features: 20; max_depth: 10; n_estimators: 160;
#
# max_features: 20; max_depth: 12; n_estimators: 10;
#
# max_features: 20; max_depth: 12; n_estimators: 20;
#
# max_features: 20; max_depth: 12; n_estimators: 30;
#
# max_features: 20; max_depth: 12; n_estimators: 40;
#
# max_features: 20; max_depth: 12; n_estimators: 50;
#
# max_features: 20; max_depth: 12; n_estimators: 60;
#
# max_features: 20; max_depth: 12; n_estimators: 80;
#
# max_features: 20; max_depth: 12; n_estimators: 90;
#
# max_features: 20; max_depth: 12; n_estimators: 100;
#
# max_features: 20; max_depth: 12; n_estimators: 120;
#
# max_features: 20; max_depth: 12; n_estimators: 140;
#
# max_features: 20; max_depth: 12; n_estimators: 160;
#
# max_features: 20; max_depth: 15; n_estimators: 10;
#
# max_features: 20; max_depth: 15; n_estimators: 20;
#
# max_features: 20; max_depth: 15; n_estimators: 30;
#
# max_features: 20; max_depth: 15; n_estimators: 40;
#
# max_features: 20; max_depth: 15; n_estimators: 50;
#
# max_features: 20; max_depth: 15; n_estimators: 60;
#
# max_features: 20; max_depth: 15; n_estimators: 80;
#
# max_features: 20; max_depth: 15; n_estimators: 90;
#
# max_features: 20; max_depth: 15; n_estimators: 100;
#
# max_features: 20; max_depth: 15; n_estimators: 120;
#
# max_features: 20; max_depth: 15; n_estimators: 140;
#
# max_features: 20; max_depth: 15; n_estimators: 160;
#
# max_features: 20; max_depth: 18; n_estimators: 10;
#
# max_features: 20; max_depth: 18; n_estimators: 20;
#
# max_features: 20; max_depth: 18; n_estimators: 30;
#
# max_features: 20; max_depth: 18; n_estimators: 40;
#
# max_features: 20; max_depth: 18; n_estimators: 50;
#
# max_features: 20; max_depth: 18; n_estimators: 60;
#
# max_features: 20; max_depth: 18; n_estimators: 80;
#
# max_features: 20; max_depth: 18; n_estimators: 90;
#
# max_features: 20; max_depth: 18; n_estimators: 100;
#
# max_features: 20; max_depth: 18; n_estimators: 120;
#
# max_features: 20; max_depth: 18; n_estimators: 140;
#
# max_features: 20; max_depth: 18; n_estimators: 160;
#
# max_features: 20; max_depth: 20; n_estimators: 10;
#
# max_features: 20; max_depth: 20; n_estimators: 20;
#
# max_features: 20; max_depth: 20; n_estimators: 30;
#
# max_features: 20; max_depth: 20; n_estimators: 40;
#
# max_features: 20; max_depth: 20; n_estimators: 50;
#
# max_features: 20; max_depth: 20; n_estimators: 60;
#
# max_features: 20; max_depth: 20; n_estimators: 80;
#
# max_features: 20; max_depth: 20; n_estimators: 90;
#
# max_features: 20; max_depth: 20; n_estimators: 100;
#
# max_features: 20; max_depth: 20; n_estimators: 120;
#
# max_features: 20; max_depth: 20; n_estimators: 140;
#
# max_features: 20; max_depth: 20; n_estimators: 160;
#
# max_features: 25; max_depth: 5; n_estimators: 10;
#
# max_features: 25; max_depth: 5; n_estimators: 20;
#
# max_features: 25; max_depth: 5; n_estimators: 30;
#
# max_features: 25; max_depth: 5; n_estimators: 40;
#
# max_features: 25; max_depth: 5; n_estimators: 50;
#
# max_features: 25; max_depth: 5; n_estimators: 60;
#
# max_features: 25; max_depth: 5; n_estimators: 80;
#
# max_features: 25; max_depth: 5; n_estimators: 90;
#
# max_features: 25; max_depth: 5; n_estimators: 100;
#
# max_features: 25; max_depth: 5; n_estimators: 120;
#
# max_features: 25; max_depth: 5; n_estimators: 140;
#
# max_features: 25; max_depth: 5; n_estimators: 160;
#
# max_features: 25; max_depth: 7; n_estimators: 10;
#
# max_features: 25; max_depth: 7; n_estimators: 20;
#
# max_features: 25; max_depth: 7; n_estimators: 30;
#
# max_features: 25; max_depth: 7; n_estimators: 40;
#
# max_features: 25; max_depth: 7; n_estimators: 50;
#
# max_features: 25; max_depth: 7; n_estimators: 60;
#
# max_features: 25; max_depth: 7; n_estimators: 80;
#
# max_features: 25; max_depth: 7; n_estimators: 90;
#
# max_features: 25; max_depth: 7; n_estimators: 100;
#
# max_features: 25; max_depth: 7; n_estimators: 120;
#
# max_features: 25; max_depth: 7; n_estimators: 140;
#
# max_features: 25; max_depth: 7; n_estimators: 160;
#
# max_features: 25; max_depth: 10; n_estimators: 10;
#
# max_features: 25; max_depth: 10; n_estimators: 20;
#
# max_features: 25; max_depth: 10; n_estimators: 30;
#
# max_features: 25; max_depth: 10; n_estimators: 40;
#
# max_features: 25; max_depth: 10; n_estimators: 50;
#
# max_features: 25; max_depth: 10; n_estimators: 60;
#
# max_features: 25; max_depth: 10; n_estimators: 80;
#
# max_features: 25; max_depth: 10; n_estimators: 90;
#
# max_features: 25; max_depth: 10; n_estimators: 100;
#
# max_features: 25; max_depth: 10; n_estimators: 120;
#
# max_features: 25; max_depth: 10; n_estimators: 140;
#
# max_features: 25; max_depth: 10; n_estimators: 160;
#
# max_features: 25; max_depth: 12; n_estimators: 10;
#
# max_features: 25; max_depth: 12; n_estimators: 20;
#
# max_features: 25; max_depth: 12; n_estimators: 30;
#
# max_features: 25; max_depth: 12; n_estimators: 40;
#
# max_features: 25; max_depth: 12; n_estimators: 50;
#
# max_features: 25; max_depth: 12; n_estimators: 60;
#
# max_features: 25; max_depth: 12; n_estimators: 80;
#
# max_features: 25; max_depth: 12; n_estimators: 90;
#
# max_features: 25; max_depth: 12; n_estimators: 100;
#
# max_features: 25; max_depth: 12; n_estimators: 120;
#
# max_features: 25; max_depth: 12; n_estimators: 140;
# max_features: 25; max_depth: 12; n_estimators: 160;
#
# max_features: 25; max_depth: 15; n_estimators: 10;
#
# max_features: 25; max_depth: 15; n_estimators: 20;
#
# max_features: 25; max_depth: 15; n_estimators: 30;
#
# max_features: 25; max_depth: 15; n_estimators: 40;
#
# max_features: 25; max_depth: 15; n_estimators: 50;
#
# max_features: 25; max_depth: 15; n_estimators: 60;
#
# max_features: 25; max_depth: 15; n_estimators: 80;
#
# max_features: 25; max_depth: 15; n_estimators: 90;
#
# max_features: 25; max_depth: 15; n_estimators: 100;
#
# max_features: 25; max_depth: 15; n_estimators: 120;
#
# max_features: 25; max_depth: 15; n_estimators: 140;
#
# max_features: 25; max_depth: 15; n_estimators: 160;
#
# max_features: 25; max_depth: 18; n_estimators: 10;
#
# max_features: 25; max_depth: 18; n_estimators: 20;
#
# max_features: 25; max_depth: 18; n_estimators: 30;
#
# max_features: 25; max_depth: 18; n_estimators: 40;
#
# max_features: 25; max_depth: 18; n_estimators: 50;
#
# max_features: 25; max_depth: 18; n_estimators: 60;
#
# max_features: 25; max_depth: 18; n_estimators: 80;
#
# max_features: 25; max_depth: 18; n_estimators: 90;
#
# max_features: 25; max_depth: 18; n_estimators: 100;
#
# max_features: 25; max_depth: 18; n_estimators: 120;
#
# max_features: 25; max_depth: 18; n_estimators: 140;
#
# max_features: 25; max_depth: 18; n_estimators: 160;
#
# max_features: 25; max_depth: 20; n_estimators: 10;
#
# max_features: 25; max_depth: 20; n_estimators: 20;
#
# max_features: 25; max_depth: 20; n_estimators: 30;
#
# max_features: 25; max_depth: 20; n_estimators: 40;
#
# max_features: 25; max_depth: 20; n_estimators: 50;
#
# max_features: 25; max_depth: 20; n_estimators: 60;
#
# max_features: 25; max_depth: 20; n_estimators: 80;
#
# max_features: 25; max_depth: 20; n_estimators: 90;
#
# max_features: 25; max_depth: 20; n_estimators: 100;
#
# max_features: 25; max_depth: 20; n_estimators: 120;
#
# max_features: 25; max_depth: 20; n_estimators: 140;
#
# max_features: 25; max_depth: 20; n_estimators: 160;
#
# max_features: 30; max_depth: 5; n_estimators: 10;
#
# max_features: 30; max_depth: 5; n_estimators: 20;
#
# max_features: 30; max_depth: 5; n_estimators: 30;
#
# max_features: 30; max_depth: 5; n_estimators: 40;
#
# max_features: 30; max_depth: 5; n_estimators: 50;
#
# max_features: 30; max_depth: 5; n_estimators: 60;
#
# max_features: 30; max_depth: 5; n_estimators: 80;
#
# max_features: 30; max_depth: 5; n_estimators: 90;
#
# max_features: 30; max_depth: 5; n_estimators: 100;
#
# max_features: 30; max_depth: 5; n_estimators: 120;
#
# max_features: 30; max_depth: 5; n_estimators: 140;
#
# max_features: 30; max_depth: 5; n_estimators: 160;
#
# max_features: 30; max_depth: 7; n_estimators: 10;
#
# max_features: 30; max_depth: 7; n_estimators: 20;
#
# max_features: 30; max_depth: 7; n_estimators: 30;
#
# max_features: 30; max_depth: 7; n_estimators: 40;
#
# max_features: 30; max_depth: 7; n_estimators: 50;
#
# max_features: 30; max_depth: 7; n_estimators: 60;
#
# max_features: 30; max_depth: 7; n_estimators: 80;
#
# max_features: 30; max_depth: 7; n_estimators: 90;
#
# max_features: 30; max_depth: 7; n_estimators: 100;
#
# max_features: 30; max_depth: 7; n_estimators: 120;
#
# max_features: 30; max_depth: 7; n_estimators: 140;
#
# max_features: 30; max_depth: 7; n_estimators: 160;
#
# max_features: 30; max_depth: 10; n_estimators: 10;
#
# max_features: 30; max_depth: 10; n_estimators: 20;
#
# max_features: 30; max_depth: 10; n_estimators: 30;
#
# max_features: 30; max_depth: 10; n_estimators: 40;
#
# max_features: 30; max_depth: 10; n_estimators: 50;
#
# max_features: 30; max_depth: 10; n_estimators: 60;
#
# max_features: 30; max_depth: 10; n_estimators: 80;
#
# max_features: 30; max_depth: 10; n_estimators: 90;
#
# max_features: 30; max_depth: 10; n_estimators: 100;
#
# max_features: 30; max_depth: 10; n_estimators: 120;
#
# max_features: 30; max_depth: 10; n_estimators: 140;
#
# max_features: 30; max_depth: 10; n_estimators: 160;
#
# max_features: 30; max_depth: 12; n_estimators: 10;
#
# max_features: 30; max_depth: 12; n_estimators: 20;
#
# max_features: 30; max_depth: 12; n_estimators: 30;
#
# max_features: 30; max_depth: 12; n_estimators: 40;
#
# max_features: 30; max_depth: 12; n_estimators: 50;
#
# max_features: 30; max_depth: 12; n_estimators: 60;
#
# max_features: 30; max_depth: 12; n_estimators: 80;
#
# max_features: 30; max_depth: 12; n_estimators: 90;
#
# max_features: 30; max_depth: 12; n_estimators: 100;
#
# max_features: 30; max_depth: 12; n_estimators: 120;
#
# max_features: 30; max_depth: 12; n_estimators: 140;
#
# max_features: 30; max_depth: 12; n_estimators: 160;
#
# max_features: 30; max_depth: 15; n_estimators: 10;
#
# max_features: 30; max_depth: 15; n_estimators: 20;
#
# max_features: 30; max_depth: 15; n_estimators: 30;
#
# max_features: 30; max_depth: 15; n_estimators: 40;
#
# max_features: 30; max_depth: 15; n_estimators: 50;
#
# max_features: 30; max_depth: 15; n_estimators: 60;
#
# max_features: 30; max_depth: 15; n_estimators: 80;
#
# max_features: 30; max_depth: 15; n_estimators: 90;
#
# max_features: 30; max_depth: 15; n_estimators: 100;
#
# max_features: 30; max_depth: 15; n_estimators: 120;
#
# max_features: 30; max_depth: 15; n_estimators: 140;
#
# max_features: 30; max_depth: 15; n_estimators: 160;
#
# max_features: 30; max_depth: 18; n_estimators: 10;
#
# max_features: 30; max_depth: 18; n_estimators: 20;
#
# max_features: 30; max_depth: 18; n_estimators: 30;
#
# max_features: 30; max_depth: 18; n_estimators: 40;
#
# max_features: 30; max_depth: 18; n_estimators: 50;
#
# max_features: 30; max_depth: 18; n_estimators: 60;
#
# max_features: 30; max_depth: 18; n_estimators: 80;
#
# max_features: 30; max_depth: 18; n_estimators: 90;
#
# max_features: 30; max_depth: 18; n_estimators: 100;
#
# max_features: 30; max_depth: 18; n_estimators: 120;
#
# max_features: 30; max_depth: 18; n_estimators: 140;
#
# max_features: 30; max_depth: 18; n_estimators: 160;
#
# max_features: 30; max_depth: 20; n_estimators: 10;
#
# max_features: 30; max_depth: 20; n_estimators: 20;
#
# max_features: 30; max_depth: 20; n_estimators: 30;
#
# max_features: 30; max_depth: 20; n_estimators: 40;
#
# max_features: 30; max_depth: 20; n_estimators: 50;
#
# max_features: 30; max_depth: 20; n_estimators: 60;
#
# max_features: 30; max_depth: 20; n_estimators: 80;
#
# max_features: 30; max_depth: 20; n_estimators: 90;
#
# max_features: 30; max_depth: 20; n_estimators: 100;
#
# max_features: 30; max_depth: 20; n_estimators: 120;
#
# max_features: 30; max_depth: 20; n_estimators: 140;
#
# max_features: 30; max_depth: 20; n_estimators: 160;
#
# max_features: 50; max_depth: 5; n_estimators: 10;
#
# max_features: 50; max_depth: 5; n_estimators: 20;
#
# max_features: 50; max_depth: 5; n_estimators: 30;
#
# max_features: 50; max_depth: 5; n_estimators: 40;
#
# max_features: 50; max_depth: 5; n_estimators: 50;
#
# max_features: 50; max_depth: 5; n_estimators: 60;
#
# max_features: 50; max_depth: 5; n_estimators: 80;
#
# max_features: 50; max_depth: 5; n_estimators: 90;
#
# max_features: 50; max_depth: 5; n_estimators: 100;
#
# max_features: 50; max_depth: 5; n_estimators: 120;
#
# max_features: 50; max_depth: 5; n_estimators: 140;
#
# max_features: 50; max_depth: 5; n_estimators: 160;
#
# max_features: 50; max_depth: 7; n_estimators: 10;
#
# max_features: 50; max_depth: 7; n_estimators: 20;
#
# max_features: 50; max_depth: 7; n_estimators: 30;
#
# max_features: 50; max_depth: 7; n_estimators: 40;
#
# max_features: 50; max_depth: 7; n_estimators: 50;
#
# max_features: 50; max_depth: 7; n_estimators: 60;
#
# max_features: 50; max_depth: 7; n_estimators: 80;
#
# max_features: 50; max_depth: 7; n_estimators: 90;
#
# max_features: 50; max_depth: 7; n_estimators: 100;
#
# max_features: 50; max_depth: 7; n_estimators: 120;
#
# max_features: 50; max_depth: 7; n_estimators: 140;
#
# max_features: 50; max_depth: 7; n_estimators: 160;
#
# max_features: 50; max_depth: 10; n_estimators: 10;
#
# max_features: 50; max_depth: 10; n_estimators: 20;
#
# max_features: 50; max_depth: 10; n_estimators: 30;
#
# max_features: 50; max_depth: 10; n_estimators: 40;
#
# max_features: 50; max_depth: 10; n_estimators: 50;
#
# max_features: 50; max_depth: 10; n_estimators: 60;
#
# max_features: 50; max_depth: 10; n_estimators: 80;
#
# max_features: 50; max_depth: 10; n_estimators: 90;
#
# max_features: 50; max_depth: 10; n_estimators: 100;
#
# max_features: 50; max_depth: 10; n_estimators: 120;
#
# max_features: 50; max_depth: 10; n_estimators: 140;
#
# max_features: 50; max_depth: 10; n_estimators: 160;
#
# max_features: 50; max_depth: 12; n_estimators: 10;
# max_features: 50; max_depth: 12; n_estimators: 20;
#
# max_features: 50; max_depth: 12; n_estimators: 30;
#
# max_features: 50; max_depth: 12; n_estimators: 40;
#
# max_features: 50; max_depth: 12; n_estimators: 50;
#
# max_features: 50; max_depth: 12; n_estimators: 60;
#
# max_features: 50; max_depth: 12; n_estimators: 80;
#
# max_features: 50; max_depth: 12; n_estimators: 90;
#
# max_features: 50; max_depth: 12; n_estimators: 100;
#
# max_features: 50; max_depth: 12; n_estimators: 120;
#
# max_features: 50; max_depth: 12; n_estimators: 140;
#
# max_features: 50; max_depth: 12; n_estimators: 160;
#
# max_features: 50; max_depth: 15; n_estimators: 10;
#
# max_features: 50; max_depth: 15; n_estimators: 20;
#
# max_features: 50; max_depth: 15; n_estimators: 30;
#
# max_features: 50; max_depth: 15; n_estimators: 40;
#
# max_features: 50; max_depth: 15; n_estimators: 50;
#
# max_features: 50; max_depth: 15; n_estimators: 60;
#
# max_features: 50; max_depth: 15; n_estimators: 80;
#
# max_features: 50; max_depth: 15; n_estimators: 90;
#
# max_features: 50; max_depth: 15; n_estimators: 100;
#
# max_features: 50; max_depth: 15; n_estimators: 120;
#
# max_features: 50; max_depth: 15; n_estimators: 140;
#
# max_features: 50; max_depth: 15; n_estimators: 160;
#
# max_features: 50; max_depth: 18; n_estimators: 10;
#
# max_features: 50; max_depth: 18; n_estimators: 20;
#
# max_features: 50; max_depth: 18; n_estimators: 30;
#
# max_features: 50; max_depth: 18; n_estimators: 40;
#
# max_features: 50; max_depth: 18; n_estimators: 50;
#
# max_features: 50; max_depth: 18; n_estimators: 60;
#
# max_features: 50; max_depth: 18; n_estimators: 80;
#
# max_features: 50; max_depth: 18; n_estimators: 90;
#
# max_features: 50; max_depth: 18; n_estimators: 100;
#
# max_features: 50; max_depth: 18; n_estimators: 120;
#
# max_features: 50; max_depth: 18; n_estimators: 140;
#
# max_features: 50; max_depth: 18; n_estimators: 160;
#
# max_features: 50; max_depth: 20; n_estimators: 10;
#
# max_features: 50; max_depth: 20; n_estimators: 20;
#
# max_features: 50; max_depth: 20; n_estimators: 30;
#
# max_features: 50; max_depth: 20; n_estimators: 40;
#
# max_features: 50; max_depth: 20; n_estimators: 50;
#
# max_features: 50; max_depth: 20; n_estimators: 60;
#
# max_features: 50; max_depth: 20; n_estimators: 80;
#
# max_features: 50; max_depth: 20; n_estimators: 90;
#
# max_features: 50; max_depth: 20; n_estimators: 100;
#
# max_features: 50; max_depth: 20; n_estimators: 120;
#
# max_features: 50; max_depth: 20; n_estimators: 140;
#
# max_features: 50; max_depth: 20; n_estimators: 160;
#
# max_features: 80; max_depth: 5; n_estimators: 10;
#
# max_features: 80; max_depth: 5; n_estimators: 20;
#
# max_features: 80; max_depth: 5; n_estimators: 30;
#
# max_features: 80; max_depth: 5; n_estimators: 40;
#
# max_features: 80; max_depth: 5; n_estimators: 50;
#
# max_features: 80; max_depth: 5; n_estimators: 60;
#
# max_features: 80; max_depth: 5; n_estimators: 80;
#
# max_features: 80; max_depth: 5; n_estimators: 90;
#
# max_features: 80; max_depth: 5; n_estimators: 100;
#
# max_features: 80; max_depth: 5; n_estimators: 120;
#
# max_features: 80; max_depth: 5; n_estimators: 140;
#
# max_features: 80; max_depth: 5; n_estimators: 160;
#
# max_features: 80; max_depth: 7; n_estimators: 10;
#
# max_features: 80; max_depth: 7; n_estimators: 20;
#
# max_features: 80; max_depth: 7; n_estimators: 30;
#
# max_features: 80; max_depth: 7; n_estimators: 40;
#
# max_features: 80; max_depth: 7; n_estimators: 50;
#
# max_features: 80; max_depth: 7; n_estimators: 60;
#
# max_features: 80; max_depth: 7; n_estimators: 80;
#
# max_features: 80; max_depth: 7; n_estimators: 90;
#
# max_features: 80; max_depth: 7; n_estimators: 100;
#
# max_features: 80; max_depth: 7; n_estimators: 120;
#
# max_features: 80; max_depth: 7; n_estimators: 140;
#
# max_features: 80; max_depth: 7; n_estimators: 160;
#
# max_features: 80; max_depth: 10; n_estimators: 10;
#
# max_features: 80; max_depth: 10; n_estimators: 20;
#
# max_features: 80; max_depth: 10; n_estimators: 30;
#
# max_features: 80; max_depth: 10; n_estimators: 40;
#
# max_features: 80; max_depth: 10; n_estimators: 50;
#
# max_features: 80; max_depth: 10; n_estimators: 60;
#
# max_features: 80; max_depth: 10; n_estimators: 80;
#
# max_features: 80; max_depth: 10; n_estimators: 90;
#
# max_features: 80; max_depth: 10; n_estimators: 100;
#
# max_features: 80; max_depth: 10; n_estimators: 120;
#
# max_features: 80; max_depth: 10; n_estimators: 140;
#
# max_features: 80; max_depth: 10; n_estimators: 160;
#
# max_features: 80; max_depth: 12; n_estimators: 10;
#
# max_features: 80; max_depth: 12; n_estimators: 20;
#
# max_features: 80; max_depth: 12; n_estimators: 30;
#
# max_features: 80; max_depth: 12; n_estimators: 40;
#
# max_features: 80; max_depth: 12; n_estimators: 50;
#
# max_features: 80; max_depth: 12; n_estimators: 60;
#
# max_features: 80; max_depth: 12; n_estimators: 80;
#
# max_features: 80; max_depth: 12; n_estimators: 90;
#
# max_features: 80; max_depth: 12; n_estimators: 100;
#
# max_features: 80; max_depth: 12; n_estimators: 120;
#
# max_features: 80; max_depth: 12; n_estimators: 140;
#
# max_features: 80; max_depth: 12; n_estimators: 160;
#
# max_features: 80; max_depth: 15; n_estimators: 10;
#
# max_features: 80; max_depth: 15; n_estimators: 20;
#
# max_features: 80; max_depth: 15; n_estimators: 30;
#
# max_features: 80; max_depth: 15; n_estimators: 40;
#
# max_features: 80; max_depth: 15; n_estimators: 50;
#
# max_features: 80; max_depth: 15; n_estimators: 60;
#
# max_features: 80; max_depth: 15; n_estimators: 80;
#
# max_features: 80; max_depth: 15; n_estimators: 90;
#
# max_features: 80; max_depth: 15; n_estimators: 100;
#
# max_features: 80; max_depth: 15; n_estimators: 120;
#
# max_features: 80; max_depth: 15; n_estimators: 140;
#
# max_features: 80; max_depth: 15; n_estimators: 160;
#
# max_features: 80; max_depth: 18; n_estimators: 10;
#
# max_features: 80; max_depth: 18; n_estimators: 20;
#
# max_features: 80; max_depth: 18; n_estimators: 30;
#
# max_features: 80; max_depth: 18; n_estimators: 40;
#
# max_features: 80; max_depth: 18; n_estimators: 50;
#
# max_features: 80; max_depth: 18; n_estimators: 60;
#
# max_features: 80; max_depth: 18; n_estimators: 80;
#
# max_features: 80; max_depth: 18; n_estimators: 90;
#
# max_features: 80; max_depth: 18; n_estimators: 100;
#
# max_features: 80; max_depth: 18; n_estimators: 120;
#
# max_features: 80; max_depth: 18; n_estimators: 140;
#
# max_features: 80; max_depth: 18; n_estimators: 160;
#
# max_features: 80; max_depth: 20; n_estimators: 10;
#
# max_features: 80; max_depth: 20; n_estimators: 20;
#
# max_features: 80; max_depth: 20; n_estimators: 30;
#
# max_features: 80; max_depth: 20; n_estimators: 40;
#
# max_features: 80; max_depth: 20; n_estimators: 50;
#
# max_features: 80; max_depth: 20; n_estimators: 60;
#
# max_features: 80; max_depth: 20; n_estimators: 80;
#
# max_features: 80; max_depth: 20; n_estimators: 90;
#
# max_features: 80; max_depth: 20; n_estimators: 100;
#
# max_features: 80; max_depth: 20; n_estimators: 120;
#
# max_features: 80; max_depth: 20; n_estimators: 140;
#
# max_features: 80; max_depth: 20; n_estimators: 160;
#
# max_features: 10; max_depth: 5; n_estimators: 10;
#
# max_features: 10; max_depth: 5; n_estimators: 20;
#
# max_features: 10; max_depth: 5; n_estimators: 30;
#
# max_features: 10; max_depth: 5; n_estimators: 40;
#
# max_features: 10; max_depth: 5; n_estimators: 50;
#
# max_features: 10; max_depth: 5; n_estimators: 60;
#
# max_features: 10; max_depth: 5; n_estimators: 80;
#
# max_features: 10; max_depth: 5; n_estimators: 90;
#
# max_features: 10; max_depth: 5; n_estimators: 100;
#
# max_features: 10; max_depth: 5; n_estimators: 120;
#
# max_features: 10; max_depth: 5; n_estimators: 140;
#
# max_features: 10; max_depth: 5; n_estimators: 160;
#
# max_features: 10; max_depth: 7; n_estimators: 10;
#
# max_features: 10; max_depth: 7; n_estimators: 20;
#
# max_features: 10; max_depth: 7; n_estimators: 30;
#
# max_features: 10; max_depth: 7; n_estimators: 40;
#
# max_features: 10; max_depth: 7; n_estimators: 50;
#
# max_features: 10; max_depth: 7; n_estimators: 60;
#
# max_features: 10; max_depth: 7; n_estimators: 80;
#
# max_features: 10; max_depth: 7; n_estimators: 90;
#
# max_features: 10; max_depth: 7; n_estimators: 100;
#
# max_features: 10; max_depth: 7; n_estimators: 120;
#
# max_features: 10; max_depth: 7; n_estimators: 140;
#
# max_features: 10; max_depth: 7; n_estimators: 160;
#
# max_features: 10; max_depth: 10; n_estimators: 10;
#
# max_features: 10; max_depth: 10; n_estimators: 20;
#
# max_features: 10; max_depth: 10; n_estimators: 30;
# max_features: 10; max_depth: 10; n_estimators: 40;
#
# max_features: 10; max_depth: 10; n_estimators: 50;
#
# max_features: 10; max_depth: 10; n_estimators: 60;
#
# max_features: 10; max_depth: 10; n_estimators: 80;
#
# max_features: 10; max_depth: 10; n_estimators: 90;
#
# max_features: 10; max_depth: 10; n_estimators: 100;
#
# max_features: 10; max_depth: 10; n_estimators: 120;
#
# max_features: 10; max_depth: 10; n_estimators: 140;
#
# max_features: 10; max_depth: 10; n_estimators: 160;
#
# max_features: 10; max_depth: 12; n_estimators: 10;
#
# max_features: 10; max_depth: 12; n_estimators: 20;
#
# max_features: 10; max_depth: 12; n_estimators: 30;
#
# max_features: 10; max_depth: 12; n_estimators: 40;
#
# max_features: 10; max_depth: 12; n_estimators: 50;
#
# max_features: 10; max_depth: 12; n_estimators: 60;
#
# max_features: 10; max_depth: 12; n_estimators: 80;
#
# max_features: 10; max_depth: 12; n_estimators: 90;
#
# max_features: 10; max_depth: 12; n_estimators: 100;
#
# max_features: 10; max_depth: 12; n_estimators: 120;
#
# max_features: 10; max_depth: 12; n_estimators: 140;
#
# max_features: 10; max_depth: 12; n_estimators: 160;
#
# max_features: 10; max_depth: 15; n_estimators: 10;
#
# max_features: 10; max_depth: 15; n_estimators: 20;
#
# max_features: 10; max_depth: 15; n_estimators: 30;
#
# max_features: 10; max_depth: 15; n_estimators: 40;
#
# max_features: 10; max_depth: 15; n_estimators: 50;
#
# max_features: 10; max_depth: 15; n_estimators: 60;
#
# max_features: 10; max_depth: 15; n_estimators: 80;
#
# max_features: 10; max_depth: 15; n_estimators: 90;
#
# max_features: 10; max_depth: 15; n_estimators: 100;
#
# max_features: 10; max_depth: 15; n_estimators: 120;
#
# max_features: 10; max_depth: 15; n_estimators: 140;
#
# max_features: 10; max_depth: 15; n_estimators: 160;
#
# max_features: 10; max_depth: 18; n_estimators: 10;
#
# max_features: 10; max_depth: 18; n_estimators: 20;
#
# max_features: 10; max_depth: 18; n_estimators: 30;
#
# max_features: 10; max_depth: 18; n_estimators: 40;
#
# max_features: 10; max_depth: 18; n_estimators: 50;
#
# max_features: 10; max_depth: 18; n_estimators: 60;
#
# max_features: 10; max_depth: 18; n_estimators: 80;
#
# max_features: 10; max_depth: 18; n_estimators: 90;
#
# max_features: 10; max_depth: 18; n_estimators: 100;
#
# max_features: 10; max_depth: 18; n_estimators: 120;
#
# max_features: 10; max_depth: 18; n_estimators: 140;
#
# max_features: 10; max_depth: 18; n_estimators: 160;
#
# max_features: 10; max_depth: 20; n_estimators: 10;
#
# max_features: 10; max_depth: 20; n_estimators: 20;
#
# max_features: 10; max_depth: 20; n_estimators: 30;
#
# max_features: 10; max_depth: 20; n_estimators: 40;
#
# max_features: 10; max_depth: 20; n_estimators: 50;
#
# max_features: 10; max_depth: 20; n_estimators: 60;
#
# max_features: 10; max_depth: 20; n_estimators: 80;
#
# max_features: 10; max_depth: 20; n_estimators: 90;
#
# max_features: 10; max_depth: 20; n_estimators: 100;
#
# max_features: 10; max_depth: 20; n_estimators: 120;
#
# max_features: 10; max_depth: 20; n_estimators: 140;
#
# max_features: 10; max_depth: 20; n_estimators: 160;

# %%
get_best_settings(results_1_rp,results_2_rp)

# %%
best_RFs(results_1_rp,results_2_rp,'rp')
# Out:
# Normal best: 0.683828520812472 | max_features: 80; max_depth: 12; n_estimators: 10;
# Extended best: 0.6995253307038448 | max_features: 25; max_depth: 5; n_estimators: 10;
# Best difference: 0.178522036722764 | max_features: 7; max_depth: 5; n_estimators: 20;
# Normal feature space
# Coefficient of determination R^2: 0.3526340326994295
# Mean squared error:               0.03376319974358975
# Mean absolute error:              0.13876153846153846
# Root mean squared error:          0.18374765234851234
# Correlation Coefficient:          0.5972822538667238
#
#
# Extended feature space
# Coefficient of determination R^2: 0.32708078033033505
# Mean squared error:               0.03509592282051282
# Mean absolute error:              0.14166068376068375
# Root mean squared error:          0.18733905844887985
# Correlation Coefficient:          0.5756356719726347
# -------------------------------------------------------

# %%
Normal best: 0.683828520812472 | max_features: 80; max_depth: 12; n_estimators: 10;
Extended best: 0.6995253307038448 | max_features: 25; max_depth: 5; n_estimators: 10;
Best difference: 0.178522036722764 | max_features: 7; max_depth: 5; n_estimators: 20;
Normal feature space
Coefficient of determination R^2: 0.3526340326994295
Mean squared error:               0.03376319974358975
Mean absolute error:              0.13876153846153846
Root mean squared error:          0.18374765234851234
Correlation Coefficient:          0.5972822538667238


Extended feature space
Coefficient of determination R^2: 0.32708078033033505
Mean squared error:               0.03509592282051282
Mean absolute error:              0.14166068376068375
Root mean squared error:          0.18733905844887985
Correlation Coefficient:          0.5756356719726347

# %% [markdown]
# # Non-RP Genes

# %%
X,y,X2,y2 = get_data('rp')

mxf = [5,7,10,12,15,18,20,25,30,50,80,10]
md = [5,7,10,12,15,18,20]
n_est = [10,20,30,40,50,60,80,90,100,120,140,160]

results_1_nrp = np.zeros((len(mxf),len(md),len(n_est)))
results_2_nrp = np.zeros((len(mxf),len(md),len(n_est)))

f = FloatProgress(min=0, max=(len(mxf)*len(md)*len(n_est)))
display(f)


i = 0
for max_features in mxf:
    j = 0
    for max_depth in md:
        k = 0
        for n_estimators in n_est:            
            
            kf = KFold(n_splits=5,shuffle=True,random_state=0)

            rfr1 = ExtraTreesRegressor(n_estimators=n_estimators, 
                                        criterion='mse', 
                                        max_features=max_features, 
                                        max_depth=max_depth, 
                                        n_jobs=2,
                                        random_state=1337)

            rfr2 = ExtraTreesRegressor(n_estimators=n_estimators, 
                                        criterion='mse', 
                                        max_features=max_features, 
                                        max_depth=max_depth, 
                                        n_jobs=2,
                                        random_state=1337)

            predictions_rfr1 = cross_val_predict(rfr1,X=X,y=y,cv=kf)
            predictions_rfr2 = cross_val_predict(rfr2,X=X2,y=y2,cv=kf)
            
            print('max_features: {}; max_depth: {}; n_estimators: {};\n'.format(max_features,max_depth,n_estimators))

            print('Normal feature space')
            print_stats(y, predictions_rfr1)
            print('\n')
            print('Extended feature space')
            print_stats(y2, predictions_rfr2)
            print('-------------------------------------------------------\n')
            

            results_1_nrp[i][j][k]=np.corrcoef(y, predictions_rfr1)[0][1]
            results_2_nrp[i][j][k]=np.corrcoef(y2, predictions_rfr2)[0][1]
            
            f.value += 1
            
            k += 1
        j += 1
    i += 1
# Out:
# FloatProgress(value=0.0, max=1008.0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-153-8fd732378293> in <module>()
#      35
#      36             predictions_rfr1 = cross_val_predict(rfr1,X=X_nrp,y=y_nrp,cv=kf)
# ---> 37             predictions_rfr2 = cross_val_predict(rfr2,X=X_nrp_extended,y=y_nrp_extended,cv=kf)
#      38
#      39             print('max_features: {}; max_depth: {}; n_estimators: {};\n'.format(max_features,max_depth,n_estimators))
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in cross_val_predict(estimator, X, y, groups, cv, n_jobs, verbose, fit_params, pre_dispatch, method)
#     678     prediction_blocks = parallel(delayed(_fit_and_predict)(
#     679         clone(estimator), X, y, train, test, verbose, fit_params, method)
# --> 680         for train, test in cv.split(X, y, groups))
#     681
#     682     # Concatenate the predictions
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     623                 return False
#     624             else:
# --> 625                 self._dispatch(tasks)
#     626                 return True
#     627
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     586         dispatch_timestamp = time.time()
#     587         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 588         job = self._backend.apply_async(batch, callback=cb)
#     589         self._jobs.append(job)
#     590
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     109     def apply_async(self, func, callback=None):
#     110         """Schedule a func to be run"""
# --> 111         result = ImmediateResult(func)
#     112         if callback:
#     113             callback(result)
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     330         # Don't delay the application, to avoid keeping the input
#     331         # arguments in memory
# --> 332         self.results = batch()
#     333
#     334     def get(self):
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in _fit_and_predict(estimator, X, y, train, test, verbose, fit_params, method)
#     751         estimator.fit(X_train, **fit_params)
#     752     else:
# --> 753         estimator.fit(X_train, y_train, **fit_params)
#     754     func = getattr(estimator, method)
#     755     predictions = func(X_test)
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     326                     t, self, X, y, sample_weight, i, len(trees),
#     327                     verbose=self.verbose, class_weight=self.class_weight)
# --> 328                 for i, t in enumerate(trees))
#     329
#     330             # Collect newly grown trees
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     787                 # consumption.
#     788                 self._iterating = False
# --> 789             self.retrieve()
#     790             # Make sure that we get a last message telling us we are done
#     791             elapsed_time = time.time() - self._start_time
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     697             try:
#     698                 if getattr(self._backend, 'supports_timeout', False):
# --> 699                     self._output.extend(job.get(timeout=self.timeout))
#     700                 else:
#     701                     self._output.extend(job.get())
#
# ~/miniconda3/envs/mlp/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# ~/miniconda3/envs/mlp/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# ~/miniconda3/envs/mlp/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# ~/miniconda3/envs/mlp/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
get_best_settings(results_1_nrp,results_2_nrp)

# %%
best_RFs(results_1_nrp,results_2_nrp,'nrp')
# Out:
# Normal best: 0.0 | max_features: 5; max_depth: 5; n_estimators: 10;
# Extended best: 0.0 | max_features: 5; max_depth: 5; n_estimators: 10;
# Best difference: 0.0 | max_features: 5; max_depth: 5; n_estimators: 10;
# Normal feature space
# Coefficient of determination R^2: -0.17288754205125412
# Mean squared error:               0.06861558845509945
# Mean absolute error:              0.2250189466089466
# Root mean squared error:          0.2619457738828772
# Correlation Coefficient:          0.00026368969917265657
#
#
# Extended feature space
# Coefficient of determination R^2: -0.07264862214631762
# Mean squared error:               0.06275146915227865
# Mean absolute error:              0.20320011063011065
# Root mean squared error:          0.2505024334258625
# Correlation Coefficient:          0.03260708413153405
# -------------------------------------------------------

# %%
Normal best: 0.2969901764177368 | max_features: 25; max_depth: 5; n_estimators: 10;
Extended best: 0.40630448232918154 | max_features: 30; max_depth: 7; n_estimators: 20;
Best difference: 0.2582434619528223 | max_features: 30; max_depth: 7; n_estimators: 20;
Normal feature space
Coefficient of determination R^2: 0.2360352774266372
Mean squared error:               0.03984437679487179
Mean absolute error:              0.1488410256410256
Root mean squared error:          0.19961056283391365
Correlation Coefficient:          0.48848065665874996


Extended feature space
Coefficient of determination R^2: 0.38909635792549957
Mean squared error:               0.031861516874999996
Mean absolute error:              0.13109380341880345
Root mean squared error:          0.1784979464167585
Correlation Coefficient:          0.6250700537546936
