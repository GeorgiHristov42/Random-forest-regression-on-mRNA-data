# %%
from __future__ import print_function, division
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score, explained_variance_score, mean_absolute_error, mean_squared_error, adjusted_rand_score
from sklearn.model_selection import train_test_split, KFold, cross_val_predict
from sklearn.linear_model import LinearRegression, Lasso, LassoCV
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVR
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from ipywidgets import FloatProgress
from IPython.display import display
# %matplotlib inline

# %%
def fit_scatter(y_true, y_pred,filename=None,title=None):
    assert y_true.shape == y_pred.shape
    fig, ax = plt.subplots()
    m, b = np.polyfit(y_true, y_pred, 1)
    ax.scatter(y_true, y_pred, marker='o',color='b',label='RP genes')
    ax.plot(y_true, m*y_true + b,'--', color='g',lw=2,label='Pearson\'s R: {0:.3f}'.format(np.corrcoef(y_true, y_pred)[0][1]))
    ax.set_ylim(ymin=0,ymax=1)
    ax.legend(loc=4,fontsize=18)
    #ax.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], 'k--', lw=4,color='w')
    ax.set_xlabel('Observed AUC',fontsize=20)
    ax.set_ylabel('Predicted AUC',fontsize=20)
    if title is not None:
        ax.set_title('{}'.format(title),fontsize=22)
    if filename is not None:
        fig.savefig('images/{}.pdf'.format(filename))

# %%
def fit_scatter_nrp(y_true, y_pred,filename=None,title=None):
    assert y_true.shape == y_pred.shape
    fig, ax = plt.subplots()
    plt.style.use('ggplot')
    m, b = np.polyfit(y_true, y_pred, 1)
    ax.scatter(y_true, y_pred, marker='o',color='r',label='nonRP genes')
    ax.plot(y_true, m*y_true + b,'--', color='g',lw=2,label='Pearson\'s R: {0:.3f}'.format(np.corrcoef(y_true, y_pred)[0][1]))
    ax.set_ylim(ymin=0,ymax=1)
    ax.legend(loc=4,fontsize=18)
    #ax.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], 'k--', lw=4,color='w')
    ax.set_xlabel('Observed AUC',fontsize=20)
    ax.set_ylabel('Predicted AUC',fontsize=20)
    if title is not None:
        ax.set_title('{}'.format(title),fontsize=22)
    if filename is not None:
        fig.savefig('images/{}.pdf'.format(filename))

# %%
def fit_scatter_multi(y_true1,y_true2, y_pred1, y_pred2,filename=None,title=None):
#     assert y_true.shape == y_pred.shape
    fig, ax = plt.subplots()
    plt.style.use('ggplot')
    ax.scatter(y_true1, y_pred1,color='blue',label='RP genes')
    ax.scatter(y_true2, y_pred2, color='red',label='nonRP genes')
    
    y_true = np.concatenate((y_true1,y_true2),axis=0)
    y_pred = np.concatenate((y_pred1,y_pred2),axis=0)
    
    m, b = np.polyfit(y_true, y_pred, 1)
    ax.plot(y_true, m*y_true + b,linestyle='dashed', color='g',lw=2,label='Pearson\'s R: {0:.3f}'.format(np.corrcoef(y_true, y_pred)[0][1]))
    ax.set_ylim(ymin=0,ymax=1)
    ax.legend(loc=4,fontsize=16,facecolor='white')
    #ax.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], 'k--', lw=4,color='w')
    ax.set_xlabel('Observed AUC',fontsize=20)
    ax.set_ylabel('Predicted AUC',fontsize=20)
    if title is not None:
        ax.set_title('{}'.format(title),fontsize=22)
    if filename is not None:
        plt.savefig('images/{}.pdf'.format(filename))

# %%
def plot_importance(feature_importance,names,filename=None):
    plt.figure(figsize=(6, 8))
    plt.style.use('ggplot')
    # make importances relative to max importance
    feature_importance = 100.0 * (feature_importance / feature_importance.max())
    sorted_idx = np.argsort(feature_importance)
    pos = np.arange(sorted_idx.shape[0]) + .5
    
    yy = pos[:10]
    ft = (feature_importance[sorted_idx])[:10]
    ft = 100.0 * (ft / ft.max())
    
    plt.barh(yy, ft, align='center',color='b')
    plt.yticks(yy, (names[sorted_idx])[:10])
    plt.xlabel('Relative Importance')
    plt.title('RF variable importance')
    plt.tight_layout()
    if filename is not None:
        plt.savefig('images/{}.pdf'.format(filename))
    plt.show()

# %%
# def plot_importance(feature_importance,names,filename=None):
#     plt.figure(figsize=(6, 8))
#     plt.style.use('ggplot')
#     # make importances relative to max importance
#     feature_importance = 100.0 * (feature_importance / feature_importance.max())
#     sorted_idx = np.argsort(feature_importance)
#     pos = np.arange(sorted_idx.shape[0]) + .5
#     plt.barh(pos, feature_importance[sorted_idx], align='center',color='b')
#     plt.yticks(pos, names[sorted_idx])
#     plt.xlabel('Relative Importance')
#     plt.title('RF variable importance')
#     plt.tight_layout()
#     if filename is not None:
#         plt.savefig('images/{}.pdf'.format(filename))
#     plt.show()

# %%
def plot_imp(feature_importance,names):
    print(names)
    feature_importance = 100.0 * (feature_importance / feature_importance.max())
    sorted_idx = np.argsort(feature_importance)
    pos = np.arange(sorted_idx.shape[0]) + .5
    
    fig2, ax2 = plt.subplots(figsize=(10,15))
    ax2.barh(pos, feature_importance[sorted_idx], align='center')
    ax2.set_yticks(pos, names[sorted_idx])
    ax2.set_xlabel('RF feature importance')

# %%
def print_stats(true,predictions):
    print('Coefficient of determination R^2: {}'.format(r2_score(true, predictions)))
    print('Mean squared error:               {}'.format(mean_squared_error(true, predictions)))
    print('Mean absolute error:              {}'.format(mean_absolute_error(true, predictions)))
    print('Root mean squared error:          {}'.format(np.sqrt(mean_squared_error(true, predictions))))
    print('Correlation Coefficient:          {}'.format(np.corrcoef(true, predictions)[0][1]))

# %%
def get_best_settings(results_1,results_2):
    best_result_1 = results_1[0][0][0]
    best_result_2 = results_2[0][0][0]
    best_difference = results_2[0][0][0] - results_1[0][0][0]

    best_i_1=0
    best_j_1=0
    best_k_1=0

    best_i_2=0
    best_j_2=0
    best_k_2=0

    best_i_3=0
    best_j_3=0
    best_k_3=0
    

    mxf = [2,4,5,7,10,12,15,18,20,30]
    md = [5,7,10,12,15,18,20]
    n_est = [10,20,30,40,50,60,80,90,200,300,500]
    
    for i in range(len(mxf)):
        for j in range(len(md)):
            for k in range(len(n_est)):
                if best_result_1 < results_1[i][j][k]:
                    best_result_1 = results_1[i][j][k]
                    best_i_1=i
                    best_j_1=j
                    best_k_1=k
                if best_result_2 < results_2[i][j][k]:
                    best_result_2 = results_2[i][j][k]
                    best_i_2=i
                    best_j_2=j
                    best_k_2=k
                if best_difference < results_2[i][j][k] - results_1[i][j][k]:
                    best_difference = results_2[i][j][k] - results_1[i][j][k]
                    best_i_3=i
                    best_j_3=j
                    best_k_3=k

#     print('{} {} {} : {}'.format(best_i_1,best_j_1,best_k_1,best_result_1))
#     print('{} {} {} : {}'.format(best_i_2,best_j_2,best_k_2,best_result_2))
#     print('{} {} {} : {}'.format(best_i_3,best_j_3,best_k_3,best_difference))

    print('Normal best: {} | max_features: {}; max_depth: {}; n_estimators: {};'.format(best_result_1,mxf[best_i_1],md[best_j_1],n_est[best_k_1]))
    print('Extended best: {} | max_features: {}; max_depth: {}; n_estimators: {};'.format(best_result_2,mxf[best_i_2],md[best_j_2],n_est[best_k_2]))
    print('Best difference: {} | max_features: {}; max_depth: {}; n_estimators: {};'.format(best_difference,mxf[best_i_3],md[best_j_3],n_est[best_k_3]))
    
    return mxf[best_i_1],md[best_j_1],n_est[best_k_1],mxf[best_i_2],md[best_j_2],n_est[best_k_2]

# %%
data_path = os.path.join(os.getcwd(), 'datasets', 'features.csv')
data_path_rp = os.path.join(os.getcwd(), 'datasets', 'rp_features.csv')
data_path_nrp = os.path.join(os.getcwd(), 'datasets', 'nrp_features.csv')

data_path_extended = os.path.join(os.getcwd(), 'datasets', 'extended_features.csv')
data_path_rp_extended = os.path.join(os.getcwd(), 'datasets', 'rp_extended_features.csv')
data_path_nrp_extended = os.path.join(os.getcwd(), 'datasets', 'nrp_extended_features.csv')

data_path_cut = os.path.join(os.getcwd(), 'datasets', 'features_cut.csv')
data_path_extended_cut = os.path.join(os.getcwd(), 'datasets', 'extended_features_cut.csv')

data_path_rp_cut = os.path.join(os.getcwd(), 'datasets', 'rp_features_cut.csv')
data_path_nrp_cut = os.path.join(os.getcwd(), 'datasets', 'nrp_features_cut.csv')
data_path_rp_extended_cut = os.path.join(os.getcwd(), 'datasets', 'rp_extended_features_cut.csv')
data_path_nrp_extended_cut = os.path.join(os.getcwd(), 'datasets', 'nrp_extended_features_cut.csv')

gene_features = pd.read_csv(data_path, delimiter = ',')
rp_gene_features = pd.read_csv(data_path_rp, delimiter = ',')
nrp_gene_features = pd.read_csv(data_path_nrp, delimiter = ',')

extended_features = pd.read_csv(data_path_extended, delimiter = ',')
rp_extended_features = pd.read_csv(data_path_rp_extended, delimiter = ',')
nrp_extended_features = pd.read_csv(data_path_nrp_extended, delimiter = ',')

gene_features_cut = pd.read_csv(data_path_cut, delimiter = ',')
extended_features_cut = pd.read_csv(data_path_extended_cut, delimiter = ',')
rp_features_cut = pd.read_csv(data_path_rp_cut, delimiter = ',')
rp_extended_features_cut = pd.read_csv(data_path_rp_extended_cut, delimiter = ',')
nrp_features_cut = pd.read_csv(data_path_nrp_cut, delimiter = ',')
nrp_extended_features_cut = pd.read_csv(data_path_nrp_extended_cut, delimiter = ',')

print('Number of data points: {}. Number of attributes: {}'.format(gene_features.shape[0],gene_features.shape[1]))
print('Number of data points: {}. Number of attributes: {}'.format(extended_features.shape[0],extended_features.shape[1]))
print('Number of data points: {}. Number of attributes: {}'.format(rp_gene_features.shape[0],rp_gene_features.shape[1]))
print('Number of data points: {}. Number of attributes: {}'.format(rp_extended_features.shape[0],rp_extended_features.shape[1]))
print('Number of data points: {}. Number of attributes: {}'.format(nrp_gene_features.shape[0],nrp_gene_features.shape[1]))
print('Number of data points: {}. Number of attributes: {}'.format(nrp_extended_features.shape[0],nrp_extended_features.shape[1]))
print('Number of data points: {}. Number of attributes: {}'.format(gene_features_cut.shape[0],gene_features_cut.shape[1]))
print('Number of data points: {}. Number of attributes: {}'.format(extended_features_cut.shape[0],extended_features_cut.shape[1]))
# Out:
# Number of data points: 117. Number of attributes: 101
# Number of data points: 117. Number of attributes: 106
# Number of data points: 84. Number of attributes: 101
# Number of data points: 84. Number of attributes: 106
# Number of data points: 33. Number of attributes: 101
# Number of data points: 33. Number of attributes: 106
# Number of data points: 117. Number of attributes: 21
# Number of data points: 117. Number of attributes: 26

# %%
def get_data(dataset):
    
    X = gene_features.drop(['ORG', 'Gene','AUC'], axis=1)
    X_cut = gene_features_cut.drop(['ORG', 'Gene','AUC'], axis=1)
    y = gene_features['AUC']

    X_rp = rp_gene_features.drop(['ORG', 'Gene','AUC'], axis=1)
    X_rp_cut = rp_features_cut.drop(['ORG', 'Gene','AUC'], axis=1)
    y_rp = rp_gene_features['AUC']

    X_nrp = nrp_gene_features.drop(['ORG', 'Gene','AUC'], axis=1)
    X_nrp_cut = nrp_features_cut.drop(['ORG', 'Gene','AUC'], axis=1)
    y_nrp = nrp_gene_features['AUC']

    X_extended = extended_features.drop(['ORG', 'Gene','AUC'], axis=1)
    X_extended_cut = extended_features_cut.drop(['ORG', 'Gene','AUC'], axis=1)
    y_extended = extended_features['AUC']

    X_rp_extended = rp_extended_features.drop(['ORG', 'Gene','AUC'], axis=1)
    X_rp_extended_cut = rp_extended_features_cut.drop(['ORG', 'Gene','AUC'], axis=1)
    y_rp_extended = rp_extended_features['AUC']

    X_nrp_extended = nrp_extended_features.drop(['ORG', 'Gene','AUC'], axis=1)
    X_nrp_extended_cut = nrp_extended_features_cut.drop(['ORG', 'Gene','AUC'], axis=1)
    y_nrp_extended = nrp_extended_features['AUC']
    
    if dataset == 'full':
        return X,y,X_extended,y_extended
    elif dataset == 'rp':
        return X_rp,y_rp,X_rp_extended,y_rp_extended
    elif dataset == 'nrp':
        return X_nrp,y_nrp,X_nrp_extended,y_nrp_extended
    elif dataset == 'cut':
        return X_cut,y,X_extended_cut,y_extended
    elif dataset == 'rp_cut':
        return X_rp_cut,y_rp,X_rp_extended_cut,y_rp_extended
    elif dataset == 'nrp_cut':
        return X_nrp_cut,y_nrp,X_nrp_extended_cut,y_nrp_extended
    else:
        return None, None, None, None

# %%
def get_variable_names(dataset):
    
    if dataset == 'full':
        return gene_features.drop(['ORG','Gene','AUC'], axis=1).columns, extended_features.drop(['ORG','Gene','AUC'], axis=1).columns
    elif dataset == 'cut':
        return gene_features_cut.drop(['ORG','Gene','AUC'], axis=1).columns, extended_features_cut.drop(['ORG','Gene','AUC'], axis=1).columns
    else:
        return None, None, None, None

# %%
kf = KFold(n_splits=5,shuffle=True,random_state=0)

# %%
X,y,X2,y2 = get_data('full')

lr1 = LinearRegression()
lr2 = LinearRegression()

predictions1 = cross_val_predict(lr1,X,y=y,cv=kf)
predictions2 = cross_val_predict(lr1,X2,y=y2,cv=kf)

print('Data')
print_stats(y,predictions1)
print('\n')
print('Extended Data')
print_stats(y2,predictions2)
# Out:
# Data
# Coefficient of determination R^2: -7.218302015333855
# Mean squared error:               0.428623354505183
# Mean absolute error:              0.4702581683241454
# Root mean squared error:          0.6546933285937646
# Correlation Coefficient:          0.15630895126957536
#
#
# Extended Data
# Coefficient of determination R^2: -5.124905342449793
# Mean squared error:               0.31944280813837916
# Mean absolute error:              0.36293982808684455
# Root mean squared error:          0.5651927176975825
# Correlation Coefficient:          0.22134989868329735

# %%
X,y,X2,y2 = get_data('rp_full')

rfr1 = ExtraTreesRegressor(random_state=1337)
rfr2 = ExtraTreesRegressor(random_state=1337)

kf = KFold(n_splits=5,shuffle=True,random_state=0)
predictions_rfr1 = cross_val_predict(rfr1,X,y=y,cv=kf)
predictions_rfr2 = cross_val_predict(rfr2,X2,y=y2,cv=kf)

print('Data')
print_stats(y,predictions_rfr1)
print('\n')
print('Extended Data')
print_stats(y2,predictions_rfr2)

rfr1.fit(X,y)
rfr2.fit(X2,y2)

names,names2 = get_variable_names('full')
plot_importance(rfr1.feature_importances_,names,'foo')
plot_importance(rfr2.feature_importances_,names2,'foo')
# Out:
# Data
# Coefficient of determination R^2: 0.14341293973709657
# Mean squared error:               0.025373674642857145
# Mean absolute error:              0.11562261904761906
# Root mean squared error:          0.15929116310347272
# Correlation Coefficient:          0.43478418511647643
#
#
# Extended Data
# Coefficient of determination R^2: 0.23026901848935022
# Mean squared error:               0.02280083880952381
# Mean absolute error:              0.10924285714285716
# Root mean squared error:          0.15099946625575802
# Correlation Coefficient:          0.49358104633453104
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-ad55391985e4> in <module>()
#      18
#      19 names,names2 = get_variable_names('cut')
# ---> 20 plot_importance(rfr1.feature_importances_,names)
#      21 plot_importance(rfr2.feature_importances_,names2)
#
# TypeError: plot_importance() missing 1 required positional argument: 'filename'

# %% [markdown]
# # Full Set

# %%
def best_RFs(results1,results2,dataset):
     
    X,y,X2,y2 = get_data(dataset)
    mxf1, md1, n_est1, mxf2, md2, n_est2 = get_best_settings(results1,results2)
    
    kf = KFold(n_splits=5,shuffle=True,random_state=0)
    
    rfr1 = ExtraTreesRegressor(n_estimators=n_est1, 
                                criterion='mse', 
                                max_features=mxf1, 
                                max_depth=md1, 
                                n_jobs=2,
                                random_state=1337)

    rfr2 = ExtraTreesRegressor(n_estimators=n_est2, 
                                criterion='mse', 
                                max_features=mxf2, 
                                max_depth=md2, 
                                n_jobs=2,
                                random_state=1337)

    predictions_rfr1 = cross_val_predict(rfr1,X,y=y,cv=kf)
    predictions_rfr2 = cross_val_predict(rfr2,X2,y=y2,cv=kf)

    print('Normal feature space')
    print_stats(y, predictions_rfr1)
    print('\n')
    print('Extended feature space')
    print_stats(y2, predictions_rfr2)
    print('-------------------------------------------------------\n')
         
    settings = 'max_features: {}; max_depth: {}; n_estimators: {};'.format(mxf1,md1,n_est1)
          
    rfr1.fit(X,y)
    fig, ax1 = plt.subplots(figsize=(20,6))
    xx = np.arange(len(rfr1.feature_importances_))
    ax1.bar(xx, rfr1.feature_importances_)
    ax1.set_xticks(xx)
    ax1.set_xticklabels(gene_features_cut.drop(['ORG','Gene','AUC'], axis=1).columns, rotation='vertical')
    ax1.set_title('Normal RF: {} -- {}'.format(settings,np.corrcoef(y, predictions_rfr1)[0][1]))

    settings = 'max_features: {}; max_depth: {}; n_estimators: {};'.format(mxf2,md2,n_est2)
    rfr2.fit(X2,y2)
    fig2, ax2 = plt.subplots(figsize=(20,6))
    xx = np.arange(len(rfr2.feature_importances_))
    ax2.bar(xx, rfr2.feature_importances_)
    ax2.set_xticks(xx)
    ax2.set_xticklabels(extended_features_cut.drop(['ORG','Gene','AUC'], axis=1).columns, rotation='vertical')
    ax2.set_title('Extended RF : {} -- {}'.format(settings,np.corrcoef(y2, predictions_rfr2)[0][1]))

# %%
X,y,X2,y2 = get_data('full')
print('echo')
mxf = [2,4,5,7,10,12,15,18,20,30]
md = [5,7,10,12,15,18,20]
n_est = [10,20,30,40,50,60,80,90,200,300,500]

results_1_full = np.zeros((len(mxf),len(md),len(n_est)))
results_2_full = np.zeros((len(mxf),len(md),len(n_est)))

f = FloatProgress(min=0, max=(len(mxf)*len(md)*len(n_est)))
display(f)


i = 0
for max_features in mxf:
    j = 0
    for max_depth in md:
        k = 0
        for n_estimators in n_est:            
            
            kf = KFold(n_splits=5,shuffle=True,random_state=0)

            rfr1 = ExtraTreesRegressor(n_estimators=n_estimators, 
                                        criterion='mse', 
                                        max_features=max_features, 
                                        max_depth=max_depth, 
                                        n_jobs=2,
                                        random_state=1337)

            rfr2 = ExtraTreesRegressor(n_estimators=n_estimators, 
                                        criterion='mse', 
                                        max_features=max_features, 
                                        max_depth=max_depth, 
                                        n_jobs=2,
                                        random_state=1337)

            predictions_rfr1 = cross_val_predict(rfr1,X=X,y=y,cv=kf)
            predictions_rfr2 = cross_val_predict(rfr2,X=X2,y=y2,cv=kf)
            
            print('max_features: {}; max_depth: {}; n_estimators: {};\n'.format(max_features,max_depth,n_estimators))

            print('Normal feature space')
            print_stats(y, predictions_rfr1)
            print('\n')
            print('Extended feature space')
            print_stats(y2, predictions_rfr2)
            print('-------------------------------------------------------\n')
            

            results_1_full[i][j][k]=np.corrcoef(y, predictions_rfr1)[0][1]
            results_2_full[i][j][k]=np.corrcoef(y2, predictions_rfr2)[0][1]
            
            f.value += 1
            
            k += 1
        j += 1
    i += 1
# Out:
# echo
# FloatProgress(value=0.0, max=1008.0)
# max_features: 5; max_depth: 5; n_estimators: 10;
#
# Normal feature space
# Coefficient of determination R^2: 0.3852018216398875
# Mean squared error:               0.03206463537853839
# Mean absolute error:              0.13508527782261703
# Root mean squared error:          0.1790660084397326
# Correlation Coefficient:          0.6262334345069076
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3957114993898655
# Mean squared error:               0.031516505932387695
# Mean absolute error:              0.1347955201383559
# Root mean squared error:          0.1775288875997022
# Correlation Coefficient:          0.6403725635378434
# -------------------------------------------------------
#
# max_features: 5; max_depth: 5; n_estimators: 20;
#
# Normal feature space
# Coefficient of determination R^2: 0.4053565154042843
# Mean squared error:               0.031013472688946053
# Mean absolute error:              0.13336332459706582
# Root mean squared error:          0.17610642432616153
# Correlation Coefficient:          0.6511617290843476
#
#
# Extended feature space
# Coefficient of determination R^2: 0.42011651450603604
# Mean squared error:               0.030243668863814986
# Mean absolute error:              0.13390870385266757
# Root mean squared error:          0.17390706961999844
# Correlation Coefficient:          0.6724395312382889
# -------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-badeb52459e7> in <module>()
#      35                                         random_state=1337)
#      36
# ---> 37             predictions_rfr1 = cross_val_predict(rfr1,X=X,y=y,cv=kf)
#      38             predictions_rfr2 = cross_val_predict(rfr2,X=X2,y=y2,cv=kf)
#      39
#
# ~/miniconda3/envs/mlp/lib/python3.5/site-packages/sklearn/model_selection/_validation.py in cross_val_predict(estimator, X, y, groups, cv, n_jobs, verbose, fit_params, pre_dispatch, method)
#     678     prediction_blocks = parallel(delayed(_fit_and_predict)(
#     679         clone(estimator), X, y, train, test, verbose, fit_params, method)
# --> 680         for train, test in cv.split(X, y, groups))
#     681
#     682     # Concatenate the predictions
#
# ~/miniconda3/envs/mlp/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# ~/miniconda3/envs/mlp/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     623                 return False
#     624             else:
# --> 625                 self._dispatch(tasks)
#     626                 return True
#     627
#
# ~/miniconda3/envs/mlp/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     586         dispatch_timestamp = time.time()
#     587         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 588         job = self._backend.apply_async(batch, callback=cb)
#     589         self._jobs.append(job)
#     590
#
# ~/miniconda3/envs/mlp/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     109     def apply_async(self, func, callback=None):
#     110         """Schedule a func to be run"""
# --> 111         result = ImmediateResult(func)
#     112         if callback:
#     113             callback(result)
#
# ~/miniconda3/envs/mlp/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     330         # Don't delay the application, to avoid keeping the input
#     331         # arguments in memory
# --> 332         self.results = batch()
#     333
#     334     def get(self):
#
# ~/miniconda3/envs/mlp/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# ~/miniconda3/envs/mlp/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# ~/miniconda3/envs/mlp/lib/python3.5/site-packages/sklearn/model_selection/_validation.py in _fit_and_predict(estimator, X, y, train, test, verbose, fit_params, method)
#     751         estimator.fit(X_train, **fit_params)
#     752     else:
# --> 753         estimator.fit(X_train, y_train, **fit_params)
#     754     func = getattr(estimator, method)
#     755     predictions = func(X_test)
#
# ~/miniconda3/envs/mlp/lib/python3.5/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     326                     t, self, X, y, sample_weight, i, len(trees),
#     327                     verbose=self.verbose, class_weight=self.class_weight)
# --> 328                 for i, t in enumerate(trees))
#     329
#     330             # Collect newly grown trees
#
# ~/miniconda3/envs/mlp/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     787                 # consumption.
#     788                 self._iterating = False
# --> 789             self.retrieve()
#     790             # Make sure that we get a last message telling us we are done
#     791             elapsed_time = time.time() - self._start_time
#
# ~/miniconda3/envs/mlp/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     697             try:
#     698                 if getattr(self._backend, 'supports_timeout', False):
# --> 699                     self._output.extend(job.get(timeout=self.timeout))
#     700                 else:
#     701                     self._output.extend(job.get())
#
# ~/miniconda3/envs/mlp/lib/python3.5/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# ~/miniconda3/envs/mlp/lib/python3.5/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# ~/miniconda3/envs/mlp/lib/python3.5/threading.py in wait(self, timeout)
#     547             signaled = self._flag
#     548             if not signaled:
# --> 549                 signaled = self._cond.wait(timeout)
#     550             return signaled
#     551
#
# ~/miniconda3/envs/mlp/lib/python3.5/threading.py in wait(self, timeout)
#     291         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     292             if timeout is None:
# --> 293                 waiter.acquire()
#     294                 gotit = True
#     295             else:
#
# KeyboardInterrupt:

# %%
get_best_settings(results_1_full,results_2_full)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-114-6af1c8ba1df9> in <module>()
# ----> 1 get_best_settings(results_1_full,results_2_full)
#
# NameError: name 'results_1_full' is not defined

# %% [markdown]
# Normal best: 0.6606799891294596 | max_features: 50; max_depth: 12; n_estimators: 20;
#
# Extended best: 0.643178381615747 | max_features: 20; max_depth: 7; n_estimators: 100;
#
# Best difference: 0.0855855290853309 | max_features: 12; max_depth: 12; n_estimators: 10;

# %%
best_RFs(results_1_full,results_2_full,'full')
# Out:
# Normal best: 0.6839871870653883 | max_features: 12; max_depth: 7; n_estimators: 40;
# Extended best: 0.695538111479249 | max_features: 5; max_depth: 7; n_estimators: 50;
# Best difference: 0.08235234031060501 | max_features: 12; max_depth: 5; n_estimators: 20;
# Normal feature space
# Coefficient of determination R^2: 0.46275664633060276
# Mean squared error:               0.02801978413615613
# Mean absolute error:              0.1249529426526229
# Root mean squared error:          0.16739111128180054
# Correlation Coefficient:          0.6839871870653883
#
#
# Extended feature space
# Coefficient of determination R^2: 0.46177284867054846
# Mean squared error:               0.028071093841302037
# Mean absolute error:              0.12581442108330093
# Root mean squared error:          0.1675443041147685
# Correlation Coefficient:          0.6955381114792492
# -------------------------------------------------------

# %%
#BEST FULL

# Normal best: 0.656753357271128 | max_features: 12; max_depth: 12; n_estimators: 40;
# Extended best: 0.6469918336286258 | max_features: 20; max_depth: 18; n_estimators: 20;

# Normal best: 0.6839871870653883 | max_features: 12; max_depth: 7; n_estimators: 40;
# Extended best: 0.695538111479249 | max_features: 5; max_depth: 7; n_estimators: 50;

X,y,X2,y2 = get_data('full')

rfr1 = ExtraTreesRegressor(n_estimators=40, 
                            criterion='mse', 
                            max_features=12, 
                            max_depth=12, 
                            n_jobs=2,
                            random_state=1337)

rfr2 = ExtraTreesRegressor(n_estimators=20, 
                            criterion='mse', 
                            max_features=20, 
                            max_depth=18, 
                            n_jobs=2,
                            random_state=1337)

kf = KFold(n_splits=5,shuffle=True,random_state=0)
predictions_rfr1 = cross_val_predict(rfr1,X,y=y,cv=kf)
predictions_rfr2 = cross_val_predict(rfr2,X2,y=y2,cv=kf)

fit_scatter(y,predictions_rfr1)
fit_scatter(y,predictions_rfr2)
print('Data')
print_stats(y,predictions_rfr1)
print('\n')
print('Extended Data')
print_stats(y2,predictions_rfr2)

rfr1.fit(X,y)
rfr2.fit(X2,y2)

names,names2 = get_variable_names('full')
plot_importance(rfr1.feature_importances_,names,'full')
plot_importance(rfr2.feature_importances_,names2,'full_ext')
# Out:
# Data
# Coefficient of determination R^2: 0.4088825365042926
# Mean squared error:               0.03082957399684131
# Mean absolute error:              0.13158937717690875
# Root mean squared error:          0.1755835242750336
# Correlation Coefficient:          0.656753357271128
#
#
# Extended Data
# Coefficient of determination R^2: 0.41094146679533605
# Mean squared error:               0.030722191035447002
# Mean absolute error:              0.13179640788224123
# Root mean squared error:          0.17527746870447156
# Correlation Coefficient:          0.6469918336286259
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-1d800cd5df19> in <module>()
#      36
#      37 names,names2 = get_variable_names('full')
# ---> 38 plot_importance(rfr1.feature_importances_,names,'full')
#      39 plot_importance(rfr2.feature_importances_,names2,'full_ext')
#
# <ipython-input-24-a9f3db3788d5> in plot_importance(feature_importance, names, filename)
#       6     sorted_idx = np.argsort(feature_importance)
#       7     pos = np.arange(sorted_idx.shape[0]) + .5
# ----> 8     plt.barh(pos, feature_importance[sorted_idx][0:10], align='center',color='b')
#       9     plt.yticks(pos, names[sorted_idx][0:10])
#      10     plt.xlabel('Relative Importance')
#
# ~/miniconda3/envs/mlp/lib/python3.5/site-packages/matplotlib/pyplot.py in barh(*args, **kwargs)
#    2788                       mplDeprecation)
#    2789     try:
# -> 2790         ret = ax.barh(*args, **kwargs)
#    2791     finally:
#    2792         ax._hold = washold
#
# ~/miniconda3/envs/mlp/lib/python3.5/site-packages/matplotlib/axes/_axes.py in barh(self, *args, **kwargs)
#    2476         kwargs.setdefault('orientation', 'horizontal')
#    2477         patches = self.bar(x=left, height=height, width=width,
# -> 2478                            bottom=y, **kwargs)
#    2479         return patches
#    2480
#
# ~/miniconda3/envs/mlp/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/miniconda3/envs/mlp/lib/python3.5/site-packages/matplotlib/axes/_axes.py in bar(self, *args, **kwargs)
#    2231         x, height, width, y, linewidth = np.broadcast_arrays(
#    2232             # Make args iterable too.
# -> 2233             np.atleast_1d(x), height, width, y, linewidth)
#    2234
#    2235         # Now that units have been converted, set the tick locations.
#
# ~/miniconda3/envs/mlp/lib/python3.5/site-packages/numpy/lib/stride_tricks.py in broadcast_arrays(*args, **kwargs)
#     247     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     248
# --> 249     shape = _broadcast_shape(*args)
#     250
#     251     if all(array.shape == shape for array in args):
#
# ~/miniconda3/envs/mlp/lib/python3.5/site-packages/numpy/lib/stride_tricks.py in _broadcast_shape(*args)
#     182     # use the old-iterator because np.nditer does not handle size 0 arrays
#     183     # consistently
# --> 184     b = np.broadcast(*args[:32])
#     185     # unfortunately, it cannot handle 32 or more arguments directly
#     186     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %% [markdown]
# ## MSE Results
#
# Normal best: 0.6839871870653883 | max_features: 12; max_depth: 7; n_estimators: 40;
#
# Extended best: 0.695538111479249 | max_features: 5; max_depth: 7; n_estimators: 50;
#
# Best difference: 0.08235234031060501 | max_features: 12; max_depth: 5; n_estimators: 20;
#
# Normal feature space
# Coefficient of determination R^2: 0.46275664633060276
# Mean squared error:               0.02801978413615613
# Mean absolute error:              0.1249529426526229
# Root mean squared error:          0.16739111128180054
# Correlation Coefficient:          0.6839871870653883
#
#
# Extended feature space
# Coefficient of determination R^2: 0.46177284867054846
# Mean squared error:               0.028071093841302037
# Mean absolute error:              0.12581442108330093
# Root mean squared error:          0.1675443041147685
# Correlation Coefficient:          0.6955381114792492

# %% [markdown]
# # RP Genes

# %%
X,y,X2,y2 = get_data('rp')

mxf = [5,7,10,12,15,18,20,30]
md = [5,7,10,12,15,18,20]
n_est = [10,20,30,40,50,60,80,90,100,120,140,160,200,300,500]

results_1_rp = np.zeros((len(mxf),len(md),len(n_est)))
results_2_rp = np.zeros((len(mxf),len(md),len(n_est)))

f = FloatProgress(min=0, max=(len(mxf)*len(md)*len(n_est)))
display(f)


i = 0
for max_features in mxf:
    j = 0
    for max_depth in md:
        k = 0
        for n_estimators in n_est:            
            
            kf = KFold(n_splits=5,shuffle=True,random_state=0)

            rfr1 = ExtraTreesRegressor(n_estimators=n_estimators, 
                                        criterion='mse', 
                                        max_features=max_features, 
                                        max_depth=max_depth, 
                                        n_jobs=2,
                                        random_state=1337)

            rfr2 = ExtraTreesRegressor(n_estimators=n_estimators, 
                                        criterion='mse', 
                                        max_features=max_features, 
                                        max_depth=max_depth, 
                                        n_jobs=2,
                                        random_state=1337)

            predictions_rfr1 = cross_val_predict(rfr1,X=X,y=y,cv=kf)
            predictions_rfr2 = cross_val_predict(rfr2,X=X2,y=y2,cv=kf)
            
            print('max_features: {}; max_depth: {}; n_estimators: {};\n'.format(max_features,max_depth,n_estimators))

            print('Normal feature space')
            print_stats(y, predictions_rfr1)
            print('\n')
            print('Extended feature space')
            print_stats(y2, predictions_rfr2)
            print('-------------------------------------------------------\n')
            

            results_1_rp[i][j][k]=np.corrcoef(y, predictions_rfr1)[0][1]
            results_2_rp[i][j][k]=np.corrcoef(y2, predictions_rfr2)[0][1]
            
            f.value += 1
            
            k += 1
        j += 1
    i += 1
# Out:
# FloatProgress(value=0.0, max=840.0)
# max_features: 5; max_depth: 5; n_estimators: 10;
#
# Normal feature space
# Coefficient of determination R^2: 0.10027375795449511
# Mean squared error:               0.02665153606954604
# Mean absolute error:              0.11646231505372562
# Root mean squared error:          0.1632529818090501
# Correlation Coefficient:          0.3191415954848009
#
#
# Extended feature space
# Coefficient of determination R^2: 0.25272289873455667
# Mean squared error:               0.02213571382895653
# Mean absolute error:              0.11075498383257029
# Root mean squared error:          0.1487807575896713
# Correlation Coefficient:          0.5441958462229599
# -------------------------------------------------------
#
# max_features: 5; max_depth: 5; n_estimators: 20;
#
# Normal feature space
# Coefficient of determination R^2: 0.1323152260784799
# Mean squared error:               0.02570240920903995
# Mean absolute error:              0.11636439120923002
# Root mean squared error:          0.16031970935926734
# Correlation Coefficient:          0.38177153954833204
#
#
# Extended feature space
# Coefficient of determination R^2: 0.24719193207908152
# Mean squared error:               0.022299551172394155
# Mean absolute error:              0.11173585174307823
# Root mean squared error:          0.14933034243714222
# Correlation Coefficient:          0.5976920309056382
# -------------------------------------------------------
#
# max_features: 5; max_depth: 5; n_estimators: 30;
#
# Normal feature space
# Coefficient of determination R^2: 0.14400411841611627
# Mean squared error:               0.025356162849657006
# Mean absolute error:              0.11596007046164931
# Root mean squared error:          0.15923618574198833
# Correlation Coefficient:          0.41576764452192866
#
#
# Extended feature space
# Coefficient of determination R^2: 0.26224090430959957
# Mean squared error:               0.021853773104057044
# Mean absolute error:              0.1094118592998238
# Root mean squared error:          0.14783021715487346
# Correlation Coefficient:          0.6088786647358255
# -------------------------------------------------------
#
# max_features: 5; max_depth: 5; n_estimators: 40;
#
# Normal feature space
# Coefficient of determination R^2: 0.14337751007260724
# Mean squared error:               0.025374724134287922
# Mean absolute error:              0.11518911820406827
# Root mean squared error:          0.15929445732444028
# Correlation Coefficient:          0.4251092799661558
#
#
# Extended feature space
# Coefficient of determination R^2: 0.23865590977309548
# Mean squared error:               0.0225524037577108
# Mean absolute error:              0.11102108404227908
# Root mean squared error:          0.1501745776012398
# Correlation Coefficient:          0.5755073006886313
# -------------------------------------------------------
#
# max_features: 5; max_depth: 5; n_estimators: 50;
#
# Normal feature space
# Coefficient of determination R^2: 0.15799245064211287
# Mean squared error:               0.024941802877198754
# Mean absolute error:              0.1142455304553639
# Root mean squared error:          0.1579297403189113
# Correlation Coefficient:          0.4559553979940517
#
#
# Extended feature space
# Coefficient of determination R^2: 0.23209754452156572
# Mean squared error:               0.022746674525740217
# Mean absolute error:              0.1108404692038418
# Root mean squared error:          0.15082000704727544
# Correlation Coefficient:          0.572694821299046
# -------------------------------------------------------
#
# max_features: 5; max_depth: 5; n_estimators: 60;
#
# Normal feature space
# Coefficient of determination R^2: 0.1752967626164078
# Mean squared error:               0.024429217522687917
# Mean absolute error:              0.11324881578824017
# Root mean squared error:          0.1562984885489553
# Correlation Coefficient:          0.49383473372650144
#
#
# Extended feature space
# Coefficient of determination R^2: 0.23105280182624766
# Mean squared error:               0.02277762171425876
# Mean absolute error:              0.11029525767551533
# Root mean squared error:          0.15092256860476091
# Correlation Coefficient:          0.5697445411144241
# -------------------------------------------------------
#
# max_features: 5; max_depth: 5; n_estimators: 80;
#
# Normal feature space
# Coefficient of determination R^2: 0.19763478663248235
# Mean squared error:               0.023767524415423086
# Mean absolute error:              0.11150891880869342
# Root mean squared error:          0.1541671963013633
# Correlation Coefficient:          0.5404621217205695
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2444026386559487
# Mean squared error:               0.022382175142665557
# Mean absolute error:              0.10956191718266287
# Root mean squared error:          0.14960673495088903
# Correlation Coefficient:          0.5991150670878782
# -------------------------------------------------------
#
# max_features: 5; max_depth: 5; n_estimators: 90;
#
# Normal feature space
# Coefficient of determination R^2: 0.1994276934337792
# Mean squared error:               0.023714415238374455
# Mean absolute error:              0.1110328284932178
# Root mean squared error:          0.15399485458408815
# Correlation Coefficient:          0.5418568023251277
#
#
# Extended feature space
# Coefficient of determination R^2: 0.25107896209497804
# Mean squared error:               0.02218441023748427
# Mean absolute error:              0.1086611097399506
# Root mean squared error:          0.1489443192521429
# Correlation Coefficient:          0.6090663951858447
# -------------------------------------------------------
#
# max_features: 5; max_depth: 5; n_estimators: 100;
#
# Normal feature space
# Coefficient of determination R^2: 0.20538806373544827
# Mean squared error:               0.02353785817394824
# Mean absolute error:              0.11091158127981651
# Root mean squared error:          0.1534205272248412
# Correlation Coefficient:          0.5501651992550214
#
#
# Extended feature space
# Coefficient of determination R^2: 0.24323693850262262
# Mean squared error:               0.022416705312211366
# Mean absolute error:              0.10900489490998666
# Root mean squared error:          0.14972209360081554
# Correlation Coefficient:          0.5969555157489755
# -------------------------------------------------------
#
# max_features: 5; max_depth: 5; n_estimators: 120;
#
# Normal feature space
# Coefficient of determination R^2: 0.21043466152257062
# Mean squared error:               0.023388368721860904
# Mean absolute error:              0.11071729688670733
# Root mean squared error:          0.1529325626603468
# Correlation Coefficient:          0.5664138915327622
#
#
# Extended feature space
# Coefficient of determination R^2: 0.23642704677794535
# Mean squared error:               0.02261842675418834
# Mean absolute error:              0.1097399487375575
# Root mean squared error:          0.15039423776923216
# Correlation Coefficient:          0.5847596567509601
# -------------------------------------------------------
#
# max_features: 5; max_depth: 5; n_estimators: 140;
#
# Normal feature space
# Coefficient of determination R^2: 0.21368039989441834
# Mean squared error:               0.023292224017786307
# Mean absolute error:              0.11057407795905312
# Root mean squared error:          0.15261790202262088
# Correlation Coefficient:          0.5684879082069546
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2324144551756414
# Mean squared error:               0.022737287052825433
# Mean absolute error:              0.10974254018118566
# Root mean squared error:          0.15078888239132696
# Correlation Coefficient:          0.5816441449502942
# -------------------------------------------------------
#
# max_features: 5; max_depth: 5; n_estimators: 160;
#
# Normal feature space
# Coefficient of determination R^2: 0.22133136143839904
# Mean squared error:               0.023065588550210608
# Mean absolute error:              0.10935903228924863
# Root mean squared error:          0.15187359398595468
# Correlation Coefficient:          0.5870871832909061
#
#
# Extended feature space
# Coefficient of determination R^2: 0.23589197873041146
# Mean squared error:               0.02263427644790861
# Mean absolute error:              0.10945619057574095
# Root mean squared error:          0.15044692236103938
# Correlation Coefficient:          0.587243018805602
# -------------------------------------------------------
# max_features: 5; max_depth: 5; n_estimators: 200;
#
# Normal feature space
# Coefficient of determination R^2: 0.2344439403570795
# Mean squared error:               0.022677169991670548
# Mean absolute error:              0.10860578134315406
# Root mean squared error:          0.1505894086304563
# Correlation Coefficient:          0.6140754870714972
#
#
# Extended feature space
# Coefficient of determination R^2: 0.24054263818715882
# Mean squared error:               0.02249651541297771
# Mean absolute error:              0.10903495224512079
# Root mean squared error:          0.14998838426017433
# Correlation Coefficient:          0.596262237520812
# -------------------------------------------------------
#
# max_features: 5; max_depth: 5; n_estimators: 300;
#
# Normal feature space
# Coefficient of determination R^2: 0.2311320482869288
# Mean squared error:               0.02277527428922376
# Mean absolute error:              0.10876316098454761
# Root mean squared error:          0.15091479148587048
# Correlation Coefficient:          0.6047785715221239
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2445177269647344
# Mean squared error:               0.022378766016567592
# Mean absolute error:              0.10840583686208079
# Root mean squared error:          0.1495953408919128
# Correlation Coefficient:          0.6040991215401467
# -------------------------------------------------------
#
# max_features: 5; max_depth: 5; n_estimators: 500;
#
# Normal feature space
# Coefficient of determination R^2: 0.2323076679394409
# Mean squared error:               0.022740450285978327
# Mean absolute error:              0.10865155203219723
# Root mean squared error:          0.15079937097341728
# Correlation Coefficient:          0.6100109956813066
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2335147433643343
# Mean squared error:               0.02270469450525099
# Mean absolute error:              0.1092760870136472
# Root mean squared error:          0.15068077019066167
# Correlation Coefficient:          0.6033642774003604
# -------------------------------------------------------
#
# max_features: 5; max_depth: 7; n_estimators: 10;
#
# Normal feature space
# Coefficient of determination R^2: 0.1994661881615607
# Mean squared error:               0.023713274954165756
# Mean absolute error:              0.11244071451686265
# Root mean squared error:          0.1539911521944224
# Correlation Coefficient:          0.45757579327382136
#
#
# Extended feature space
# Coefficient of determination R^2: 0.23438478711640331
# Mean squared error:               0.022678922218796797
# Mean absolute error:              0.10659224719375188
# Root mean squared error:          0.15059522641437476
# Correlation Coefficient:          0.4956794910129567
# -------------------------------------------------------
#
# max_features: 5; max_depth: 7; n_estimators: 20;
#
# Normal feature space
# Coefficient of determination R^2: 0.2097884257493482
# Mean squared error:               0.023407511406840626
# Mean absolute error:              0.1099826759903998
# Root mean squared error:          0.1529951352391331
# Correlation Coefficient:          0.48680115948251523
#
#
# Extended feature space
# Coefficient of determination R^2: 0.23173611734705624
# Mean squared error:               0.022757380659370434
# Mean absolute error:              0.11047884510460677
# Root mean squared error:          0.15085549595348005
# Correlation Coefficient:          0.5418366650872635
# -------------------------------------------------------
#
# max_features: 5; max_depth: 7; n_estimators: 30;
#
# Normal feature space
# Coefficient of determination R^2: 0.20940536388064668
# Mean squared error:               0.023418858399662974
# Mean absolute error:              0.10874239713104805
# Root mean squared error:          0.1530322136011336
# Correlation Coefficient:          0.49307281699409544
#
#
# Extended feature space
# Coefficient of determination R^2: 0.26260072996630623
# Mean squared error:               0.021843114410311865
# Mean absolute error:              0.10624433247211036
# Root mean squared error:          0.14779416230119466
# Correlation Coefficient:          0.575203530225183
# -------------------------------------------------------
#
# max_features: 5; max_depth: 7; n_estimators: 40;
#
# Normal feature space
# Coefficient of determination R^2: 0.22415150158582753
# Mean squared error:               0.02298205084357499
# Mean absolute error:              0.10741307090110934
# Root mean squared error:          0.15159832071489113
# Correlation Coefficient:          0.5193232552958642
#
#
# Extended feature space
# Coefficient of determination R^2: 0.24268011531439582
# Mean squared error:               0.022433199432969307
# Mean absolute error:              0.10736322135928222
# Root mean squared error:          0.1497771659264833
# Correlation Coefficient:          0.5371194103949514
# -------------------------------------------------------
#
# max_features: 5; max_depth: 7; n_estimators: 50;
#
# Normal feature space
# Coefficient of determination R^2: 0.2306386288424963
# Mean squared error:               0.02278989027518279
# Mean absolute error:              0.10738338469408008
# Root mean squared error:          0.1509632083495273
# Correlation Coefficient:          0.5312368338654725
#
#
# Extended feature space
# Coefficient of determination R^2: 0.231290546651144
# Mean squared error:               0.022770579277926497
# Mean absolute error:              0.10966591877576501
# Root mean squared error:          0.15089923551140508
# Correlation Coefficient:          0.5345401853670703
# -------------------------------------------------------
#
# max_features: 5; max_depth: 7; n_estimators: 60;
#
# Normal feature space
# Coefficient of determination R^2: 0.23847546411214693
# Mean squared error:               0.022557748888058924
# Mean absolute error:              0.10698958598067848
# Root mean squared error:          0.15019237293570845
# Correlation Coefficient:          0.5519150830363203
#
#
# Extended feature space
# Coefficient of determination R^2: 0.23806439240168287
# Mean squared error:               0.022569925583598778
# Mean absolute error:              0.10952124423401056
# Root mean squared error:          0.15023290446369855
# Correlation Coefficient:          0.5552330777060971
# -------------------------------------------------------
#
# max_features: 5; max_depth: 7; n_estimators: 80;
#
# Normal feature space
# Coefficient of determination R^2: 0.24424246709957154
# Mean squared error:               0.022386919716973402
# Mean absolute error:              0.10597892350573199
# Root mean squared error:          0.14962259093122737
# Correlation Coefficient:          0.5765446432564334
#
#
# Extended feature space
# Coefficient of determination R^2: 0.22877674178872998
# Mean squared error:               0.02284504277341165
# Mean absolute error:              0.10965841792242231
# Root mean squared error:          0.15114576664072218
# Correlation Coefficient:          0.5389549479913803
# -------------------------------------------------------
#
# max_features: 5; max_depth: 7; n_estimators: 90;
#
# Normal feature space
# Coefficient of determination R^2: 0.2459773392305088
# Mean squared error:               0.022335529632953394
# Mean absolute error:              0.10544012357316451
# Root mean squared error:          0.14945075989419856
# Correlation Coefficient:          0.5807114624451499
#
#
# Extended feature space
# Coefficient of determination R^2: 0.23763399457812207
# Mean squared error:               0.02258267475393842
# Mean absolute error:              0.1088850284541131
# Root mean squared error:          0.1502753298247534
# Correlation Coefficient:          0.5561946025868276
# -------------------------------------------------------
#
# max_features: 5; max_depth: 7; n_estimators: 100;
#
# Normal feature space
# Coefficient of determination R^2: 0.24389530286234806
# Mean squared error:               0.022397203356327285
# Mean absolute error:              0.10594546853196588
# Root mean squared error:          0.14965695224855838
# Correlation Coefficient:          0.5808006252962111
#
#
# Extended feature space
# Coefficient of determination R^2: 0.23341078026964934
# Mean squared error:               0.022707774082169407
# Mean absolute error:              0.10942133211384106
# Root mean squared error:          0.15069098872251588
# Correlation Coefficient:          0.5496079203379088
# -------------------------------------------------------
# max_features: 5; max_depth: 7; n_estimators: 120;
#
# Normal feature space
# Coefficient of determination R^2: 0.25257613982939797
# Mean squared error:               0.022140061096015753
# Mean absolute error:              0.10517235403631005
# Root mean squared error:          0.14879536651393332
# Correlation Coefficient:          0.5973363787414739
#
#
# Extended feature space
# Coefficient of determination R^2: 0.22978152730373091
# Mean squared error:               0.022815279189619404
# Mean absolute error:              0.10981355559881785
# Root mean squared error:          0.15104727468451526
# Correlation Coefficient:          0.5358500965033731
# -------------------------------------------------------
#
# max_features: 5; max_depth: 7; n_estimators: 140;
#
# Normal feature space
# Coefficient of determination R^2: 0.2541292094647175
# Mean squared error:               0.022094056334267188
# Mean absolute error:              0.10561860778102092
# Root mean squared error:          0.14864069541773273
# Correlation Coefficient:          0.6025329978566588
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2360782672083921
# Mean squared error:               0.022628758242638797
# Mean absolute error:              0.10941428020507239
# Root mean squared error:          0.15042858186740576
# Correlation Coefficient:          0.5501887178429101
# -------------------------------------------------------
#
# max_features: 5; max_depth: 7; n_estimators: 160;
#
# Normal feature space
# Coefficient of determination R^2: 0.2665523618885337
# Mean squared error:               0.02172605984883839
# Mean absolute error:              0.10426779522724013
# Root mean squared error:          0.14739762497692557
# Correlation Coefficient:          0.6194520608075785
#
#
# Extended feature space
# Coefficient of determination R^2: 0.23927590879021832
# Mean squared error:               0.022534038253409886
# Mean absolute error:              0.10934877433718317
# Root mean squared error:          0.15011341796591632
# Correlation Coefficient:          0.558361542655447
# -------------------------------------------------------
#
# max_features: 5; max_depth: 7; n_estimators: 200;
#
# Normal feature space
# Coefficient of determination R^2: 0.2770338458406568
# Mean squared error:               0.021415579133085023
# Mean absolute error:              0.10406547684643258
# Root mean squared error:          0.14634062707630108
# Correlation Coefficient:          0.6434252908276579
#
#
# Extended feature space
# Coefficient of determination R^2: 0.24727933724112638
# Mean squared error:               0.02229696207170992
# Mean absolute error:              0.10900297882057068
# Root mean squared error:          0.14932167314797246
# Correlation Coefficient:          0.568239965563439
# -------------------------------------------------------
#
# max_features: 5; max_depth: 7; n_estimators: 300;
#
# Normal feature space
# Coefficient of determination R^2: 0.26292275389556885
# Mean squared error:               0.021833575472838523
# Mean absolute error:              0.10523335492069955
# Root mean squared error:          0.14776188775472018
# Correlation Coefficient:          0.6243834243433701
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2583387883509738
# Mean squared error:               0.021969360912169025
# Mean absolute error:              0.107385225069387
# Root mean squared error:          0.1482206494121822
# Correlation Coefficient:          0.5924479311284199
# -------------------------------------------------------
#
# max_features: 5; max_depth: 7; n_estimators: 500;
#
# Normal feature space
# Coefficient of determination R^2: 0.2613774559411254
# Mean squared error:               0.021879350023192207
# Mean absolute error:              0.10482492846211956
# Root mean squared error:          0.14791669960890896
# Correlation Coefficient:          0.6180801184030899
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2535373714541146
# Mean squared error:               0.022111587658074142
# Mean absolute error:              0.10728141802989188
# Root mean squared error:          0.14869965587745704
# Correlation Coefficient:          0.5973784881992952
# -------------------------------------------------------
#
# max_features: 5; max_depth: 10; n_estimators: 10;
#
# Normal feature space
# Coefficient of determination R^2: 0.19679634507157373
# Mean squared error:               0.023792360587203475
# Mean absolute error:              0.10573773929443574
# Root mean squared error:          0.15424772473914639
# Correlation Coefficient:          0.4473067875637104
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2515213551022658
# Mean squared error:               0.022171305747874365
# Mean absolute error:              0.10553708803704073
# Root mean squared error:          0.14890032151702817
# Correlation Coefficient:          0.5096475321357075
# -------------------------------------------------------
#
# max_features: 5; max_depth: 10; n_estimators: 20;
#
# Normal feature space
# Coefficient of determination R^2: 0.2249601325085615
# Mean squared error:               0.022958097717393853
# Mean absolute error:              0.10449145648437472
# Root mean squared error:          0.15151929816823287
# Correlation Coefficient:          0.5001458176201997
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2684338371834284
# Mean squared error:               0.02167032711109825
# Mean absolute error:              0.10755054184708072
# Root mean squared error:          0.14720844782517833
# Correlation Coefficient:          0.5689183085504923
# -------------------------------------------------------
#
# max_features: 5; max_depth: 10; n_estimators: 30;
#
# Normal feature space
# Coefficient of determination R^2: 0.26901442030137646
# Mean squared error:               0.021653129177786685
# Mean absolute error:              0.10196542825527548
# Root mean squared error:          0.14715002269040492
# Correlation Coefficient:          0.5735142586049525
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2664321700431348
# Mean squared error:               0.021729620151020562
# Mean absolute error:              0.10577211016253996
# Root mean squared error:          0.14740970168554227
# Correlation Coefficient:          0.566011626353694
# -------------------------------------------------------
#
# max_features: 5; max_depth: 10; n_estimators: 40;
#
# Normal feature space
# Coefficient of determination R^2: 0.2690120117185538
# Mean squared error:               0.021653200524412997
# Mean absolute error:              0.10162072845697546
# Root mean squared error:          0.1471502651183918
# Correlation Coefficient:          0.573579475597137
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2582782524039997
# Mean squared error:               0.021971154097583528
# Mean absolute error:              0.10688198553000879
# Root mean squared error:          0.14822669832922652
# Correlation Coefficient:          0.567386466410192
# -------------------------------------------------------
#
# max_features: 5; max_depth: 10; n_estimators: 50;
#
# Normal feature space
# Coefficient of determination R^2: 0.2810962996451343
# Mean squared error:               0.021295241824866973
# Mean absolute error:              0.10063576025773105
# Root mean squared error:          0.14592889304338252
# Correlation Coefficient:          0.5946299724075487
#
#
# Extended feature space
# Coefficient of determination R^2: 0.25708144779067166
# Mean squared error:               0.022006605638096338
# Mean absolute error:              0.10725712074219845
# Root mean squared error:          0.14834623567214753
# Correlation Coefficient:          0.5734996552139768
# -------------------------------------------------------
#
# max_features: 5; max_depth: 10; n_estimators: 60;
#
# Normal feature space
# Coefficient of determination R^2: 0.2917676900522834
# Mean squared error:               0.020979135732749725
# Mean absolute error:              0.09973841084840449
# Root mean squared error:          0.14484176101093815
# Correlation Coefficient:          0.617264584703884
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2731510631296806
# Mean squared error:               0.02153059425505871
# Mean absolute error:              0.1061749363700056
# Root mean squared error:          0.1467330714428711
# Correlation Coefficient:          0.5892211041528352
# -------------------------------------------------------
# max_features: 5; max_depth: 10; n_estimators: 80;
#
# Normal feature space
# Coefficient of determination R^2: 0.3001085825983102
# Mean squared error:               0.02073206324763775
# Mean absolute error:              0.09882884809130099
# Root mean squared error:          0.14398633007212092
# Correlation Coefficient:          0.6352357358021878
#
#
# Extended feature space
# Coefficient of determination R^2: 0.27139761395966744
# Mean squared error:               0.021582534624936638
# Mean absolute error:              0.10633607451186011
# Root mean squared error:          0.14690995413836544
# Correlation Coefficient:          0.5899171553912698
# -------------------------------------------------------
#
# max_features: 5; max_depth: 10; n_estimators: 90;
#
# Normal feature space
# Coefficient of determination R^2: 0.303894858113391
# Mean squared error:               0.020619906845230282
# Mean absolute error:              0.09894744617991598
# Root mean squared error:          0.14359633297974667
# Correlation Coefficient:          0.6429998280852369
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2735775508777968
# Mean squared error:               0.021517960908301707
# Mean absolute error:              0.10542886185561533
# Root mean squared error:          0.14669001638932933
# Correlation Coefficient:          0.5964951040402005
# -------------------------------------------------------
#
# max_features: 5; max_depth: 10; n_estimators: 100;
#
# Normal feature space
# Coefficient of determination R^2: 0.3065063331824224
# Mean squared error:               0.02054255017967524
# Mean absolute error:              0.09896680450973407
# Root mean squared error:          0.14332672528065113
# Correlation Coefficient:          0.6521547962037201
#
#
# Extended feature space
# Coefficient of determination R^2: 0.26750144777361207
# Mean squared error:               0.021697946189908363
# Mean absolute error:              0.10572292541030344
# Root mean squared error:          0.14730222737592383
# Correlation Coefficient:          0.5882181250866276
# -------------------------------------------------------
#
# max_features: 5; max_depth: 10; n_estimators: 120;
#
# Normal feature space
# Coefficient of determination R^2: 0.3165662699185531
# Mean squared error:               0.020244556463085633
# Mean absolute error:              0.09833718072342203
# Root mean squared error:          0.14228336678292947
# Correlation Coefficient:          0.6661976662130435
#
#
# Extended feature space
# Coefficient of determination R^2: 0.27537732361194156
# Mean squared error:               0.021464648349770573
# Mean absolute error:              0.10547434064677053
# Root mean squared error:          0.14650818526543347
# Correlation Coefficient:          0.5953448636739738
# -------------------------------------------------------
#
# max_features: 5; max_depth: 10; n_estimators: 140;
#
# Normal feature space
# Coefficient of determination R^2: 0.31448108222349125
# Mean squared error:               0.02030632353452324
# Mean absolute error:              0.09884286106358801
# Root mean squared error:          0.14250025801563743
# Correlation Coefficient:          0.6669559374653513
#
#
# Extended feature space
# Coefficient of determination R^2: 0.27370640676446156
# Mean squared error:               0.02151414396137859
# Mean absolute error:              0.10525837394185493
# Root mean squared error:          0.14667700556453486
# Correlation Coefficient:          0.5960468176279297
# -------------------------------------------------------
#
# max_features: 5; max_depth: 10; n_estimators: 160;
#
# Normal feature space
# Coefficient of determination R^2: 0.3161200343933822
# Mean squared error:               0.020257774775099706
# Mean absolute error:              0.0994285650510782
# Root mean squared error:          0.14232980986110993
# Correlation Coefficient:          0.6661005879966612
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2740275169660652
# Mean squared error:               0.021504632090188883
# Mean absolute error:              0.10454246895536871
# Root mean squared error:          0.14664457743192855
# Correlation Coefficient:          0.5951137645054103
# -------------------------------------------------------
#
# max_features: 5; max_depth: 10; n_estimators: 200;
#
# Normal feature space
# Coefficient of determination R^2: 0.30921436485454656
# Mean squared error:               0.02046233333102247
# Mean absolute error:              0.09996881605596622
# Root mean squared error:          0.14304661244161804
# Correlation Coefficient:          0.6695793048274998
#
#
# Extended feature space
# Coefficient of determination R^2: 0.27715727868027396
# Mean squared error:               0.021411922826729275
# Mean absolute error:              0.10441490039927306
# Root mean squared error:          0.1463281340916
# Correlation Coefficient:          0.6020889006066802
# -------------------------------------------------------
#
# max_features: 5; max_depth: 10; n_estimators: 300;
#
# Normal feature space
# Coefficient of determination R^2: 0.2873517880532146
# Mean squared error:               0.021109942822626526
# Mean absolute error:              0.10203965480903399
# Root mean squared error:          0.14529261103933166
# Correlation Coefficient:          0.6428328547708397
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2821759874067411
# Mean squared error:               0.021263259499602245
# Mean absolute error:              0.10403079413073076
# Root mean squared error:          0.14581926998720796
# Correlation Coefficient:          0.6087081729730207
# -------------------------------------------------------
#
# max_features: 5; max_depth: 10; n_estimators: 500;
#
# Normal feature space
# Coefficient of determination R^2: 0.278546234270335
# Mean squared error:               0.02137077942301644
# Mean absolute error:              0.10293493701972341
# Root mean squared error:          0.1461874803908202
# Correlation Coefficient:          0.6309681747227895
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2720033257427329
# Mean squared error:               0.021564592334626848
# Mean absolute error:              0.10463898891254361
# Root mean squared error:          0.14684887583712328
# Correlation Coefficient:          0.6046621225079254
# -------------------------------------------------------
#
# max_features: 5; max_depth: 12; n_estimators: 10;
#
# Normal feature space
# Coefficient of determination R^2: 0.1934525769549843
# Mean squared error:               0.02389140911152447
# Mean absolute error:              0.10622940476190475
# Root mean squared error:          0.15456846092112217
# Correlation Coefficient:          0.45804662074965663
#
#
# Extended feature space
# Coefficient of determination R^2: 0.21572651298256107
# Mean squared error:               0.02323161440763753
# Mean absolute error:              0.1091384734940985
# Root mean squared error:          0.15241920616391338
# Correlation Coefficient:          0.46742943646014795
# -------------------------------------------------------
#
# max_features: 5; max_depth: 12; n_estimators: 20;
#
# Normal feature space
# Coefficient of determination R^2: 0.2161717944085122
# Mean squared error:               0.023218424357786527
# Mean absolute error:              0.10643054647237683
# Root mean squared error:          0.15237593103172997
# Correlation Coefficient:          0.4933644769597829
#
#
# Extended feature space
# Coefficient of determination R^2: 0.24872618348773157
# Mean squared error:               0.02225410384092094
# Mean absolute error:              0.10911351646534681
# Root mean squared error:          0.14917809437354046
# Correlation Coefficient:          0.5142904031679958
# -------------------------------------------------------
#
# max_features: 5; max_depth: 12; n_estimators: 30;
#
# Normal feature space
# Coefficient of determination R^2: 0.21419358658671084
# Mean squared error:               0.023277022489809368
# Mean absolute error:              0.10447884173366317
# Root mean squared error:          0.1525680913225612
# Correlation Coefficient:          0.5041559731418501
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2759670050194043
# Mean squared error:               0.021447180908491098
# Mean absolute error:              0.10729893592408478
# Root mean squared error:          0.146448560622804
# Correlation Coefficient:          0.5575708558049559
# -------------------------------------------------------
# max_features: 5; max_depth: 12; n_estimators: 40;
#
# Normal feature space
# Coefficient of determination R^2: 0.24187792875976277
# Mean squared error:               0.022456961665186414
# Mean absolute error:              0.10341243194801232
# Root mean squared error:          0.14985647021462375
# Correlation Coefficient:          0.5457397847486823
#
#
# Extended feature space
# Coefficient of determination R^2: 0.25621422053376175
# Mean squared error:               0.02203229449481511
# Mean absolute error:              0.10878133239941279
# Root mean squared error:          0.14843279453953265
# Correlation Coefficient:          0.5409149873584005
# -------------------------------------------------------
#
# max_features: 5; max_depth: 12; n_estimators: 50;
#
# Normal feature space
# Coefficient of determination R^2: 0.26008730019627824
# Mean squared error:               0.02191756679487484
# Mean absolute error:              0.10176113216941787
# Root mean squared error:          0.14804582667159125
# Correlation Coefficient:          0.5771740557082015
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2627055767161105
# Mean squared error:               0.021840008657913416
# Mean absolute error:              0.1076373349830199
# Root mean squared error:          0.14778365490781928
# Correlation Coefficient:          0.5546062761952212
# -------------------------------------------------------
#
# max_features: 5; max_depth: 12; n_estimators: 60;
#
# Normal feature space
# Coefficient of determination R^2: 0.26796674779041507
# Mean squared error:               0.02168416315280055
# Mean absolute error:              0.10155492218594893
# Root mean squared error:          0.14725543505351696
# Correlation Coefficient:          0.5963948209738185
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2727756001614865
# Mean squared error:               0.021541716154556554
# Mean absolute error:              0.10706015486542803
# Root mean squared error:          0.14677096495750294
# Correlation Coefficient:          0.5689756033037937
# -------------------------------------------------------
#
# max_features: 5; max_depth: 12; n_estimators: 80;
#
# Normal feature space
# Coefficient of determination R^2: 0.278765969615796
# Mean squared error:               0.021364270460387993
# Mean absolute error:              0.10102567304471317
# Root mean squared error:          0.1461652163149222
# Correlation Coefficient:          0.6132315361333933
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2815921274166343
# Mean squared error:               0.02128055449985757
# Mean absolute error:              0.10488209850011654
# Root mean squared error:          0.14587856079581252
# Correlation Coefficient:          0.594350683388658
# -------------------------------------------------------
#
# max_features: 5; max_depth: 12; n_estimators: 90;
#
# Normal feature space
# Coefficient of determination R^2: 0.28859541767689423
# Mean squared error:               0.02107310423970679
# Mean absolute error:              0.1005964737257892
# Root mean squared error:          0.14516578191745735
# Correlation Coefficient:          0.6270767423256592
#
#
# Extended feature space
# Coefficient of determination R^2: 0.28707580780175923
# Mean squared error:               0.02111811786219125
# Mean absolute error:              0.10445299664003448
# Root mean squared error:          0.14532074133512823
# Correlation Coefficient:          0.6044461604976994
# -------------------------------------------------------
#
# max_features: 5; max_depth: 12; n_estimators: 100;
#
# Normal feature space
# Coefficient of determination R^2: 0.2914079116610475
# Mean squared error:               0.020989793026405256
# Mean absolute error:              0.10064819383757778
# Root mean squared error:          0.144878545776817
# Correlation Coefficient:          0.6340231587491052
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2825981496477603
# Mean squared error:               0.021250754282272865
# Mean absolute error:              0.10496120366279667
# Root mean squared error:          0.14577638451502653
# Correlation Coefficient:          0.5985628329035179
# -------------------------------------------------------
#
# max_features: 5; max_depth: 12; n_estimators: 120;
#
# Normal feature space
# Coefficient of determination R^2: 0.3057459885602366
# Mean squared error:               0.020565072977362455
# Mean absolute error:              0.09992051623613385
# Root mean squared error:          0.14340527527731486
# Correlation Coefficient:          0.666136918251866
#
#
# Extended feature space
# Coefficient of determination R^2: 0.27759700677939736
# Mean squared error:               0.021398897276570888
# Mean absolute error:              0.10550619708785722
# Root mean squared error:          0.14628361930363526
# Correlation Coefficient:          0.5932219337306835
# -------------------------------------------------------
#
# max_features: 5; max_depth: 12; n_estimators: 140;
#
# Normal feature space
# Coefficient of determination R^2: 0.30689238223978876
# Mean squared error:               0.02053111470086379
# Mean absolute error:              0.09984394095554235
# Root mean squared error:          0.1432868266829292
# Correlation Coefficient:          0.6686151985008864
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2727494363130032
# Mean squared error:               0.021542491175578486
# Mean absolute error:              0.10561645458931877
# Root mean squared error:          0.14677360517333654
# Correlation Coefficient:          0.595383524510965
# -------------------------------------------------------
#
# max_features: 5; max_depth: 12; n_estimators: 160;
#
# Normal feature space
# Coefficient of determination R^2: 0.3083832901434538
# Mean squared error:               0.020486951283244046
# Mean absolute error:              0.09991264677241854
# Root mean squared error:          0.14313263528365586
# Correlation Coefficient:          0.66318855780428
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2760601334296304
# Mean squared error:               0.021444422274733126
# Mean absolute error:              0.1048798571450642
# Root mean squared error:          0.14643914188062263
# Correlation Coefficient:          0.6007077564071092
# -------------------------------------------------------
#
# max_features: 5; max_depth: 12; n_estimators: 200;
#
# Normal feature space
# Coefficient of determination R^2: 0.3088180263855166
# Mean squared error:               0.020474073601017356
# Mean absolute error:              0.09993814601280386
# Root mean squared error:          0.14308764307590421
# Correlation Coefficient:          0.6689173550380972
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2880220837193094
# Mean squared error:               0.021090087439636283
# Mean absolute error:              0.10391838905728684
# Root mean squared error:          0.14522426601514046
# Correlation Coefficient:          0.623727676042494
# -------------------------------------------------------
#
# max_features: 5; max_depth: 12; n_estimators: 300;
#
# Normal feature space
# Coefficient of determination R^2: 0.29957833771887454
# Mean squared error:               0.02074777007030177
# Mean absolute error:              0.10105708002332542
# Root mean squared error:          0.14404086250193648
# Correlation Coefficient:          0.6617020619769891
#
#
# Extended feature space
# Coefficient of determination R^2: 0.28416346381310953
# Mean squared error:               0.021204386815160722
# Mean absolute error:              0.103821793761923
# Root mean squared error:          0.14561726139150097
# Correlation Coefficient:          0.6174782985017958
# -------------------------------------------------------
#
# max_features: 5; max_depth: 12; n_estimators: 500;
#
# Normal feature space
# Coefficient of determination R^2: 0.2925555490109617
# Mean squared error:               0.02095579791011693
# Mean absolute error:              0.10236436510837106
# Root mean squared error:          0.14476117542392689
# Correlation Coefficient:          0.6532350650735314
#
#
# Extended feature space
# Coefficient of determination R^2: 0.27448597506859096
# Mean squared error:               0.021491051723089592
# Mean absolute error:              0.10472766683796712
# Root mean squared error:          0.14659826643957832
# Correlation Coefficient:          0.6096512649763499
# -------------------------------------------------------
# max_features: 5; max_depth: 15; n_estimators: 10;
#
# Normal feature space
# Coefficient of determination R^2: 0.18320496984747392
# Mean squared error:               0.02419496196759259
# Mean absolute error:              0.10589424603174603
# Root mean squared error:          0.15554729816873256
# Correlation Coefficient:          0.4286653415730119
#
#
# Extended feature space
# Coefficient of determination R^2: 0.22130783005656707
# Mean squared error:               0.023066285592757946
# Mean absolute error:              0.10879117063492066
# Root mean squared error:          0.1518758887801416
# Correlation Coefficient:          0.47080690172740886
# -------------------------------------------------------
#
# max_features: 5; max_depth: 15; n_estimators: 20;
#
# Normal feature space
# Coefficient of determination R^2: 0.21272594687549007
# Mean squared error:               0.023320496661032572
# Mean absolute error:              0.10518794642857136
# Root mean squared error:          0.15271049951143692
# Correlation Coefficient:          0.47166985484036583
#
#
# Extended feature space
# Coefficient of determination R^2: 0.26243565707882965
# Mean squared error:               0.021848004171006945
# Mean absolute error:              0.1066825892857143
# Root mean squared error:          0.14781070384450154
# Correlation Coefficient:          0.5352828002461228
# -------------------------------------------------------
#
# max_features: 5; max_depth: 15; n_estimators: 30;
#
# Normal feature space
# Coefficient of determination R^2: 0.23062310707084188
# Mean squared error:               0.02279035005843438
# Mean absolute error:              0.1039631613756614
# Root mean squared error:          0.15096473117398773
# Correlation Coefficient:          0.5113447270623043
#
#
# Extended feature space
# Coefficient of determination R^2: 0.27913920835494477
# Mean squared error:               0.021353214446620562
# Mean absolute error:              0.10590878637566144
# Root mean squared error:          0.14612739115792275
# Correlation Coefficient:          0.57683828092582
# -------------------------------------------------------
#
# max_features: 5; max_depth: 15; n_estimators: 40;
#
# Normal feature space
# Coefficient of determination R^2: 0.25097389382991175
# Mean squared error:               0.022187522551569732
# Mean absolute error:              0.10294885912698415
# Root mean squared error:          0.14895476679707076
# Correlation Coefficient:          0.5510407650314176
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2814125140492212
# Mean squared error:               0.021285874976149664
# Mean absolute error:              0.10559822668650799
# Root mean squared error:          0.14589679563359048
# Correlation Coefficient:          0.5863455491989331
# -------------------------------------------------------
#
# max_features: 5; max_depth: 15; n_estimators: 50;
#
# Normal feature space
# Coefficient of determination R^2: 0.26842067689047466
# Mean squared error:               0.021670716943033734
# Mean absolute error:              0.10163369047619046
# Root mean squared error:          0.14720977190062395
# Correlation Coefficient:          0.5875625215642646
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2752970416875816
# Mean squared error:               0.021467026447132664
# Mean absolute error:              0.10582953939909297
# Root mean squared error:          0.1465163009604483
# Correlation Coefficient:          0.579826792824927
# -------------------------------------------------------
#
# max_features: 5; max_depth: 15; n_estimators: 60;
#
# Normal feature space
# Coefficient of determination R^2: 0.2774850495000317
# Mean squared error:               0.021402213655853635
# Mean absolute error:              0.10137137896825392
# Root mean squared error:          0.14629495430756878
# Correlation Coefficient:          0.6068170087824838
#
#
# Extended feature space
# Coefficient of determination R^2: 0.2927643693773767
# Mean squared error:               0.02094961226912138
# Mean absolute error:              0.105672883361678
# Root mean squared error:          0.14473980886100887
# Correlation Coefficient:          0.6022364167954798
# -------------------------------------------------------
#
# max_features: 5; max_depth: 15; n_estimators: 80;
#
# Normal feature space
# Coefficient of determination R^2: 0.28467314649611064
# Mean squared error:               0.021189289082344638
# Mean absolute error:              0.10118876736111108
# Root mean squared error:          0.1455654116964076
# Correlation Coefficient:          0.6269862224187746
#
#
# Extended feature space
# Coefficient of determination R^2: 0.28425414139120775
# Mean squared error:               0.02120170077953072
# Mean absolute error:              0.1068051384755291
# Root mean squared error:          0.14560803816936316
# Correlation Coefficient:          0.6001612194195639
# -------------------------------------------------------
#
# max_features: 5; max_depth: 15; n_estimators: 90;
#
# Normal feature space
# Coefficient of determination R^2: 0.28764535888328746
# Mean squared error:               0.021101246717965996
# Mean absolute error:              0.10059056531872007
# Root mean squared error:          0.14526268178016677
# Correlation Coefficient:          0.6230229915589722
#
#
# Extended feature space
# Coefficient of determination R^2: 0.28813703756812115
# Mean squared error:               0.021086682296488548
# Mean absolute error:              0.10641641056731341
# Root mean squared error:          0.14521254180162452
# Correlation Coefficient:          0.6110673993740946
# -------------------------------------------------------
#
# max_features: 5; max_depth: 15; n_estimators: 100;
#
# Normal feature space
# Coefficient of determination R^2: 0.29409488364198266
# Mean squared error:               0.02091020000430451
# Mean absolute error:              0.1006721079931973
# Root mean squared error:          0.1446035960974156
# Correlation Coefficient:          0.6349441376575621
#
#
# Extended feature space
# Coefficient of determination R^2: 0.28276888321329907
# Mean squared error:               0.02124569684194536
# Mean absolute error:              0.10635043419312172
# Root mean squared error:          0.14575903691348047
# Correlation Coefficient:          0.6042209222527612
# -------------------------------------------------------
#
# max_features: 5; max_depth: 15; n_estimators: 120;
#
# Normal feature space
# Coefficient of determination R^2: 0.3044981918123121
# Mean squared error:               0.020602034998120196
# Mean absolute error:              0.0998877810059209
# ...
# -------------------------------------------------------
#
# max_features: 30; max_depth: 18; n_estimators: 90;
#
# Normal feature space
# Coefficient of determination R^2: 0.3592671843855033
# Mean squared error:               0.018979677315478238
# Mean absolute error:              0.09666281966490302
# Root mean squared error:          0.13776674967305513
# Correlation Coefficient:          0.6255712799611288
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3546695032343936
# Mean squared error:               0.01911586903614706
# Mean absolute error:              0.09653494268077606
# Root mean squared error:          0.13826014984856289
# Correlation Coefficient:          0.6230483594327078
# -------------------------------------------------------
#
# max_features: 30; max_depth: 18; n_estimators: 100;
#
# Normal feature space
# Coefficient of determination R^2: 0.355357122215336
# Mean squared error:               0.01909550050490246
# Mean absolute error:              0.09715106150793654
# Root mean squared error:          0.13818647005008292
# Correlation Coefficient:          0.6214646249539477
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3611552786059864
# Mean squared error:               0.018923748513062177
# Mean absolute error:              0.09667910714285718
# Root mean squared error:          0.13756361624013153
# Correlation Coefficient:          0.6297242527496916
# -------------------------------------------------------
#
# max_features: 30; max_depth: 18; n_estimators: 120;
#
# Normal feature space
# Coefficient of determination R^2: 0.35992706006709374
# Mean squared error:               0.018960130591477678
# Mean absolute error:              0.09730147982804237
# Root mean squared error:          0.13769579002815474
# Correlation Coefficient:          0.6244375560241543
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3529740789654684
# Mean squared error:               0.01916609060238005
# Mean absolute error:              0.09738526785714295
# Root mean squared error:          0.13844165053328442
# Correlation Coefficient:          0.6210126553621435
# -------------------------------------------------------
#
# max_features: 30; max_depth: 18; n_estimators: 140;
#
# Normal feature space
# Coefficient of determination R^2: 0.3606215517985544
# Mean squared error:               0.018939558476798724
# Mean absolute error:              0.09681066468253974
# Root mean squared error:          0.13762106843357497
# Correlation Coefficient:          0.6271631413826674
#
#
# Extended feature space
# Coefficient of determination R^2: 0.36335636246081493
# Mean squared error:               0.018858548385503722
# Mean absolute error:              0.09685371882086176
# Root mean squared error:          0.1373264300326187
# Correlation Coefficient:          0.6325530129231528
# -------------------------------------------------------
#
# max_features: 30; max_depth: 18; n_estimators: 160;
#
# Normal feature space
# Coefficient of determination R^2: 0.3579830026352584
# Mean squared error:               0.019017717126519756
# Mean absolute error:              0.09727532862103183
# Root mean squared error:          0.13790473931855915
# Correlation Coefficient:          0.6252116578781055
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3655779523112427
# Mean squared error:               0.018792740832868818
# Mean absolute error:              0.09665379216269854
# Root mean squared error:          0.1370866179934016
# Correlation Coefficient:          0.6343447829819384
# -------------------------------------------------------
#
# max_features: 30; max_depth: 18; n_estimators: 200;
#
# Normal feature space
# Coefficient of determination R^2: 0.36315634238198513
# Mean squared error:               0.01886447334589328
# Mean absolute error:              0.09654198908730169
# Root mean squared error:          0.13734800088058538
# Correlation Coefficient:          0.6302156591290177
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3715635933741369
# Mean squared error:               0.018615435202297897
# Mean absolute error:              0.09568455902777792
# Root mean squared error:          0.13643839343197317
# Correlation Coefficient:          0.6413730886612664
# -------------------------------------------------------
#
# max_features: 30; max_depth: 18; n_estimators: 300;
#
# Normal feature space
# Coefficient of determination R^2: 0.35858664278695074
# Mean squared error:               0.018999836201718363
# Mean absolute error:              0.09686186177248687
# Root mean squared error:          0.137839893360806
# Correlation Coefficient:          0.6310067335804513
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3664884063601831
# Mean squared error:               0.018765771519547652
# Mean absolute error:              0.09573325429894189
# Root mean squared error:          0.1369882167178902
# Correlation Coefficient:          0.6375030999454852
# -------------------------------------------------------
#
# max_features: 30; max_depth: 18; n_estimators: 500;
#
# Normal feature space
# Coefficient of determination R^2: 0.3718171900312507
# Mean squared error:               0.018607923205716786
# Mean absolute error:              0.09563751666666692
# Root mean squared error:          0.136410861758574
# Correlation Coefficient:          0.6441336639124616
#
#
# Extended feature space
# Coefficient of determination R^2: 0.36457916749492414
# Mean squared error:               0.018822326664996277
# Mean absolute error:              0.0960285668650796
# Root mean squared error:          0.13719448481989455
# Correlation Coefficient:          0.6377305986938556
# -------------------------------------------------------
#
# max_features: 30; max_depth: 20; n_estimators: 10;
#
# Normal feature space
# Coefficient of determination R^2: 0.18651896452703898
# Mean squared error:               0.024096795386904762
# Mean absolute error:              0.11312797619047618
# Root mean squared error:          0.15523142525566389
# Correlation Coefficient:          0.43563306176222866
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3353228945611869
# Mean squared error:               0.019688950952380956
# Mean absolute error:              0.1011690476190476
# Root mean squared error:          0.1403173223532325
# Correlation Coefficient:          0.5876953040176582
# -------------------------------------------------------
#
# max_features: 30; max_depth: 20; n_estimators: 20;
#
# Normal feature space
# Coefficient of determination R^2: 0.291486102107558
# Mean squared error:               0.020987476882440476
# Mean absolute error:              0.10445386904761902
# Root mean squared error:          0.14487055215757438
# Correlation Coefficient:          0.5532909886211924
#
#
# Extended feature space
# Coefficient of determination R^2: 0.32414650402760636
# Mean squared error:               0.02002001607142857
# Mean absolute error:              0.1008
# Root mean squared error:          0.14149210603927193
# Correlation Coefficient:          0.5923677009001483
# -------------------------------------------------------
#
# max_features: 30; max_depth: 20; n_estimators: 30;
#
# Normal feature space
# Coefficient of determination R^2: 0.3299754918250102
# Mean squared error:               0.019847350796957677
# Mean absolute error:              0.09950337301587305
# Root mean squared error:          0.14088062605254734
# Correlation Coefficient:          0.5883516317638823
#
#
# Extended feature space
# Coefficient of determination R^2: 0.27918465421133676
# Mean squared error:               0.021351868257275135
# Mean absolute error:              0.10375773809523814
# Root mean squared error:          0.14612278486695746
# Correlation Coefficient:          0.5417302200559185
# -------------------------------------------------------
# max_features: 30; max_depth: 20; n_estimators: 40;
#
# Normal feature space
# Coefficient of determination R^2: 0.351558894469283
# Mean squared error:               0.019208010954241076
# Mean absolute error:              0.09948080357142859
# Root mean squared error:          0.13859296863203802
# Correlation Coefficient:          0.6130450908017168
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3103794110932895
# Mean squared error:               0.020427822531622026
# Mean absolute error:              0.10023020833333335
# Root mean squared error:          0.1429259337266055
# Correlation Coefficient:          0.5816776592658834
# -------------------------------------------------------
#
# max_features: 30; max_depth: 20; n_estimators: 50;
#
# Normal feature space
# Coefficient of determination R^2: 0.347201230735407
# Mean squared error:               0.0193370929202381
# Mean absolute error:              0.09928678571428573
# Root mean squared error:          0.1390578761531978
# Correlation Coefficient:          0.6141961925282848
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3132496082775187
# Mean squared error:               0.02034280204404762
# Mean absolute error:              0.09981940476190479
# Root mean squared error:          0.14262819512301073
# Correlation Coefficient:          0.5855971645306104
# -------------------------------------------------------
#
# max_features: 30; max_depth: 20; n_estimators: 60;
#
# Normal feature space
# Coefficient of determination R^2: 0.35379494732379757
# Mean squared error:               0.019141774980985453
# Mean absolute error:              0.09739117063492063
# Root mean squared error:          0.13835380363757785
# Correlation Coefficient:          0.6187432783704035
#
#
# Extended feature space
# Coefficient of determination R^2: 0.32500601502046933
# Mean squared error:               0.019994555784556885
# Mean absolute error:              0.0994655753968254
# Root mean squared error:          0.14140210671894846
# Correlation Coefficient:          0.5957166937874915
# -------------------------------------------------------
#
# max_features: 30; max_depth: 20; n_estimators: 80;
#
# Normal feature space
# Coefficient of determination R^2: 0.3555674856151775
# Mean squared error:               0.01908926915643602
# Mean absolute error:              0.09654806547619046
# Root mean squared error:          0.13816392132693694
# Correlation Coefficient:          0.6190525537846953
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3421761259889273
# Mean squared error:               0.0194859457091704
# Mean absolute error:              0.0974142113095238
# Root mean squared error:          0.13959206893362675
# Correlation Coefficient:          0.6130285673902158
# -------------------------------------------------------
#
# max_features: 30; max_depth: 20; n_estimators: 90;
#
# Normal feature space
# Coefficient of determination R^2: 0.35667414949894327
# Mean squared error:               0.019056487749118174
# Mean absolute error:              0.09669232804232804
# Root mean squared error:          0.13804523805303165
# Correlation Coefficient:          0.623496327645829
#
#
# Extended feature space
# Coefficient of determination R^2: 0.35434540063287767
# Mean squared error:               0.019125469547692547
# Mean absolute error:              0.09636673280423282
# Root mean squared error:          0.13829486450223866
# Correlation Coefficient:          0.6235675196948443
# -------------------------------------------------------
#
# max_features: 30; max_depth: 20; n_estimators: 100;
#
# Normal feature space
# Coefficient of determination R^2: 0.35296934114653167
# Mean squared error:               0.01916623094523811
# Mean absolute error:              0.09714428571428572
# Root mean squared error:          0.13844215739881444
# Correlation Coefficient:          0.6195101779105183
#
#
# Extended feature space
# Coefficient of determination R^2: 0.36074621438294285
# Mean squared error:               0.018935865743154767
# Mean absolute error:              0.09654494047619049
# Root mean squared error:          0.13760765147023898
# Correlation Coefficient:          0.6300231914459782
# -------------------------------------------------------
#
# max_features: 30; max_depth: 20; n_estimators: 120;
#
# Normal feature space
# Coefficient of determination R^2: 0.3580584102759057
# Mean squared error:               0.019015483414351858
# Mean absolute error:              0.09742192460317463
# Root mean squared error:          0.137896640330183
# Correlation Coefficient:          0.6228061931401478
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3522271686693883
# Mean squared error:               0.019188215450768858
# Mean absolute error:              0.0973343750000001
# Root mean squared error:          0.1385215342492598
# Correlation Coefficient:          0.6209108962054478
# -------------------------------------------------------
#
# max_features: 30; max_depth: 20; n_estimators: 140;
#
# Normal feature space
# Coefficient of determination R^2: 0.35859419235034395
# Mean squared error:               0.018999612569849375
# Mean absolute error:              0.09694183673469395
# Root mean squared error:          0.13783908215687368
# Correlation Coefficient:          0.6253538114688585
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3608125534347857
# Mean squared error:               0.018933900659165455
# Mean absolute error:              0.09690539965986404
# Root mean squared error:          0.13760051111520427
# Correlation Coefficient:          0.630422055043134
# -------------------------------------------------------
#
# max_features: 30; max_depth: 20; n_estimators: 160;
#
# Normal feature space
# Coefficient of determination R^2: 0.3566813829257065
# Mean squared error:               0.019056273481794096
# Mean absolute error:              0.09730762648809532
# Root mean squared error:          0.13804446197437295
# Correlation Coefficient:          0.624180504721862
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3637517975007022
# Mean squared error:               0.018846834876731586
# Mean absolute error:              0.09663836185515885
# Root mean squared error:          0.13728377499446753
# Correlation Coefficient:          0.6328777416609863
# -------------------------------------------------------
#
# max_features: 30; max_depth: 20; n_estimators: 200;
#
# Normal feature space
# Coefficient of determination R^2: 0.36297641426611293
# Mean squared error:               0.018869803145610126
# Mean absolute error:              0.09648699404761915
# Root mean squared error:          0.1373674020487034
# Correlation Coefficient:          0.6303282102072976
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3710250358149245
# Mean squared error:               0.018631388261733228
# Mean absolute error:              0.0955784275793652
# Root mean squared error:          0.13649684341307394
# Correlation Coefficient:          0.6409814161510241
# -------------------------------------------------------
#
# max_features: 30; max_depth: 20; n_estimators: 300;
#
# Normal feature space
# Coefficient of determination R^2: 0.357834962119019
# Mean squared error:               0.01902210235724209
# Mean absolute error:              0.0969499801587303
# Root mean squared error:          0.13792063789455908
# Correlation Coefficient:          0.6305313690445803
#
#
# Extended feature space
# Coefficient of determination R^2: 0.36640438922799234
# Mean squared error:               0.01876826026059399
# Mean absolute error:              0.09562176917989432
# Root mean squared error:          0.13699730019454395
# Correlation Coefficient:          0.6377505939291174
# -------------------------------------------------------
#
# max_features: 30; max_depth: 20; n_estimators: 500;
#
# Normal feature space
# Coefficient of determination R^2: 0.3724361943720258
# Mean squared error:               0.01858958716554765
# Mean absolute error:              0.09556859523809548
# Root mean squared error:          0.1363436363221535
# Correlation Coefficient:          0.6454226880627405
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3640093808619195
# Mean squared error:               0.018839204786686874
# Mean absolute error:              0.09599091865079389
# Root mean squared error:          0.13725598269906808
# Correlation Coefficient:          0.637398745383145
# -------------------------------------------------------

# %%
get_best_settings(results_1_rp,results_2_rp)
# Out:
# Normal best: 0.6695793048274998 | max_features: 5; max_depth: 10; n_estimators: 200;
# Extended best: 0.6750835594373267 | max_features: 18; max_depth: 18; n_estimators: 90;
# Best difference: 0.24783162603570874 | max_features: 15; max_depth: 5; n_estimators: 20;
# (5, 10, 200, 18, 18, 90)

# %%
best_RFs(results_1_rp,results_2_rp,'rp')
# Out:
# Normal best: 0.6695793048274998 | max_features: 5; max_depth: 10; n_estimators: 200;
# Extended best: 0.6750835594373267 | max_features: 18; max_depth: 18; n_estimators: 90;
# Best difference: 0.24783162603570874 | max_features: 15; max_depth: 5; n_estimators: 20;
# Normal feature space
# Coefficient of determination R^2: 0.30921436485454656
# Mean squared error:               0.02046233333102247
# Mean absolute error:              0.09996881605596622
# Root mean squared error:          0.14304661244161804
# Correlation Coefficient:          0.6695793048275
#
#
# Extended feature space
# Coefficient of determination R^2: 0.3841484986201381
# Mean squared error:               0.018242647302577335
# Mean absolute error:              0.09664412477954147
# Root mean squared error:          0.13506534456542632
# Correlation Coefficient:          0.6750835594373265
# -------------------------------------------------------

# %%
#BEST RIBOSOMAL PROTEIN

# Normal best: 0.6686151985008865 | max_features: 5; max_depth: 12; n_estimators: 140;
# Extended best: 0.6750835594373263 | max_features: 18; max_depth: 18; n_estimators: 90;
                
X,y,X2,y2 = get_data('rp')

rfr1 = ExtraTreesRegressor(n_estimators=140, 
                            criterion='mse', 
                            max_features=5, 
                            max_depth=12, 
                            n_jobs=2,
                            random_state=1337)

rfr2 = ExtraTreesRegressor(n_estimators=90, 
                            criterion='mse', 
                            max_features=18, 
                            max_depth=18, 
                            n_jobs=2,
                            random_state=1337)

kf = KFold(n_splits=5,shuffle=True,random_state=0)
predictions_rfr1_rp = cross_val_predict(rfr1,X,y=y,cv=kf)
predictions_rfr2_rp = cross_val_predict(rfr2,X2,y=y2,cv=kf)

fit_scatter(y,predictions_rfr1_rp,filename='full_rp_scat',title='RP intron-containing')
fit_scatter(y,predictions_rfr2_rp,filename='full_rp_scat_ext',title='RP intron-containing')

print('Data')
print_stats(y,predictions_rfr1_rp)
print('\n')
print('Extended Data')
print_stats(y2,predictions_rfr2_rp)

rfr1.fit(X,y)
rfr2.fit(X2,y2)

names,names2 = get_variable_names('full')
plot_importance(rfr1.feature_importances_,names,'rp_full')
plot_importance(rfr2.feature_importances_,names2,'rp_full_extended')
# Out:
# Data
# Coefficient of determination R^2: 0.3068923822397889
# Mean squared error:               0.02053111470086379
# Mean absolute error:              0.09984394095554235
# Root mean squared error:          0.1432868266829292
# Correlation Coefficient:          0.6686151985008861
#
#
# Extended Data
# Coefficient of determination R^2: 0.38414849862013833
# Mean squared error:               0.01824264730257733
# Mean absolute error:              0.09664412477954147
# Root mean squared error:          0.1350653445654263
# Correlation Coefficient:          0.6750835594373267

# %% [markdown]
# Normal best: 0.683828520812472 | max_features: 80; max_depth: 12; n_estimators: 10;
# Extended best: 0.6995253307038448 | max_features: 25; max_depth: 5; n_estimators: 10;
# Best difference: 0.178522036722764 | max_features: 7; max_depth: 5; n_estimators: 20;
# Normal feature space
# Coefficient of determination R^2: 0.3526340326994295
# Mean squared error:               0.03376319974358975
# Mean absolute error:              0.13876153846153846
# Root mean squared error:          0.18374765234851234
# Correlation Coefficient:          0.5972822538667238
#
#
# Extended feature space
# Coefficient of determination R^2: 0.32708078033033505
# Mean squared error:               0.03509592282051282
# Mean absolute error:              0.14166068376068375
# Root mean squared error:          0.18733905844887985
# Correlation Coefficient:          0.5756356719726347

# %% [markdown]
# # Non-RP Genes

# %%
X,y,X2,y2 = get_data('nrp')

mxf = [2,4,5,7,10,12,15,18,20,30]
md = [5,7,10,12,15,18,20]
n_est = [10,20,30,40,50,60,80,90,200,300,500]

results_1_nrp = np.zeros((len(mxf),len(md),len(n_est)))
results_2_nrp = np.zeros((len(mxf),len(md),len(n_est)))

f = FloatProgress(min=0, max=(len(mxf)*len(md)*len(n_est)))
display(f)


i = 0
for max_features in mxf:
    j = 0
    for max_depth in md:
        k = 0
        for n_estimators in n_est:            
            
            kf = KFold(n_splits=5,shuffle=True,random_state=0)

            rfr1 = ExtraTreesRegressor(n_estimators=n_estimators, 
                                        criterion='mse', 
                                        max_features=max_features, 
                                        max_depth=max_depth, 
                                        n_jobs=2,
                                        random_state=1337)

            rfr2 = ExtraTreesRegressor(n_estimators=n_estimators, 
                                        criterion='mse', 
                                        max_features=max_features, 
                                        max_depth=max_depth, 
                                        n_jobs=2,
                                        random_state=1337)

            predictions_rfr1 = cross_val_predict(rfr1,X=X,y=y,cv=kf)
            predictions_rfr2 = cross_val_predict(rfr2,X=X2,y=y2,cv=kf)
            
            print('max_features: {}; max_depth: {}; n_estimators: {};\n'.format(max_features,max_depth,n_estimators))

            print('Normal feature space')
            print_stats(y, predictions_rfr1)
            print('\n')
            print('Extended feature space')
            print_stats(y2, predictions_rfr2)
            print('-------------------------------------------------------\n')
            

            results_1_nrp[i][j][k]=np.corrcoef(y, predictions_rfr1)[0][1]
            results_2_nrp[i][j][k]=np.corrcoef(y2, predictions_rfr2)[0][1]
            
            f.value += 1
            
            k += 1
        j += 1
    i += 1
# Out:
# FloatProgress(value=0.0, max=770.0)
# max_features: 2; max_depth: 5; n_estimators: 10;
#
# Normal feature space
# Coefficient of determination R^2: -0.10807282324725986
# Mean squared error:               0.0648238352717465
# Mean absolute error:              0.2078112601119419
# Root mean squared error:          0.25460525381803595
# Correlation Coefficient:          0.007543815690100991
#
#
# Extended feature space
# Coefficient of determination R^2: -0.042139930692752126
# Mean squared error:               0.06096666733451839
# Mean absolute error:              0.20710250903137267
# Root mean squared error:          0.24691429147483218
# Correlation Coefficient:          0.010592640034252603
# -------------------------------------------------------
#
# max_features: 2; max_depth: 5; n_estimators: 20;
#
# Normal feature space
# Coefficient of determination R^2: 0.044590635328434325
# Mean squared error:               0.05589280593585455
# Mean absolute error:              0.1938343623800442
# Root mean squared error:          0.23641659403657467
# Correlation Coefficient:          0.2193094246097312
#
#
# Extended feature space
# Coefficient of determination R^2: -0.0017762827068517062
# Mean squared error:               0.05860533655091797
# Mean absolute error:              0.19789955565898745
# Root mean squared error:          0.24208539103159027
# Correlation Coefficient:          0.11231531010562784
# -------------------------------------------------------
#
# max_features: 2; max_depth: 5; n_estimators: 30;
#
# Normal feature space
# Coefficient of determination R^2: -0.025350068553651628
# Mean squared error:               0.059984436532800105
# Mean absolute error:              0.20202328359070781
# Root mean squared error:          0.24491720342352455
# Correlation Coefficient:          0.0869774672173474
#
#
# Extended feature space
# Coefficient of determination R^2: -0.020671019201929708
# Mean squared error:               0.05971070549451373
# Mean absolute error:              0.1978948740586898
# Root mean squared error:          0.24435774081152767
# Correlation Coefficient:          0.05145668595994056
# -------------------------------------------------------
#
# max_features: 2; max_depth: 5; n_estimators: 40;
#
# Normal feature space
# Coefficient of determination R^2: -0.008781395877829334
# Mean squared error:               0.0590151456291017
# Mean absolute error:              0.200209986476066
# Root mean squared error:          0.2429303308133871
# Correlation Coefficient:          0.11245485894797147
#
#
# Extended feature space
# Coefficient of determination R^2: -0.01306876840732385
# Mean squared error:               0.05926596301652402
# Mean absolute error:              0.19935716408408843
# Root mean squared error:          0.24344601663720855
# Correlation Coefficient:          0.05481195468785077
# -------------------------------------------------------
#
# max_features: 2; max_depth: 5; n_estimators: 50;
#
# Normal feature space
# Coefficient of determination R^2: -0.015478501460816751
# Mean squared error:               0.059406935825559025
# Mean absolute error:              0.20063329306972486
# Root mean squared error:          0.24373538074222836
# Correlation Coefficient:          0.09145222665486193
#
#
# Extended feature space
# Coefficient of determination R^2: -0.023542552522085147
# Mean squared error:               0.059878694275591844
# Mean absolute error:              0.19922069421677913
# Root mean squared error:          0.24470123472428953
# Correlation Coefficient:          0.021141685634198035
# -------------------------------------------------------
#
# max_features: 2; max_depth: 5; n_estimators: 60;
#
# Normal feature space
# Coefficient of determination R^2: 0.0200828991838079
# Mean squared error:               0.05732654333775831
# Mean absolute error:              0.1974811142786209
# Root mean squared error:          0.2394296208445361
# Correlation Coefficient:          0.15624170895068903
#
#
# Extended feature space
# Coefficient of determination R^2: 0.009922854527022906
# Mean squared error:               0.057920920392557765
# Mean absolute error:              0.1963593184787119
# Root mean squared error:          0.24066765547650512
# Correlation Coefficient:          0.1155730375258471
# -------------------------------------------------------
#
# max_features: 2; max_depth: 5; n_estimators: 80;
#
# Normal feature space
# Coefficient of determination R^2: 0.03654574610345884
# Mean squared error:               0.05636344339122592
# Mean absolute error:              0.1948677362184631
# Root mean squared error:          0.23740986371931963
# Correlation Coefficient:          0.1940059923714355
#
#
# Extended feature space
# Coefficient of determination R^2: 0.0038302459133393585
# Mean squared error:               0.058277346657025865
# Mean absolute error:              0.19714288366721472
# Root mean squared error:          0.2414070145149595
# Correlation Coefficient:          0.10074757073504573
# -------------------------------------------------------
#
# max_features: 2; max_depth: 5; n_estimators: 90;
#
# Normal feature space
# Coefficient of determination R^2: 0.04516032594612929
# Mean squared error:               0.05585947822491124
# Mean absolute error:              0.1932847772154233
# Root mean squared error:          0.23634609839155635
# Correlation Coefficient:          0.21735269862966164
#
#
# Extended feature space
# Coefficient of determination R^2: -0.0034063265775381435
# Mean squared error:               0.058700696434440286
# Mean absolute error:              0.19795854696272508
# Root mean squared error:          0.2422822660337324
# Correlation Coefficient:          0.07923664811335852
# -------------------------------------------------------
#
# max_features: 2; max_depth: 5; n_estimators: 200;
#
# Normal feature space
# Coefficient of determination R^2: 0.06477955296341043
# Mean squared error:               0.054711725555912305
# Mean absolute error:              0.192627678814846
# Root mean squared error:          0.23390537735569977
# Correlation Coefficient:          0.28364544534776076
#
#
# Extended feature space
# Coefficient of determination R^2: -0.0074550847342904625
# Mean squared error:               0.05893755454186983
# Mean absolute error:              0.19690011369096744
# Root mean squared error:          0.24277058005835433
# Correlation Coefficient:          0.05777462247307815
# -------------------------------------------------------
#
# max_features: 2; max_depth: 5; n_estimators: 300;
#
# Normal feature space
# Coefficient of determination R^2: 0.04148282893501487
# Mean squared error:               0.05607461702757785
# Mean absolute error:              0.19556570006745205
# Root mean squared error:          0.2368007960872975
# Correlation Coefficient:          0.21152049979492848
#
#
# Extended feature space
# Coefficient of determination R^2: 0.012130900969634317
# Mean squared error:               0.05779174653695435
# Mean absolute error:              0.195835172668108
# Root mean squared error:          0.24039914005036364
# Correlation Coefficient:          0.11809952851575584
# -------------------------------------------------------
#
# max_features: 2; max_depth: 5; n_estimators: 500;
#
# Normal feature space
# Coefficient of determination R^2: 0.025333686456750937
# Mean squared error:               0.057019364818362124
# Mean absolute error:              0.19685680047831425
# Root mean squared error:          0.2387872794316358
# Correlation Coefficient:          0.1623998866435845
#
#
# Extended feature space
# Coefficient of determination R^2: 0.012088813777522245
# Mean squared error:               0.05779420869751932
# Mean absolute error:              0.19688512025709842
# Root mean squared error:          0.24040426098037307
# Correlation Coefficient:          0.11723966776086428
# -------------------------------------------------------
#
# max_features: 2; max_depth: 7; n_estimators: 10;
#
# Normal feature space
# Coefficient of determination R^2: -0.0013862995545068646
# Mean squared error:               0.058582521982149575
# Mean absolute error:              0.19161266113516115
# Root mean squared error:          0.2420382655328483
# Correlation Coefficient:          0.14327858026779836
#
#
# Extended feature space
# Coefficient of determination R^2: -0.06045516289395625
# Mean squared error:               0.06203813445316435
# Mean absolute error:              0.19897620425029514
# Root mean squared error:          0.24907455601318323
# Correlation Coefficient:          0.04448236014885901
# -------------------------------------------------------
# max_features: 2; max_depth: 7; n_estimators: 20;
#
# Normal feature space
# Coefficient of determination R^2: 0.13315430069337642
# Mean squared error:               0.05071170561985302
# Mean absolute error:              0.17559480339105338
# Root mean squared error:          0.22519259672523212
# Correlation Coefficient:          0.38280813385552753
#
#
# Extended feature space
# Coefficient of determination R^2: 0.023167125297899327
# Mean squared error:               0.057146111725894774
# Mean absolute error:              0.1916065027985483
# Root mean squared error:          0.23905252921877815
# Correlation Coefficient:          0.17989726894865177
# -------------------------------------------------------
#
# max_features: 2; max_depth: 7; n_estimators: 30;
#
# Normal feature space
# Coefficient of determination R^2: 0.029481485996935675
# Mean squared error:               0.05677671264921569
# Mean absolute error:              0.19261197884326672
# Root mean squared error:          0.23827864497099963
# Correlation Coefficient:          0.18645791313591364
#
#
# Extended feature space
# Coefficient of determination R^2: 0.025439728996519806
# Mean squared error:               0.05701316117904749
# Mean absolute error:              0.19380919658343895
# Root mean squared error:          0.23877428919179614
# Correlation Coefficient:          0.17331386234832613
# -------------------------------------------------------
#
# max_features: 2; max_depth: 7; n_estimators: 40;
#
# Normal feature space
# Coefficient of determination R^2: 0.0422975240309541
# Mean squared error:               0.056026956206386425
# Mean absolute error:              0.19505554618151205
# Root mean squared error:          0.23670013985290847
# Correlation Coefficient:          0.21215368874405607
#
#
# Extended feature space
# Coefficient of determination R^2: 0.006976703555788166
# Mean squared error:               0.05809327441229207
# Mean absolute error:              0.19697689954195635
# Root mean squared error:          0.24102546424038285
# Correlation Coefficient:          0.1260816590560145
# -------------------------------------------------------
#
# max_features: 2; max_depth: 7; n_estimators: 50;
#
# Normal feature space
# Coefficient of determination R^2: 0.06096920913434223
# Mean squared error:               0.05493463608626931
# Mean absolute error:              0.1908502166907167
# Root mean squared error:          0.23438139023025978
# Correlation Coefficient:          0.2504626799151679
#
#
# Extended feature space
# Coefficient of determination R^2: 0.011002039006794861
# Mean squared error:               0.05785778656644374
# Mean absolute error:              0.1966205369495824
# Root mean squared error:          0.24053645579504937
# Correlation Coefficient:          0.13557728348723042
# -------------------------------------------------------
#
# max_features: 2; max_depth: 7; n_estimators: 60;
#
# Normal feature space
# Coefficient of determination R^2: 0.05839584759176497
# Mean squared error:               0.05508518139451161
# Mean absolute error:              0.1901772941718775
# Root mean squared error:          0.23470232507265795
# Correlation Coefficient:          0.24875886886465273
#
#
# Extended feature space
# Coefficient of determination R^2: 0.027055257400905863
# Mean squared error:               0.056918650470937304
# Mean absolute error:              0.1952565479470025
# Root mean squared error:          0.238576299055328
# Correlation Coefficient:          0.17297512124545006
# -------------------------------------------------------
#
# max_features: 2; max_depth: 7; n_estimators: 80;
#
# Normal feature space
# Coefficient of determination R^2: 0.056219171779145594
# Mean squared error:               0.055212520023667534
# Mean absolute error:              0.1906229746600201
# Root mean squared error:          0.2349734453585501
# Correlation Coefficient:          0.2465143447523913
#
#
# Extended feature space
# Coefficient of determination R^2: 0.018983190150417828
# Mean squared error:               0.057390877879434386
# Mean absolute error:              0.1984918414918415
# Root mean squared error:          0.23956393275999288
# Correlation Coefficient:          0.15980640274469776
# -------------------------------------------------------
#
# max_features: 2; max_depth: 7; n_estimators: 90;
#
# Normal feature space
# Coefficient of determination R^2: 0.06199173312229689
# Mean squared error:               0.05487481697946879
# Mean absolute error:              0.18944105804315398
# Root mean squared error:          0.23425374485687264
# Correlation Coefficient:          0.25912659533179855
#
#
# Extended feature space
# Coefficient of determination R^2: -0.0025740781533170054
# Mean squared error:               0.05865200871859254
# Mean absolute error:              0.1994942293406182
# Root mean squared error:          0.24218176793184193
# Correlation Coefficient:          0.11212737369576796
# -------------------------------------------------------
#
# max_features: 2; max_depth: 7; n_estimators: 200;
#
# Normal feature space
# Coefficient of determination R^2: 0.09965408272639731
# Mean squared error:               0.05267151599106584
# Mean absolute error:              0.18805289513895188
# Root mean squared error:          0.2295027581338966
# Correlation Coefficient:          0.36627784511611094
#
#
# Extended feature space
# Coefficient of determination R^2: 0.010366229374997094
# Mean squared error:               0.05789498233369942
# Mean absolute error:              0.19792123612771897
# Root mean squared error:          0.24061376172966378
# Correlation Coefficient:          0.12554535038194412
# -------------------------------------------------------
#
# max_features: 2; max_depth: 7; n_estimators: 300;
#
# Normal feature space
# Coefficient of determination R^2: 0.06675572293528598
# Mean squared error:               0.05459611680345647
# Mean absolute error:              0.1918420083464515
# Root mean squared error:          0.23365811948968618
# Correlation Coefficient:          0.27863332938288804
#
#
# Extended feature space
# Coefficient of determination R^2: 0.029600348753311634
# Mean squared error:               0.056769759009005764
# Mean absolute error:              0.19570104468665434
# Root mean squared error:          0.23826405311965496
# Correlation Coefficient:          0.1731172647136784
# -------------------------------------------------------
#
# max_features: 2; max_depth: 7; n_estimators: 500;
#
# Normal feature space
# Coefficient of determination R^2: 0.04069281105165656
# Mean squared error:               0.05612083419675493
# Mean absolute error:              0.19436645639066308
# Root mean squared error:          0.2368983625877455
# Correlation Coefficient:          0.20725489753642407
#
#
# Extended feature space
# Coefficient of determination R^2: 0.02664693483352687
# Mean squared error:               0.056942537921554445
# Mean absolute error:              0.1963641055443713
# Root mean squared error:          0.23862635630113127
# Correlation Coefficient:          0.16470810461925212
# -------------------------------------------------------
#
# max_features: 2; max_depth: 10; n_estimators: 10;
#
# Normal feature space
# Coefficient of determination R^2: -0.021218892063160855
# Mean squared error:               0.05974275683569023
# Mean absolute error:              0.19441313131313132
# Root mean squared error:          0.2444233148365561
# Correlation Coefficient:          0.13355295997972993
#
#
# Extended feature space
# Coefficient of determination R^2: -0.12842382528865626
# Mean squared error:               0.0660143978198653
# Mean absolute error:              0.2090348484848485
# Root mean squared error:          0.2569326717641517
# Correlation Coefficient:          0.0018303663011396583
# -------------------------------------------------------
#
# max_features: 2; max_depth: 10; n_estimators: 20;
#
# Normal feature space
# Coefficient of determination R^2: 0.11691887574719495
# Mean squared error:               0.051661501057659924
# Mean absolute error:              0.18292853535353534
# Root mean squared error:          0.2272916651741984
# Correlation Coefficient:          0.36197404499914754
#
#
# Extended feature space
# Coefficient of determination R^2: -0.12652675643245814
# Mean squared error:               0.06590341659511785
# Mean absolute error:              0.20300909090909094
# Root mean squared error:          0.2567166075561101
# Correlation Coefficient:          -0.07915242408341178
# -------------------------------------------------------
# max_features: 2; max_depth: 10; n_estimators: 30;
#
# Normal feature space
# Coefficient of determination R^2: -0.007810971514991438
# Mean squared error:               0.05895837442442948
# Mean absolute error:              0.1987631313131313
# Root mean squared error:          0.24281345602010915
# Correlation Coefficient:          0.10338356540274891
#
#
# Extended feature space
# Coefficient of determination R^2: -0.09629894873169165
# Mean squared error:               0.0641350468761691
# Mean absolute error:              0.20458855218855218
# Root mean squared error:          0.2532489819844674
# Correlation Coefficient:          -0.043761157561521574
# -------------------------------------------------------
#
# max_features: 2; max_depth: 10; n_estimators: 40;
#
# Normal feature space
# Coefficient of determination R^2: 0.0067533623044635505
# Mean squared error:               0.05810634019297139
# Mean absolute error:              0.20008207070707074
# Root mean squared error:          0.24105256728143634
# Correlation Coefficient:          0.14725940474914276
#
#
# Extended feature space
# Coefficient of determination R^2: -0.08768123083457735
# Mean squared error:               0.06363089812920875
# Mean absolute error:              0.20576186868686866
# Root mean squared error:          0.25225165634581814
# Correlation Coefficient:          -0.07756543654967649
# -------------------------------------------------------
#
# max_features: 2; max_depth: 10; n_estimators: 50;
#
# Normal feature space
# Coefficient of determination R^2: 0.031090601588043998
# Mean squared error:               0.05668257709979799
# Mean absolute error:              0.19597797979797982
# Root mean squared error:          0.2380810305332997
# Correlation Coefficient:          0.18721761007051163
#
#
# Extended feature space
# Coefficient of determination R^2: -0.0801329901200829
# Mean squared error:               0.06318931531768021
# Mean absolute error:              0.20319053391053393
# Root mean squared error:          0.2513748502091651
# Correlation Coefficient:          -0.06159991220605439
# -------------------------------------------------------
#
# max_features: 2; max_depth: 10; n_estimators: 60;
#
# Normal feature space
# Coefficient of determination R^2: 0.061412678976721535
# Mean squared error:               0.054908692470103236
# Mean absolute error:              0.1934595749158249
# Root mean squared error:          0.23432603882220013
# Correlation Coefficient:          0.25696328050571277
#
#
# Extended feature space
# Coefficient of determination R^2: -0.05487373866670997
# Mean squared error:               0.0617116132019451
# Mean absolute error:              0.2001202934102934
# Root mean squared error:          0.24841822236290376
# Correlation Coefficient:          0.004969422401548705
# -------------------------------------------------------
#
# max_features: 2; max_depth: 10; n_estimators: 80;
#
# Normal feature space
# Coefficient of determination R^2: 0.05615721222687797
# Mean squared error:               0.05521614474554992
# Mean absolute error:              0.19229141308922557
# Root mean squared error:          0.23498115827774346
# Correlation Coefficient:          0.24790773540007582
#
#
# Extended feature space
# Coefficient of determination R^2: -0.05582312353422836
# Mean squared error:               0.061767153566233746
# Mean absolute error:              0.2010059397546897
# Root mean squared error:          0.24852998524571185
# Correlation Coefficient:          0.004951145603743728
# -------------------------------------------------------
#
# max_features: 2; max_depth: 10; n_estimators: 90;
#
# Normal feature space
# Coefficient of determination R^2: 0.0718884897509785
# Mean squared error:               0.05429584264857406
# Mean absolute error:              0.1903200888514777
# Root mean squared error:          0.2330146833325618
# Correlation Coefficient:          0.2842406352793612
#
#
# Extended feature space
# Coefficient of determination R^2: -0.06436786008598894
# Mean squared error:               0.06226703280074881
# Mean absolute error:              0.20135151996151993
# Root mean squared error:          0.24953363060066433
# Correlation Coefficient:          -0.0187096810995906
# -------------------------------------------------------
#
# max_features: 2; max_depth: 10; n_estimators: 200;
#
# Normal feature space
# Coefficient of determination R^2: 0.08564462002343876
# Mean squared error:               0.05349108947346648
# Mean absolute error:              0.19026433543771037
# Root mean squared error:          0.2312814075395307
# Correlation Coefficient:          0.33291618129928685
#
#
# Extended feature space
# Coefficient of determination R^2: -0.008764046571113848
# Mean squared error:               0.059014130669997014
# Mean absolute error:              0.1985713784271284
# Root mean squared error:          0.24292824181226236
# Correlation Coefficient:          0.07680875880156159
# -------------------------------------------------------
#
# max_features: 2; max_depth: 10; n_estimators: 300;
#
# Normal feature space
# Coefficient of determination R^2: 0.05839726535073231
# Mean squared error:               0.0550850984535967
# Mean absolute error:              0.1933858793490459
# Root mean squared error:          0.23470214837874132
# Correlation Coefficient:          0.2573882903361384
#
#
# Extended feature space
# Coefficient of determination R^2: 0.0009221214786118148
# Mean squared error:               0.05844747607032026
# Mean absolute error:              0.19827561423761406
# Root mean squared error:          0.24175912820474899
# Correlation Coefficient:          0.09104010956043153
# -------------------------------------------------------
#
# max_features: 2; max_depth: 10; n_estimators: 500;
#
# Normal feature space
# Coefficient of determination R^2: 0.0351615006438486
# Mean squared error:               0.05644442371830088
# Mean absolute error:              0.19549085579605566
# Root mean squared error:          0.23758035213018117
# Correlation Coefficient:          0.19196310376593634
#
#
# Extended feature space
# Coefficient of determination R^2: 0.011162075577580644
# Mean squared error:               0.05784842419956277
# Mean absolute error:              0.1979131355218854
# Root mean squared error:          0.24051699357750747
# Correlation Coefficient:          0.12045194271920533
# -------------------------------------------------------
#
# max_features: 2; max_depth: 12; n_estimators: 10;
#
# Normal feature space
# Coefficient of determination R^2: -0.08140927101745432
# Mean squared error:               0.06326397956439392
# Mean absolute error:              0.2051901515151515
# Root mean squared error:          0.2515233181325221
# Correlation Coefficient:          0.037896681317667845
#
#
# Extended feature space
# Coefficient of determination R^2: -0.11738052043283465
# Mean squared error:               0.06536834878787878
# Mean absolute error:              0.2096030303030303
# Root mean squared error:          0.2556723465451021
# Correlation Coefficient:          -0.009926324208372111
# -------------------------------------------------------
#
# max_features: 2; max_depth: 12; n_estimators: 20;
#
# Normal feature space
# Coefficient of determination R^2: 0.05963293401084513
# Mean squared error:               0.055012810080492414
# Mean absolute error:              0.1875526515151515
# Root mean squared error:          0.2345480975844665
# Correlation Coefficient:          0.24436991931825625
#
#
# Extended feature space
# Coefficient of determination R^2: -0.130062364569701
# Mean squared error:               0.0661102546969697
# Mean absolute error:              0.20654242424242422
# Root mean squared error:          0.257119144944459
# Correlation Coefficient:          -0.08766728371030806
# -------------------------------------------------------
#
# max_features: 2; max_depth: 12; n_estimators: 30;
#
# Normal feature space
# Coefficient of determination R^2: -0.038520556052169974
# Mean squared error:               0.06075492877314815
# Mean absolute error:              0.20214621212121212
# Root mean squared error:          0.24648514919391828
# Correlation Coefficient:          0.04372660050361859
#
#
# Extended feature space
# Coefficient of determination R^2: -0.11541249089910899
# Mean squared error:               0.06525321626262626
# Mean absolute error:              0.2079383838383838
# Root mean squared error:          0.2554470909261373
# Correlation Coefficient:          -0.08092238223307464
# -------------------------------------------------------
# max_features: 2; max_depth: 12; n_estimators: 40;
#
# Normal feature space
# Coefficient of determination R^2: -0.01993532772600526
# Mean squared error:               0.059667666497395834
# Mean absolute error:              0.20327178030303028
# Root mean squared error:          0.24426965938772632
# Correlation Coefficient:          0.09579223883106755
#
#
# Extended feature space
# Coefficient of determination R^2: -0.08567261180251529
# Mean squared error:               0.06351339106060606
# Mean absolute error:              0.20564242424242424
# Root mean squared error:          0.25201863236793837
# Correlation Coefficient:          -0.08073852023896146
# -------------------------------------------------------
#
# max_features: 2; max_depth: 12; n_estimators: 50;
#
# Normal feature space
# Coefficient of determination R^2: 0.00846282770388751
# Mean squared error:               0.05800633403712121
# Mean absolute error:              0.19927742424242423
# Root mean squared error:          0.24084504154564032
# Correlation Coefficient:          0.1362378088947866
#
#
# Extended feature space
# Coefficient of determination R^2: -0.06889817920649532
# Mean squared error:               0.06253206290909091
# Mean absolute error:              0.2022339393939394
# Root mean squared error:          0.2500641175960496
# Correlation Coefficient:          -0.04449644839444391
# -------------------------------------------------------
#
# max_features: 2; max_depth: 12; n_estimators: 60;
#
# Normal feature space
# Coefficient of determination R^2: 0.04280611206507878
# Mean squared error:               0.05599720308343854
# Mean absolute error:              0.19574760101010097
# Root mean squared error:          0.2366372816853645
# Correlation Coefficient:          0.21120691518722232
#
#
# Extended feature space
# Coefficient of determination R^2: -0.047690945289465825
# Mean squared error:               0.06129140957912457
# Mean absolute error:              0.1997838383838384
# Root mean squared error:          0.2475710192634117
# Correlation Coefficient:          0.013163538575907647
# -------------------------------------------------------
#
# max_features: 2; max_depth: 12; n_estimators: 80;
#
# Normal feature space
# Coefficient of determination R^2: 0.040477110700511854
# Mean squared error:               0.05613345297391228
# Mean absolute error:              0.1948051452020202
# Root mean squared error:          0.23692499440521736
# Correlation Coefficient:          0.20713694374410968
#
#
# Extended feature space
# Coefficient of determination R^2: -0.05520884650125257
# Mean squared error:               0.061731217486617466
# Mean absolute error:              0.2014120896464646
# Root mean squared error:          0.24845767745557285
# Correlation Coefficient:          -0.0006180458104434959
# -------------------------------------------------------
#
# max_features: 2; max_depth: 12; n_estimators: 90;
#
# Normal feature space
# Coefficient of determination R^2: 0.07056102767176453
# Mean squared error:               0.05437350106717897
# Mean absolute error:              0.19208672839506166
# Root mean squared error:          0.23318126225573738
# Correlation Coefficient:          0.28048994959282153
#
#
# Extended feature space
# Coefficient of determination R^2: -0.06452305370619582
# Mean squared error:               0.06227611184813672
# Mean absolute error:              0.20161714365881034
# Root mean squared error:          0.24955182196917883
# Correlation Coefficient:          -0.025317729892202878
# -------------------------------------------------------
#
# max_features: 2; max_depth: 12; n_estimators: 200;
#
# Normal feature space
# Coefficient of determination R^2: 0.09258942696374062
# Mean squared error:               0.05308480839550185
# Mean absolute error:              0.18992582070707062
# Root mean squared error:          0.2304014071039972
# Correlation Coefficient:          0.3499709092154275
#
#
# Extended feature space
# Coefficient of determination R^2: -0.016839677875320147
# Mean squared error:               0.059486566580702865
# Mean absolute error:              0.19935941919191918
# Root mean squared error:          0.24389868097368395
# Correlation Coefficient:          0.05812461112582096
# -------------------------------------------------------
#
# max_features: 2; max_depth: 12; n_estimators: 300;
#
# Normal feature space
# Coefficient of determination R^2: 0.060282575778917935
# Mean squared error:               0.054974805113602435
# Mean absolute error:              0.1935562193362192
# Root mean squared error:          0.23446706615983925
# Correlation Coefficient:          0.2628666397813177
#
#
# Extended feature space
# Coefficient of determination R^2: -0.0013341279968726028
# Mean squared error:               0.058579469871866754
# Mean absolute error:              0.19844562289562273
# Root mean squared error:          0.24203196043470532
# Correlation Coefficient:          0.08454434153529976
# -------------------------------------------------------
#
# max_features: 2; max_depth: 12; n_estimators: 500;
#
# Normal feature space
# Coefficient of determination R^2: 0.032134843948659286
# Mean squared error:               0.056621487437324425
# Mean absolute error:              0.19592453593073575
# Root mean squared error:          0.23795270000007235
# Correlation Coefficient:          0.1829808188156599
#
#
# Extended feature space
# Coefficient of determination R^2: 0.013394869953058053
# Mean squared error:               0.05771780255470782
# Mean absolute error:              0.1977455404040403
# Root mean squared error:          0.2402452966338942
# Correlation Coefficient:          0.12739323989822485
# -------------------------------------------------------
#
# max_features: 2; max_depth: 15; n_estimators: 10;
#
# Normal feature space
# Coefficient of determination R^2: -0.08688676256412697
# Mean squared error:               0.0635844206060606
# Mean absolute error:              0.20716363636363636
# Root mean squared error:          0.25215951420888444
# Correlation Coefficient:          0.037362797141843075
#
#
# Extended feature space
# Coefficient of determination R^2: -0.07949082728135082
# Mean squared error:               0.06315174787878788
# Mean absolute error:              0.2043818181818182
# Root mean squared error:          0.25130011515872386
# Correlation Coefficient:          0.04667010151362432
# -------------------------------------------------------
#
# max_features: 2; max_depth: 15; n_estimators: 20;
#
# Normal feature space
# Coefficient of determination R^2: 0.06464870835471204
# Mean squared error:               0.05471938015151515
# Mean absolute error:              0.1877121212121212
# Root mean squared error:          0.23392173937348182
# Correlation Coefficient:          0.25454839606566115
#
#
# Extended feature space
# Coefficient of determination R^2: -0.11229697910380199
# Mean squared error:               0.0650709543939394
# Mean absolute error:              0.20390303030303028
# Root mean squared error:          0.255090090740388
# Correlation Coefficient:          -0.06122211027597727
# -------------------------------------------------------
#
# max_features: 2; max_depth: 15; n_estimators: 30;
#
# Normal feature space
# Coefficient of determination R^2: -0.02951336027958873
# Mean squared error:               0.06022799501683501
# Mean absolute error:              0.20044848484848488
# Root mean squared error:          0.24541392588203917
# Correlation Coefficient:          0.06399227230412213
#
#
# Extended feature space
# Coefficient of determination R^2: -0.10464600814641178
# Mean squared error:               0.0646233617171717
# Mean absolute error:              0.20727373737373736
# Root mean squared error:          0.25421125411195256
# Correlation Coefficient:          -0.06519176143296701
# -------------------------------------------------------
#
# max_features: 2; max_depth: 15; n_estimators: 40;
#
# Normal feature space
# Coefficient of determination R^2: -0.012745614749489764
# Mean squared error:               0.05924705806818181
# Mean absolute error:              0.20216363636363638
# Root mean squared error:          0.24340718573653863
# Correlation Coefficient:          0.11088291043982237
#
#
# Extended feature space
# Coefficient of determination R^2: -0.07715659171899292
# Mean squared error:               0.06301519178030301
# Mean absolute error:              0.20508484848484848
# Root mean squared error:          0.2510282688867989
# Correlation Coefficient:          -0.06702463472923843
# -------------------------------------------------------
# max_features: 2; max_depth: 15; n_estimators: 50;
#
# Normal feature space
# Coefficient of determination R^2: 0.011235635554239343
# Mean squared error:               0.057844120836363644
# Mean absolute error:              0.19854121212121215
# Root mean squared error:          0.2405080473422119
# Correlation Coefficient:          0.14445372866226602
#
#
# Extended feature space
# Coefficient of determination R^2: -0.059091324003522905
# Mean squared error:               0.06195834793939392
# Mean absolute error:              0.20160666666666666
# Root mean squared error:          0.24891433855725129
# Correlation Coefficient:          -0.027875061350486757
# -------------------------------------------------------
#
# max_features: 2; max_depth: 15; n_estimators: 60;
#
# Normal feature space
# Coefficient of determination R^2: 0.04554205688162549
# Mean squared error:               0.05583714642255892
# Mean absolute error:              0.19522575757575758
# Root mean squared error:          0.2362988498121794
# Correlation Coefficient:          0.21769891534790273
#
#
# Extended feature space
# Coefficient of determination R^2: -0.04033804127855234
# Mean squared error:               0.06086125424242423
# Mean absolute error:              0.19967575757575756
# Root mean squared error:          0.24670073822837302
# Correlation Coefficient:          0.027171618298802578
# -------------------------------------------------------
#
# max_features: 2; max_depth: 15; n_estimators: 80;
#
# Normal feature space
# Coefficient of determination R^2: 0.04128691361529402
# Mean squared error:               0.056086078352272715
# Mean absolute error:              0.1948863636363636
# Root mean squared error:          0.23682499520167358
# Correlation Coefficient:          0.2089053227692111
#
#
# Extended feature space
# Coefficient of determination R^2: -0.05145902582580697
# Mean squared error:               0.061511847646780304
# Mean absolute error:              0.2013647727272727
# Root mean squared error:          0.24801582136384023
# Correlation Coefficient:          0.00595321844402283
# -------------------------------------------------------
#
# max_features: 2; max_depth: 15; n_estimators: 90;
#
# Normal feature space
# Coefficient of determination R^2: 0.07170868302809075
# Mean squared error:               0.05430636159745602
# Mean absolute error:              0.19161313131313126
# Root mean squared error:          0.23303725366871283
# Correlation Coefficient:          0.2825344641773689
#
#
# Extended feature space
# Coefficient of determination R^2: -0.06138241492340657
# Mean squared error:               0.062092380014964456
# Mean absolute error:              0.2013582491582491
# Root mean squared error:          0.24918342644518807
# Correlation Coefficient:          -0.019492561681472093
# -------------------------------------------------------
#
# max_features: 2; max_depth: 15; n_estimators: 200;
#
# Normal feature space
# Coefficient of determination R^2: 0.09609561629521335
# Mean squared error:               0.05287969133560602
# Mean absolute error:              0.18954712121212108
# Root mean squared error:          0.22995584649146458
# Correlation Coefficient:          0.3590367724033549
#
#
# Extended feature space
# Coefficient of determination R^2: -0.013143025553851606
# Mean squared error:               0.05927030716515152
# Mean absolute error:              0.19910090909090905
# Root mean squared error:          0.24345493867480184
# Correlation Coefficient:          0.0647850679136806
# -------------------------------------------------------
#
# max_features: 2; max_depth: 15; n_estimators: 300;
#
# Normal feature space
# Coefficient of determination R^2: 0.061266622271962334
# Mean squared error:               0.054917236994949443
# Mean absolute error:              0.19368636363636355
# Root mean squared error:          0.23434427024134694
# Correlation Coefficient:          0.26604182072020405
#
#
# Extended feature space
# Coefficient of determination R^2: 0.0010490484519852794
# Mean squared error:               0.05844005066195279
# Mean absolute error:              0.19823616161616145
# Root mean squared error:          0.24174377067869357
# Correlation Coefficient:          0.09033438101206719
# -------------------------------------------------------
#
# max_features: 2; max_depth: 15; n_estimators: 500;
#
# Normal feature space
# Coefficient of determination R^2: 0.033611769420488935
# Mean squared error:               0.05653508519779114
# Mean absolute error:              0.19588913131313113
# Root mean squared error:          0.23777107729450853
# Correlation Coefficient:          0.18725030953285413
#
#
# Extended feature space
# Coefficient of determination R^2: 0.013720209931280758
# Mean squared error:               0.05769876970351505
# Mean absolute error:              0.19770545454545435
# Root mean squared error:          0.2402056820799938
# Correlation Coefficient:          0.1280650884227734
# -------------------------------------------------------
#
# max_features: 2; max_depth: 18; n_estimators: 10;
#
# Normal feature space
# Coefficient of determination R^2: -0.08688676256412697
# Mean squared error:               0.0635844206060606
# Mean absolute error:              0.20716363636363636
# Root mean squared error:          0.25215951420888444
# Correlation Coefficient:          0.037362797141843054
#
#
# Extended feature space
# Coefficient of determination R^2: -0.07949082728135082
# Mean squared error:               0.06315174787878788
# Mean absolute error:              0.2043818181818182
# Root mean squared error:          0.25130011515872386
# Correlation Coefficient:          0.046670101513624294
# -------------------------------------------------------
#
# max_features: 2; max_depth: 18; n_estimators: 20;
#
# Normal feature space
# Coefficient of determination R^2: 0.06464870835471204
# Mean squared error:               0.05471938015151515
# Mean absolute error:              0.1877121212121212
# Root mean squared error:          0.23392173937348182
# Correlation Coefficient:          0.25454839606566115
#
#
# Extended feature space
# Coefficient of determination R^2: -0.11229697910380199
# Mean squared error:               0.0650709543939394
# Mean absolute error:              0.20390303030303028
# Root mean squared error:          0.255090090740388
# Correlation Coefficient:          -0.06122211027597706
# -------------------------------------------------------
#
# max_features: 2; max_depth: 18; n_estimators: 30;
#
# Normal feature space
# Coefficient of determination R^2: -0.02951336027958873
# Mean squared error:               0.06022799501683501
# Mean absolute error:              0.20044848484848482
# Root mean squared error:          0.24541392588203917
# Correlation Coefficient:          0.06399227230412231
#
#
# Extended feature space
# Coefficient of determination R^2: -0.104646008146412
# Mean squared error:               0.06462336171717172
# Mean absolute error:              0.20727373737373736
# Root mean squared error:          0.25421125411195256
# Correlation Coefficient:          -0.0651917614329672
# -------------------------------------------------------
#
# max_features: 2; max_depth: 18; n_estimators: 40;
#
# Normal feature space
# Coefficient of determination R^2: -0.012745614749489764
# Mean squared error:               0.05924705806818181
# Mean absolute error:              0.20216363636363638
# Root mean squared error:          0.24340718573653863
# Correlation Coefficient:          0.11088291043982242
#
#
# Extended feature space
# Coefficient of determination R^2: -0.07715659171899292
# Mean squared error:               0.06301519178030301
# Mean absolute error:              0.20508484848484848
# Root mean squared error:          0.2510282688867989
# Correlation Coefficient:          -0.06702463472923838
# -------------------------------------------------------
#
# max_features: 2; max_depth: 18; n_estimators: 50;
#
# Normal feature space
# Coefficient of determination R^2: 0.011235635554239343
# Mean squared error:               0.057844120836363644
# Mean absolute error:              0.19854121212121215
# Root mean squared error:          0.2405080473422119
# Correlation Coefficient:          0.14445372866226602
#
#
# Extended feature space
# Coefficient of determination R^2: -0.059091324003522905
# Mean squared error:               0.06195834793939392
# Mean absolute error:              0.20160666666666666
# Root mean squared error:          0.24891433855725129
# Correlation Coefficient:          -0.027875061350486847
# -------------------------------------------------------
# max_features: 2; max_depth: 18; n_estimators: 60;
#
# Normal feature space
# Coefficient of determination R^2: 0.04554205688162549
# Mean squared error:               0.05583714642255892
# Mean absolute error:              0.19522575757575758
# Root mean squared error:          0.2362988498121794
# Correlation Coefficient:          0.21769891534790276
#
#
# Extended feature space
# Coefficient of determination R^2: -0.04033804127855234
# Mean squared error:               0.06086125424242423
# Mean absolute error:              0.19967575757575756
# Root mean squared error:          0.24670073822837302
# Correlation Coefficient:          0.027171618298802516
# -------------------------------------------------------
#
# max_features: 2; max_depth: 18; n_estimators: 80;
#
# Normal feature space
# Coefficient of determination R^2: 0.04195676265854198
# Mean squared error:               0.0560468912310606
# Mean absolute error:              0.1947992424242424
# Root mean squared error:          0.23674224640114533
# Correlation Coefficient:          0.2105491248659135
#
#
# Extended feature space
# Coefficient of determination R^2: -0.051110784724757385
# Mean squared error:               0.06149147504734848
# Mean absolute error:              0.20132272727272724
# Root mean squared error:          0.24797474679359688
# Correlation Coefficient:          0.0067683850873698605
# -------------------------------------------------------
#
# max_features: 2; max_depth: 18; n_estimators: 90;
#
# Normal feature space
# Coefficient of determination R^2: 0.07229010209894471
# Mean squared error:               0.05427234775533106
# Mean absolute error:              0.1915356902356902
# Root mean squared error:          0.23296426282872457
# Correlation Coefficient:          0.28396952210412185
#
#
# Extended feature space
# Coefficient of determination R^2: -0.06107570218281211
# Mean squared error:               0.06207443688365132
# Mean absolute error:              0.20132087542087537
# Root mean squared error:          0.24914741998192821
# Correlation Coefficient:          -0.0187505762332704
# -------------------------------------------------------
#
# max_features: 2; max_depth: 18; n_estimators: 200;
#
# Normal feature space
# Coefficient of determination R^2: 0.09634067560859871
# Mean squared error:               0.052865355017424204
# Mean absolute error:              0.18951227272727264
# Root mean squared error:          0.22992467248519505
# Correlation Coefficient:          0.35971633123916613
#
#
# Extended feature space
# Coefficient of determination R^2: -0.013000556016486309
# Mean squared error:               0.05926197249469696
# Mean absolute error:              0.19908409090909085
# Root mean squared error:          0.2434378205922345
# Correlation Coefficient:          0.06516559351583277
# -------------------------------------------------------
#
# max_features: 2; max_depth: 18; n_estimators: 300;
#
# Normal feature space
# Coefficient of determination R^2: 0.06167691134983
# Mean squared error:               0.05489323450067335
# Mean absolute error:              0.19363262626262615
# Root mean squared error:          0.2342930526086366
# Correlation Coefficient:          0.2671730267223387
#
#
# Extended feature space
# Coefficient of determination R^2: 0.0011472853293732488
# Mean squared error:               0.05843430366498309
# Mean absolute error:              0.19822494949494934
# Root mean squared error:          0.24173188384030578
# Correlation Coefficient:          0.09062326953321738
# -------------------------------------------------------
#
# max_features: 2; max_depth: 18; n_estimators: 500;
#
# Normal feature space
# Coefficient of determination R^2: 0.03409178525162326
# Mean squared error:               0.05650700358933323
# Mean absolute error:              0.19581503030303013
# Root mean squared error:          0.2377120181844688
# Correlation Coefficient:          0.18854051810897846
#
#
# Extended feature space
# Coefficient of determination R^2: 0.01351892088195994
# Mean squared error:               0.0577105453990302
# Mean absolute error:              0.19773357575757558
# Root mean squared error:          0.2402301925217357
# Correlation Coefficient:          0.12747827973761802
# -------------------------------------------------------
#
# max_features: 2; max_depth: 20; n_estimators: 10;
#
# Normal feature space
# Coefficient of determination R^2: -0.08688676256412697
# Mean squared error:               0.0635844206060606
# Mean absolute error:              0.20716363636363636
# Root mean squared error:          0.25215951420888444
# Correlation Coefficient:          0.037362797141842964
#
#
# Extended feature space
# Coefficient of determination R^2: -0.0794908272813506
# Mean squared error:               0.06315174787878787
# Mean absolute error:              0.2043818181818182
# Root mean squared error:          0.25130011515872386
# Correlation Coefficient:          0.0466701015136243
# -------------------------------------------------------
#
# max_features: 2; max_depth: 20; n_estimators: 20;
#
# Normal feature space
# Coefficient of determination R^2: 0.06464870835471215
# Mean squared error:               0.054719380151515146
# Mean absolute error:              0.1877121212121212
# Root mean squared error:          0.2339217393734818
# Correlation Coefficient:          0.2545483960656612
#
#
# Extended feature space
# Coefficient of determination R^2: -0.11229697910380199
# Mean squared error:               0.0650709543939394
# Mean absolute error:              0.20390303030303028
# Root mean squared error:          0.255090090740388
# Correlation Coefficient:          -0.06122211027597706
# -------------------------------------------------------
#
# max_features: 2; max_depth: 20; n_estimators: 30;
#
# Normal feature space
# Coefficient of determination R^2: -0.02951336027958873
# Mean squared error:               0.06022799501683501
# Mean absolute error:              0.20044848484848488
# Root mean squared error:          0.24541392588203917
# Correlation Coefficient:          0.06399227230412227
#
#
# Extended feature space
# Coefficient of determination R^2: -0.104646008146412
# Mean squared error:               0.06462336171717172
# Mean absolute error:              0.20727373737373736
# Root mean squared error:          0.25421125411195256
# Correlation Coefficient:          -0.06519176143296705
# -------------------------------------------------------
#
# ...
#
# Normal feature space
# Coefficient of determination R^2: 0.013684443156758874
# Mean squared error:               0.0577008621106666
# Mean absolute error:              0.19864636363636345
# Root mean squared error:          0.2402100374894159
# Correlation Coefficient:          0.1829934774528405
#
#
# Extended feature space
# Coefficient of determination R^2: 0.011427296148581845
# Mean squared error:               0.05783290841915145
# Mean absolute error:              0.19887248484848463
# Root mean squared error:          0.24048473635378909
# Correlation Coefficient:          0.1633659932633732
# -------------------------------------------------------
#
# max_features: 30; max_depth: 18; n_estimators: 10;
#
# Normal feature space
# Coefficient of determination R^2: -0.10661494933889704
# Mean squared error:               0.06473854757575759
# Mean absolute error:              0.20465757575757576
# Root mean squared error:          0.2544377086356454
# Correlation Coefficient:          0.09043366733000514
#
#
# Extended feature space
# Coefficient of determination R^2: -0.24190040589534312
# Mean squared error:               0.07265293909090909
# Mean absolute error:              0.22963939393939392
# Root mean squared error:          0.2695420915013258
# Correlation Coefficient:          -0.06730075913303517
# -------------------------------------------------------
#
# max_features: 30; max_depth: 18; n_estimators: 20;
#
# Normal feature space
# Coefficient of determination R^2: 0.08193235209466787
# Mean squared error:               0.05370826242424242
# Mean absolute error:              0.19243030303030303
# Root mean squared error:          0.23175043133561243
# Correlation Coefficient:          0.2967860442826525
#
#
# Extended feature space
# Coefficient of determination R^2: -0.06262438138114068
# Mean squared error:               0.06216503681818183
# Mean absolute error:              0.20989393939393938
# Root mean squared error:          0.24932917362030024
# Correlation Coefficient:          0.08680954029802515
# -------------------------------------------------------
#
# max_features: 30; max_depth: 18; n_estimators: 30;
#
# Normal feature space
# Coefficient of determination R^2: 0.06284983036993985
# Mean squared error:               0.05482461707070707
# Mean absolute error:              0.1930090909090909
# Root mean squared error:          0.23414657176799977
# Correlation Coefficient:          0.2747411588516338
#
#
# Extended feature space
# Coefficient of determination R^2: -0.0743482828103601
# Mean squared error:               0.06285090171717171
# Mean absolute error:              0.21206565656565657
# Root mean squared error:          0.2507008211338202
# Correlation Coefficient:          0.049985467968950495
# -------------------------------------------------------
#
# max_features: 30; max_depth: 18; n_estimators: 40;
#
# Normal feature space
# Coefficient of determination R^2: 0.0582124684133315
# Mean squared error:               0.0550959093371212
# Mean absolute error:              0.19064166666666663
# Root mean squared error:          0.23472517831950027
# Correlation Coefficient:          0.26478014928109356
#
#
# Extended feature space
# Coefficient of determination R^2: -0.05924444732241696
# Mean squared error:               0.06196730587121213
# Mean absolute error:              0.20924696969696968
# Root mean squared error:          0.24893233191213257
# Correlation Coefficient:          0.06553897040687413
# -------------------------------------------------------
#
# max_features: 30; max_depth: 18; n_estimators: 50;
#
# Normal feature space
# Coefficient of determination R^2: 0.04443693333062115
# Mean squared error:               0.0559017977212121
# Mean absolute error:              0.1927951515151515
# Root mean squared error:          0.23643561009545938
# Correlation Coefficient:          0.25310209860693206
#
#
# Extended feature space
# Coefficient of determination R^2: -0.016227430041491964
# Mean squared error:               0.059450749212121214
# Mean absolute error:              0.20373696969696967
# Root mean squared error:          0.24382524318068713
# Correlation Coefficient:          0.13532982956532308
# -------------------------------------------------------
#
# max_features: 30; max_depth: 18; n_estimators: 60;
#
# Normal feature space
# Coefficient of determination R^2: 0.05183536995985194
# Mean squared error:               0.05546897866161615
# Mean absolute error:              0.19237222222222222
# Root mean squared error:          0.23551853146114884
# Correlation Coefficient:          0.25668506520597856
#
#
# Extended feature space
# Coefficient of determination R^2: -0.0067000004065420615
# Mean squared error:               0.058893381035353534
# Mean absolute error:              0.20152676767676764
# Root mean squared error:          0.24267958512275714
# Correlation Coefficient:          0.14942844715872597
# -------------------------------------------------------
#
# max_features: 30; max_depth: 18; n_estimators: 80;
#
# Normal feature space
# Coefficient of determination R^2: 0.03195886837513506
# Mean squared error:               0.05663178225852269
# Mean absolute error:              0.19584356060606056
# Root mean squared error:          0.2379743310916593
# Correlation Coefficient:          0.22657231028799465
#
#
# Extended feature space
# Coefficient of determination R^2: -0.01407235844343413
# Mean squared error:               0.059324674460227274
# Mean absolute error:              0.20336590909090907
# Root mean squared error:          0.2435665709004979
# Correlation Coefficient:          0.1436729346593419
# -------------------------------------------------------
#
# max_features: 30; max_depth: 18; n_estimators: 90;
#
# Normal feature space
# Coefficient of determination R^2: 0.026313791818299848
# Mean squared error:               0.05696202726150389
# Mean absolute error:              0.19556329966329958
# Root mean squared error:          0.23866718932753175
# Correlation Coefficient:          0.2182722227924209
#
#
# Extended feature space
# Coefficient of determination R^2: 0.0004650661044223181
# Mean squared error:               0.058474214459408896
# Mean absolute error:              0.2022124579124579
# Root mean squared error:          0.24181442152900826
# Correlation Coefficient:          0.16223543541164434
# -------------------------------------------------------
# max_features: 30; max_depth: 18; n_estimators: 200;
#
# Normal feature space
# Coefficient of determination R^2: 0.00046766275745990793
# Mean squared error:               0.058474062551515084
# Mean absolute error:              0.20003303030303016
# Root mean squared error:          0.24181410742865084
# Correlation Coefficient:          0.16915283365682066
#
#
# Extended feature space
# Coefficient of determination R^2: -0.004463680288477434
# Mean squared error:               0.058762553129545425
# Mean absolute error:              0.200415909090909
# Root mean squared error:          0.24240988661674967
# Correlation Coefficient:          0.13942293951924326
# -------------------------------------------------------
#
# max_features: 30; max_depth: 18; n_estimators: 300;
#
# Normal feature space
# Coefficient of determination R^2: 0.01754831018680847
# Mean squared error:               0.05747482039696961
# Mean absolute error:              0.19844030303030286
# Root mean squared error:          0.23973906731479877
# Correlation Coefficient:          0.19467209326770418
#
#
# Extended feature space
# Coefficient of determination R^2: 0.0034093996679988026
# Mean squared error:               0.058301966760606005
# Mean absolute error:              0.19912373737373723
# Root mean squared error:          0.24145800206372536
# Correlation Coefficient:          0.15183343822477804
# -------------------------------------------------------
#
# max_features: 30; max_depth: 18; n_estimators: 500;
#
# Normal feature space
# Coefficient of determination R^2: 0.013723987057837284
# Mean squared error:               0.05769854873624235
# Mean absolute error:              0.19864193939393926
# Root mean squared error:          0.24020522212525344
# Correlation Coefficient:          0.18305717860260007
#
#
# Extended feature space
# Coefficient of determination R^2: 0.011414673652912155
# Mean squared error:               0.05783364685309084
# Mean absolute error:              0.19887490909090888
# Root mean squared error:          0.2404862716520235
# Correlation Coefficient:          0.163350606557143
# -------------------------------------------------------
#
# max_features: 30; max_depth: 20; n_estimators: 10;
#
# Normal feature space
# Coefficient of determination R^2: -0.10661494933889704
# Mean squared error:               0.06473854757575759
# Mean absolute error:              0.20465757575757576
# Root mean squared error:          0.2544377086356454
# Correlation Coefficient:          0.09043366733000505
#
#
# Extended feature space
# Coefficient of determination R^2: -0.24190040589534312
# Mean squared error:               0.07265293909090909
# Mean absolute error:              0.22963939393939392
# Root mean squared error:          0.2695420915013258
# Correlation Coefficient:          -0.06730075913303521
# -------------------------------------------------------
#
# max_features: 30; max_depth: 20; n_estimators: 20;
#
# Normal feature space
# Coefficient of determination R^2: 0.08193235209466776
# Mean squared error:               0.053708262424242426
# Mean absolute error:              0.19243030303030303
# Root mean squared error:          0.23175043133561246
# Correlation Coefficient:          0.29678604428265243
#
#
# Extended feature space
# Coefficient of determination R^2: -0.06262438138114068
# Mean squared error:               0.06216503681818183
# Mean absolute error:              0.20989393939393938
# Root mean squared error:          0.24932917362030024
# Correlation Coefficient:          0.08680954029802523
# -------------------------------------------------------
#
# max_features: 30; max_depth: 20; n_estimators: 30;
#
# Normal feature space
# Coefficient of determination R^2: 0.06284983036993985
# Mean squared error:               0.05482461707070707
# Mean absolute error:              0.1930090909090909
# Root mean squared error:          0.23414657176799977
# Correlation Coefficient:          0.27474115885163375
#
#
# Extended feature space
# Coefficient of determination R^2: -0.07434828281036032
# Mean squared error:               0.06285090171717173
# Mean absolute error:              0.21206565656565657
# Root mean squared error:          0.25070082113382025
# Correlation Coefficient:          0.04998546796895044
# -------------------------------------------------------
#
# max_features: 30; max_depth: 20; n_estimators: 40;
#
# Normal feature space
# Coefficient of determination R^2: 0.0582124684133315
# Mean squared error:               0.0550959093371212
# Mean absolute error:              0.1906416666666666
# Root mean squared error:          0.23472517831950027
# Correlation Coefficient:          0.2647801492810937
#
#
# Extended feature space
# Coefficient of determination R^2: -0.05924444732241696
# Mean squared error:               0.06196730587121213
# Mean absolute error:              0.20924696969696968
# Root mean squared error:          0.24893233191213257
# Correlation Coefficient:          0.06553897040687418
# -------------------------------------------------------
#
# max_features: 30; max_depth: 20; n_estimators: 50;
#
# Normal feature space
# Coefficient of determination R^2: 0.04443693333062104
# Mean squared error:               0.05590179772121211
# Mean absolute error:              0.1927951515151515
# Root mean squared error:          0.2364356100954594
# Correlation Coefficient:          0.2531020986069319
#
#
# Extended feature space
# Coefficient of determination R^2: -0.016227430041491964
# Mean squared error:               0.05945074921212122
# Mean absolute error:              0.2037369696969697
# Root mean squared error:          0.24382524318068713
# Correlation Coefficient:          0.1353298295653232
# -------------------------------------------------------
#
# max_features: 30; max_depth: 20; n_estimators: 60;
#
# Normal feature space
# Coefficient of determination R^2: 0.05183536995985194
# Mean squared error:               0.05546897866161615
# Mean absolute error:              0.19237222222222222
# Root mean squared error:          0.23551853146114884
# Correlation Coefficient:          0.25668506520597856
#
#
# Extended feature space
# Coefficient of determination R^2: -0.0067000004065420615
# Mean squared error:               0.058893381035353534
# Mean absolute error:              0.20152676767676767
# Root mean squared error:          0.24267958512275714
# Correlation Coefficient:          0.149428447158726
# -------------------------------------------------------
#
# max_features: 30; max_depth: 20; n_estimators: 80;
#
# Normal feature space
# Coefficient of determination R^2: 0.03195886837513484
# Mean squared error:               0.0566317822585227
# Mean absolute error:              0.19584356060606056
# Root mean squared error:          0.23797433109165933
# Correlation Coefficient:          0.2265723102879946
#
#
# Extended feature space
# Coefficient of determination R^2: -0.01407235844343413
# Mean squared error:               0.05932467446022727
# Mean absolute error:              0.20336590909090907
# Root mean squared error:          0.24356657090049788
# Correlation Coefficient:          0.1436729346593419
# -------------------------------------------------------
#
# max_features: 30; max_depth: 20; n_estimators: 90;
#
# Normal feature space
# Coefficient of determination R^2: 0.026313791818299626
# Mean squared error:               0.05696202726150391
# Mean absolute error:              0.19556329966329963
# Root mean squared error:          0.2386671893275318
# Correlation Coefficient:          0.21827222279242062
#
#
# Extended feature space
# Coefficient of determination R^2: 0.0004650661044223181
# Mean squared error:               0.058474214459408896
# Mean absolute error:              0.2022124579124579
# Root mean squared error:          0.24181442152900826
# Correlation Coefficient:          0.16223543541164437
# -------------------------------------------------------
#
# max_features: 30; max_depth: 20; n_estimators: 200;
#
# Normal feature space
# Coefficient of determination R^2: 0.0004676627574597969
# Mean squared error:               0.05847406255151509
# Mean absolute error:              0.20003303030303016
# Root mean squared error:          0.24181410742865084
# Correlation Coefficient:          0.16915283365682068
#
#
# Extended feature space
# Coefficient of determination R^2: -0.004463680288477434
# Mean squared error:               0.058762553129545425
# Mean absolute error:              0.200415909090909
# Root mean squared error:          0.24240988661674967
# Correlation Coefficient:          0.13942293951924312
# -------------------------------------------------------
# max_features: 30; max_depth: 20; n_estimators: 300;
#
# Normal feature space
# Coefficient of determination R^2: 0.01754831018680847
# Mean squared error:               0.05747482039696961
# Mean absolute error:              0.19844030303030286
# Root mean squared error:          0.23973906731479877
# Correlation Coefficient:          0.19467209326770418
#
#
# Extended feature space
# Coefficient of determination R^2: 0.0034093996679989136
# Mean squared error:               0.058301966760606
# Mean absolute error:              0.19912373737373723
# Root mean squared error:          0.24145800206372536
# Correlation Coefficient:          0.15183343822477818
# -------------------------------------------------------
#
# max_features: 30; max_depth: 20; n_estimators: 500;
#
# Normal feature space
# Coefficient of determination R^2: 0.013723987057837173
# Mean squared error:               0.057698548736242354
# Mean absolute error:              0.19864193939393926
# Root mean squared error:          0.24020522212525347
# Correlation Coefficient:          0.18305717860260012
#
#
# Extended feature space
# Coefficient of determination R^2: 0.011414673652912155
# Mean squared error:               0.05783364685309084
# Mean absolute error:              0.1988749090909089
# Root mean squared error:          0.2404862716520235
# Correlation Coefficient:          0.16335060655714304
# -------------------------------------------------------

# %%
get_best_settings(results_1_nrp,results_2_nrp)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-126-ca012dc14fcd> in <module>()
# ----> 1 get_best_settings(results_1_nrp,results_2_nrp)
#
# <ipython-input-116-038ecd51052e> in get_best_settings(results_1, results_2)
#      24         for j in range(len(md)):
#      25             for k in range(len(n_est)):
# ---> 26                 if best_result_1 < results_1[i][j][k]:
#      27                     best_result_1 = results_1[i][j][k]
#      28                     best_i_1=i
#
# IndexError: index 11 is out of bounds for axis 0 with size 11

# %%
best_RFs(results_1_nrp,results_2_nrp,'nrp')
# Out:
# Normal best: 0.38280813385552753 | max_features: 2; max_depth: 7; n_estimators: 20;
# Extended best: 0.39016968220304177 | max_features: 4; max_depth: 5; n_estimators: 10;
# Best difference: 0.40031742573046575 | max_features: 4; max_depth: 5; n_estimators: 10;
# Normal feature space
# Coefficient of determination R^2: 0.13315430069337653
# Mean squared error:               0.05071170561985301
# Mean absolute error:              0.17559480339105335
# Root mean squared error:          0.2251925967252321
# Correlation Coefficient:          0.38280813385552753
#
#
# Extended feature space
# Coefficient of determination R^2: 0.1353267336473516
# Mean squared error:               0.05058461520395896
# Mean absolute error:              0.18640657675657674
# Root mean squared error:          0.22491023810391328
# Correlation Coefficient:          0.39016968220304177
# -------------------------------------------------------

# %%
#BEST NON RIBOSOMAL PROTEIN

# Normal best: 0.38280813385552753 | max_features: 2; max_depth: 7; n_estimators: 20;
# Extended best: 0.39016968220304177 | max_features: 4; max_depth: 5; n_estimators: 10;

X,y,X2,y2 = get_data('nrp')

rfr1 = ExtraTreesRegressor(n_estimators=20, 
                            criterion='mse', 
                            max_features=2, 
                            max_depth=7, 
                            n_jobs=2,
                            random_state=1337)

rfr2 = ExtraTreesRegressor(n_estimators=10, 
                            criterion='mse', 
                            max_features=4, 
                            max_depth=5, 
                            n_jobs=2,
                            random_state=1337)

kf = KFold(n_splits=5,shuffle=True,random_state=0)
predictions_rfr1_nrp = cross_val_predict(rfr1,X,y=y,cv=kf)
predictions_rfr2_nrp = cross_val_predict(rfr2,X2,y=y2,cv=kf)

fit_scatter_nrp(y,predictions_rfr1_nrp,filename='full_nrp_scat',title='non-RP intron-containing')
fit_scatter_nrp(y,predictions_rfr2_nrp,filename='full_nrp_scat_ext',title='non-RP intron-containing')

print('Data')
print_stats(y,predictions_rfr1_nrp)
print('\n')
print('Extended Data')
print_stats(y2,predictions_rfr2_nrp)

rfr1.fit(X,y)
rfr2.fit(X2,y2)

names,names2 = get_variable_names('full')
plot_importance(rfr1.feature_importances_,names,'nrp_full')
plot_importance(rfr2.feature_importances_,names2,'nrp_full_ext')
# Out:
# Data
# Coefficient of determination R^2: 0.13315430069337653
# Mean squared error:               0.05071170561985301
# Mean absolute error:              0.17559480339105338
# Root mean squared error:          0.2251925967252321
# Correlation Coefficient:          0.3828081338555276
#
#
# Extended Data
# Coefficient of determination R^2: 0.1353267336473516
# Mean squared error:               0.05058461520395896
# Mean absolute error:              0.18640657675657674
# Root mean squared error:          0.22491023810391328
# Correlation Coefficient:          0.39016968220304177
# /home/ghristov/miniconda3/envs/mlp/lib/python3.5/site-packages/ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in true_divide
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# Normal best: 0.2969901764177368 | max_features: 25; max_depth: 5; n_estimators: 10;
# Extended best: 0.40630448232918154 | max_features: 30; max_depth: 7; n_estimators: 20;
# Best difference: 0.2582434619528223 | max_features: 30; max_depth: 7; n_estimators: 20;
# Normal feature space
# Coefficient of determination R^2: 0.2360352774266372
# Mean squared error:               0.03984437679487179
# Mean absolute error:              0.1488410256410256
# Root mean squared error:          0.19961056283391365
# Correlation Coefficient:          0.48848065665874996
#
#
# Extended feature space
# Coefficient of determination R^2: 0.38909635792549957
# Mean squared error:               0.031861516874999996
# Mean absolute error:              0.13109380341880345
# Root mean squared error:          0.1784979464167585
# Correlation Coefficient:          0.6250700537546936

# %%
X,y1,_,_ = get_data('rp')
X,y2,_,_ = get_data('nrp')

fit_scatter_multi(y1,y2,predictions_rfr1_rp,predictions_rfr1_nrp,'full_rp_nrp','All intron-containing')
fit_scatter_multi(y1,y2,predictions_rfr2_rp,predictions_rfr2_nrp,'full_rp_nrp_ext','All intron-containing')

# %%
from sklearn.cross_validation import ShuffleSplit
from sklearn.metrics import r2_score
from collections import defaultdict

X,Y,X2,Y2 = get_data('full')
names = gene_features.drop(['ORG','Gene','AUC'], axis=1).columns
rf = RandomForestRegressor(random_state=1337,n_estimators=300)
scores = defaultdict(list)
X = X.values
Y = Y.values
#crossvalidate the scores on a number of different random splits of the data
for train_idx, test_idx in ShuffleSplit(len(X), 100, .3):
    X_train, X_test = X[train_idx], X[test_idx]
    Y_train, Y_test = Y[train_idx], Y[test_idx]
    r = rf.fit(X_train, Y_train)
    acc = r2_score(Y_test, rf.predict(X_test))
    for i in range(X.shape[1]):
        X_t = X_test.copy()
        np.random.shuffle(X_t[:, i])
        shuff_acc = r2_score(Y_test, rf.predict(X_t))
        scores[names[i]].append((acc-shuff_acc)/acc)
print("Features sorted by their score:")
print (sorted([(round(np.mean(score), 4), feat) for
              feat, score in scores.items()], reverse=True))
# Out:
# Features sorted by their score:
# [(0.6054, 'A'), (0.2064, 'U'), (0.085, 'ΔG, 5ss'), (0.0845, '5ss-BP len (bp)'), (0.0708, 'Exon2 len (bp)'), (0.0685, 'Intron len (bp)'), (0.0233, 'G'), (0.018, 'ΔG per bp, intron'), (0.0176, 'BP-3ss len (bp)'), (0.0081, 'ΔG, 3ss'), (0.0081, 'Gene len (bp)'), (-0.003, 'C'), (-0.0033, 'ΔG  per bp, 3ss-BP'), (-0.0056, 'BP score'), (-0.0077, 'Exon1 len (bp)'), (-0.0102, '3ss Score'), (-0.0129, 'ΔG  per bp, 5ss-BP'), (-0.0159, '5ss Score')]

# %%
from sklearn import ensemble
from sklearn import datasets
from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error

# #############################################################################
# Load data
names = extended_features_cut.drop(['ORG','Gene','AUC'], axis=1).columns
X2,y2,X,y = get_data('rp_cut')
X = X.astype(np.float32)
offset = int(X.shape[0] * 0.9)
X_train, y_train = X[:offset], y[:offset]
X_test, y_test = X[offset:], y[offset:]

# #############################################################################
# Fit regression model
params = {'n_estimators': 500, 'max_depth': 4, 'min_samples_split': 2,
          'learning_rate': 0.01, 'loss': 'ls'}
clf = ensemble.GradientBoostingRegressor(**params)

clf.fit(X_train, y_train)
mse = mean_squared_error(y_test, clf.predict(X_test))
print("MSE: %.4f" % mse)
print("R2: %.4f" % r2_score(y_test,clf.predict(X_test)))

# #############################################################################
# Plot training deviance

# # compute test set deviance
# test_score = np.zeros((params['n_estimators'],), dtype=np.float64)

# for i, y_pred in enumerate(clf.staged_predict(X_test)):
#     test_score[i] = clf.loss_(y_test, y_pred)


# plt.subplot(1, 2, 1)
# plt.title('Deviance')
# plt.plot(np.arange(params['n_estimators']) + 1, clf.train_score_, 'b-',
#          label='Training Set Deviance')
# plt.plot(np.arange(params['n_estimators']) + 1, test_score, 'r-',
#          label='Test Set Deviance')
# plt.legend(loc='upper right')
# plt.xlabel('Boosting Iterations')
# plt.ylabel('Deviance')

# #############################################################################
# Plot feature importance
plt.figure(figsize=(20, 12))
feature_importance = clf.feature_importances_
# make importances relative to max importance
feature_importance = 100.0 * (feature_importance / feature_importance.max())
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
plt.subplot(1, 2, 2)
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, names[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()
# Out:
# MSE: 0.0391
# R2: -2.0055

# %%
X,y,X2,y2 = get_data('nrp')

rf = RandomForestRegressor(n_estimators=1000, 
                            criterion='mse', 
                            max_features=10, 
                            max_depth=10, 
                            n_jobs=2,
                            random_state=1337)

rf.fit(X, y)

fig, ax1 = plt.subplots(figsize=(18,6))
xx = np.arange(len(rf.feature_importances_))
ax1.bar(xx, rf.feature_importances_,color='b')
ax1.set_xticks(xx)
ax1.set_xticklabels(get_variable_names('full')[1], rotation='vertical',fontsize=13)
ax1.set_title('RF feature importance predicting non-RP intron-containing genes',fontsize=25)
plt.tight_layout()
fig.savefig('RF_fi_nrp.pdf')

# %%
from sklearn.cross_validation import ShuffleSplit
from sklearn.metrics import r2_score
from collections import defaultdict

X,Y,X2,Y2 = get_data('rp_cut')
X = X.values
Y = Y.values
rf = ExtraTreesRegressor(n_estimators=1000)
scores = defaultdict(list)
 
#crossvalidate the scores on a number of different random splits of the data
for train_idx, test_idx in ShuffleSplit(len(X), 100, .3):
    X_train, X_test = X[train_idx], X[test_idx]
    Y_train, Y_test = Y[train_idx], Y[test_idx]
    r = rf.fit(X_train, Y_train)
    acc = r2_score(Y_test, rf.predict(X_test))
    for i in range(X.shape[1]):
        X_t = X_test.copy()
        np.random.shuffle(X_t[:, i])
        shuff_acc = r2_score(Y_test, rf.predict(X_t))
        scores[names[i]].append((acc-shuff_acc)/acc)
print ("Features sorted by their score:")
print (sorted([(round(np.mean(score), 4), feat) for
              feat, score in scores.items()], reverse=True))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-133-2b7d4aa41ab6> in <module>()
#      18         X_t = X_test.copy()
#      19         np.random.shuffle(X_t[:, i])
# ---> 20         shuff_acc = r2_score(Y_test, rf.predict(X_t))
#      21         scores[names[i]].append((acc-shuff_acc)/acc)
#      22 print ("Features sorted by their score:")
#
# ~/miniconda3/envs/mlp/lib/python3.5/site-packages/sklearn/ensemble/forest.py in predict(self, X)
#     694         Parallel(n_jobs=n_jobs, verbose=self.verbose, backend="threading")(
#     695             delayed(accumulate_prediction)(e.predict, X, [y_hat], lock)
# --> 696             for e in self.estimators_)
#     697
#     698         y_hat /= len(self.estimators_)
#
# ~/miniconda3/envs/mlp/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# ~/miniconda3/envs/mlp/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     619         with self._lock:
#     620             tasks = BatchedCalls(itertools.islice(iterator, batch_size))
# --> 621             if len(tasks) == 0:
#     622                 # No more tasks available in the iterator: tell caller to stop.
#     623                 return False
#
# ~/miniconda3/envs/mlp/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in __len__(self)
#     131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
# --> 133     def __len__(self):
#     134         return self._size
#     135
#
# KeyboardInterrupt:
